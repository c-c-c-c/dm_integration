# %%
from urllib import request
from bs4 import BeautifulSoup
import urllib.request
import requests

# URLごとにスクレイピングを行う
def scraping(url):
    
    start_at = get_start_at(url)
    #ページに複数ある対象部分を取得する
    html = request.urlopen(url)
    soup = BeautifulSoup(html, fromEncoding="euc-jp")
    drama_info_tables = soup.select('.tableborder.ar')
    # cast
    tmp_drama_info_dict = {}
    for dt in drama_info_tables:
        drama_title = dt.select('.red')
        cast_staff = dt.select('.left.pl5px')
        
        # <フジテレビ>などを消す
        [drama_title, TV_station] = reshape_title(drama_title[0].text)
        # キャストスタッフは調整中

        #         import pdb; pdb.set_trace()
        cast_staff_value = reshape_cast_staff(str(cast_staff[0]))
        
        # 曜日時間
        weekday_time_value = get_weekday_time(dt)
        
        drama_key = start_at + "_" + TV_station + "_" + weekday_time_value
        print(drama_key)
        tmp_drama_info_dict[drama_title] = cast_staff_value
    
    return tmp_drama_info_dict

# %%
# 以下yymmを設定する配列
yymm_arr = ["1910","1907", "1904","1901",
           "1810", "1807", "1804", "1801",
           "1710", "1707", "1704", "1701",
           "1610", "1607", "1604", "1601", 
           "1510", "1507", "1504", "1501", 
           "1410", "1407", "1404", "1401", 
           "1310", "1307", "1304", "1301", 
           "1210", "1207", "1204", "1201", 
           "1110", "1107", "1104", "1101", 
           "1010", "1007", "1004", "1001", 
           "0910", "0907", "0904", "0901", 
           "0810", "0807", "0804", "0801", 
           "0710", "0707", "0704", "0701", 
           "0610", "0607", "0604", "0601", 
           "0510", "0507", "0504", "0501", 
           "0410", "0407", "0404", "0401", 
           "0310", "0307", "0304", "0301", ]
# urlを配列で作成
urls_arr =[]
for yymm in yymm_arr:
    preurl = "https://artv.info/ar"
    epiurl = ".html"
    # urlを合体(ex: https://artv.info/ar1707.html )
    url = preurl + yymm +epiurl
    urls_arr.append(url)

# %%
def reshape_cast_staff (tmp_cast_staff): 
    tmp_splited = tmp_cast_staff.split("<br/>")
    tmp_splited = [tmp_ele for tmp_ele in tmp_splited if tmp_ele]
    import re
    p = re.compile(r"<[^>]*?>|\n|\r|\t")

    info_arr = []
    for tmp_text in tmp_splited:
        #import pdb; pdb.set_trace()
        tmp_text_after = p.sub("",tmp_text)
        if tmp_text_after:
            info_arr.append(tmp_text_after)
        
    return (info_arr)

# %%
def reshape_title (tmp_title): 
    
    TV_station_dict = {"テレビ朝日": "EX", "日本テレビ": "NTV", "フジテレビ":"CX", "TBS":"TBS"}
    import re
    tv_reg = re.compile(r"\u3000＜(\w+)＞")
    TV_station = tv_reg.findall(tmp_title)[0]
    TV_station = TV_station_dict[TV_station]
    
    
    p = re.compile(r"\u3000＜\w+＞")
    return(p.sub("",tmp_title), TV_station)

# %%
def get_weekday_time (tmp_dom):
    import re
    p = re.compile(r"(\w)曜(\d{2})")

#     import pdb; pdb.set_trace()
    tmp_match = re.findall(p,str(tmp_dom))[0]
    tmp_match = tmp_match[0] + tmp_match[1]
    return (tmp_match)

# %%
def get_start_at (url):
    import re
    p = re.compile("\d{4}")

#     import pdb; pdb.set_trace()
    start_at = re.findall(p,url)[0]
    return (start_at)

# %%
# get_weekday_time(dt)

# %%
###########
# 実行本体
#
drama_info_dict = {}
for tmp_url in urls_arr:
    tmp_drama_info_dict = scraping(tmp_url)
    drama_info_dict.update(tmp_drama_info_dict)

import pprint
pprint.pprint(drama_info_dict)
# Out:
# 1910CX月21
# 1910CX火22
# 1910TBS火22
# 1910NTV水22
# 1910EX木22
# 1910CX木22
# 1910NTV木23
# 1910TBS金22
# 1910EX金23
# 1910NTV土22
# 1910EX土23
# 1910TBS日21
# 1910NTV日22
# 1907CX月21
# 1907CX火21
# 1907TBS火22
# 1907NTV水22
# 1907EX木21
# 1907CX木22
# 1907NTV木23
# 1907TBS金22
# 1907EX金23
# 1907NTV土22
# 1907EX土23
# 1907TBS日21
# 1907NTV日22
# 1904CX月21
# 1904CX火21
# 1904TBS火22
# 1904NTV水22
# 1904EX木21
# 1904CX木22
# 1904NTV木23
# 1904TBS金22
# 1904EX金23
# 1904NTV土22
# 1904EX土23
# 1904TBS日21
# 1904NTV日22
# 1901CX月21
# 1901CX火21
# 1901TBS火22
# 1901NTV水22
# 1901EX木21
# 1901CX木22
# 1901NTV木23
# 1901TBS金22
# 1901EX金23
# 1901NTV土22
# 1901EX土23
# 1901TBS日21
# 1901NTV日22
# 1810CX月21
# 1810CX火21
# 1810TBS火22
# 1810NTV水22
# 1810EX木21
# 1810CX木22
# 1810NTV木23
# 1810TBS金22
# 1810EX金23
# 1810NTV土22
# 1810EX土23
# 1810TBS日21
# 1810NTV日22
# 1807CX月21
# 1807CX火21
# 1807TBS火22
# 1807NTV水22
# 1807EX木21
# 1807CX木22
# 1807NTV木23
# 1807TBS金22
# 1807EX金23
# 1807NTV土22
# 1807EX土23
# 1807TBS日21
# 1807NTV日22
# 1804CX月21
# 1804CX火21
# 1804TBS火22
# 1804NTV水22
# 1804EX木21
# 1804CX木22
# 1804NTV木23
# 1804TBS金22
# 1804EX金23
# 1804NTV土22
# 1804EX土23
# 1804TBS日21
# 1804NTV日22
# 1801CX月21
# 1801CX火21
# 1801TBS火22
# 1801NTV水22
# 1801EX木21
# 1801CX木22
# 1801NTV木23
# 1801TBS金22
# 1801EX金23
# 1801NTV土22
# 1801EX土23
# 1801TBS日21
# 1801NTV日22
# 1710CX月21
# 1710CX火21
# 1710TBS火22
# 1710NTV水22
# 1710EX木21
# 1710CX木22
# 1710NTV木23
# 1710TBS金22
# 1710EX金23
# 1710NTV土22
# 1710TBS日21
# 1710NTV日22
# 1707CX月21
# 1707CX火21
# 1707TBS火22
# 1707NTV水22
# 1707EX木20
# 1707EX木21
# 1707CX木22
# 1707NTV木23
# 1707TBS金22
# 1707EX金23
# 1707NTV土22
# 1707TBS日21
# 1707CX日21
# 1707NTV日22
# 1704CX月21
# 1704CX火21
# 1704TBS火22
# 1704NTV水22
# 1704EX木21
# 1704CX木22
# 1704NTV木23
# 1704TBS金22
# 1704EX金23
# 1704NTV土22
# 1704TBS日21
# 1704CX日21
# 1704NTV日22
# 1701CX月21
# 1701CX火21
# 1701TBS火22
# 1701NTV水22
# 1701EX木21
# 1701CX木22
# 1701NTV木23
# 1701TBS金22
# 1701EX金23
# 1701NTV土21
# 1701CX日21
# 1701TBS日21
# 1701NTV日22
# 1610CX月21
# 1610CX火21
# 1610TBS火22
# 1610NTV水22
# 1610EX木21
# 1610CX木22
# 1610NTV木23
# 1610TBS金22
# 1610EX金23
# 1610NTV土21
# 1610CX日21
# 1610TBS日21
# 1610NTV日22
# 1607CX月21
# 1607CX火22
# 1607TBS火22
# 1607NTV水22
# 1607EX木21
# 1607CX木22
# 1607NTV木23
# 1607TBS金22
# 1607EX金23
# 1607NTV土21
# 1607CX日21
# 1607TBS日21
# 1607NTV日22
# 1604CX月21
# 1604CX火22
# 1604TBS火22
# 1604NTV水22
# 1604EX木21
# 1604CX木22
# 1604NTV木23
# 1604TBS金22
# 1604EX金23
# 1604NTV土21
# 1604CX土23
# 1604CX日21
# 1604TBS日21
# 1604NTV日22
# 1601CX月21
# 1601CX火22
# 1601TBS火22
# 1601NTV水22
# 1601CX水22
# 1601EX木21
# 1601CX木22
# 1601NTV木23
# 1601TBS金22
# 1601EX金23
# 1601NTV土21
# 1601TBS日21
# 1601NTV日22
# 1510CX月21
# 1510CX火22
# 1510TBS火22
# 1510NTV水22
# 1510CX水22
# 1510EX木21
# 1510CX木22
# 1510NTV木23
# 1510TBS金22
# 1510EX金23
# 1510NTV土21
# 1510TBS日21
# 1510NTV日22
# 1507CX月21
# 1507CX火22
# 1507TBS火22
# 1507NTV水22
# 1507CX水22
# 1507TBS木21
# 1507EX木21
# 1507CX木22
# 1507NTV木23
# 1507TBS金22
# 1507EX金23
# 1507NTV土21
# 1507TBS日21
# 1507NTV日22
# 1504CX月21
# 1504CX火22
# 1504TBS火22
# 1504NTV水22
# 1504CX水22
# 1504TBS木21
# 1504EX木21
# 1504CX木22
# 1504NTV木23
# 1504TBS金22
# 1504EX金23
# 1504NTV土21
# 1504TBS日21
# 1504NTV日22
# 1501TBS月20
# 1501CX月21
# 1501CX火21
# 1501CX火22
# 1501TBS火22
# 1501NTV水22
# 1501CX水22
# 1501TBS木21
# 1501EX木21
# 1501CX木22
# 1501NTV木23
# 1501TBS金22
# 1501EX金23
# 1501NTV土21
# 1501TBS日21
# 1410TBS月20
# 1410CX月21
# 1410CX火21
# 1410CX火22
# 1410TBS火22
# 1410NTV水22
# 1410CX水22
# 1410TBS木21
# 1410TBS木21
# 1410EX木21
# 1410CX木22
# 1410NTV木23
# 1410TBS金22
# 1410EX金23
# 1410NTV土21
# 1410TBS日21
# 1407TBS月20
# 1407CX月21
# 1407TBS火22
# 1407CX火21
# 1407CX火22
# 1407NTV水22
# 1407CX水22
# 1407EX木20
# 1407TBS木21
# 1407EX木21
# 1407CX木22
# 1407NTV木23
# 1407TBS金22
# 1407EX金23
# 1407NTV土21
# 1407CX土23
# 1407TBS日21
# 1404TBS月20
# 1404CX月21
# 1404TBS火22
# 1404CX火21
# 1404CX火22
# 1404EX水21
# 1404NTV水22
# 1404CX水22
# 1404EX木20
# 1404TBS木21
# 1404EX木21
# 1404CX木22
# 1404NTV木23
# 1404TBS金22
# 1404EX金23
# 1404NTV土21
# 1404CX土23
# 1404TBS日21
# 1401TBS月20
# 1401CX月21
# 1401CX火21
# 1401CX火22
# 1401NTV水22
# 1401CX水22
# 1401TBS木21
# 1401EX木21
# 1401CX木22
# 1401NTV木23
# 1401CX金20
# 1401TBS金22
# 1401EX金23
# 1401NTV土21
# 1401CX土23
# 1401TBS日21
# 1310TBS月20
# 1310CX月21
# 1310CX火21
# 1310CX火22
# 1310NTV水22
# 1310CX水22
# 1310TBS木21
# 1310EX木21
# 1310CX木22
# 1310NTV木23
# 1310CX金20
# 1310TBS金22
# 1310EX金23
# 1310NTV土21
# 1310CX土23
# 1310TBS日21
# 1307TBS月20
# 1307CX月21
# 1307CX火21
# 1307CX火22
# 1307NTV水22
# 1307CX水22
# 1307TBS木21
# 1307EX木21
# 1307CX木22
# 1307NTV木23
# 1307TBS金22
# 1307EX金23
# 1307NTV土21
# 1307CX土23
# 1307TBS日21
# 1304TBS月20
# 1304CX月21
# 1304CX火21
# 1304CX火22
# 1304EX水21
# 1304NTV水22
# 1304CX水22
# 1304EX木20
# 1304TBS木21
# 1304EX木21
# 1304CX木22
# 1304NTV木23
# 1304TBS金22
# 1304EX金23
# 1304NTV土21
# 1304CX土23
# 1304TBS日21
# 1301TBS月20
# 1301CX月21
# 1301CX火21
# 1301CX火22
# 1301NTV水22
# 1301TBS木21
# 1301EX木21
# 1301CX木22
# 1301NTV木23
# 1301TBS金22
# 1301EX金23
# 1301NTV土21
# 1301CX土23
# 1301TBS日21
# 1301CX日21
# 1210TBS月20
# 1210CX月21
# 1210CX火21
# 1210CX火22
# 1210NTV水22
# 1210EX木21
# 1210TBS木21
# 1210CX木22
# 1210NTV木23
# 1210TBS金22
# 1210EX金23
# 1210NTV土21
# 1210CX土23
# 1210TBS日21
# 1210CX日21
# 1207TBS月20
# 1207CX月21
# 1207CX火21
# 1207CX火22
# 1207NTV水22
# 1207EX木21
# 1207TBS木21
# 1207CX木22
# 1207NTV木23
# 1207TBS金22
# 1207EX金23
# 1207NTV土21
# 1207CX土23
# 1207TBS日21
# 1207CX日21
# 1204TBS月20
# 1204CX月21
# 1204CX火21
# 1204CX火22
# 1204EX水21
# 1204NTV水22
# 1204EX木21
# 1204TBS木21
# 1204CX木22
# 1204NTV木23
# 1204TBS金22
# 1204EX金23
# 1204NTV土21
# 1204CX土23
# 1204TBS日21
# 1204CX日21
# 1201TBS月20
# 1201CX月21
# 1201CX火21
# 1201CX火22
# 1201NTV水22
# 1201EX木21
# 1201TBS木21
# 1201CX木22
# 1201NTV木23
# 1201TBS金22
# 1201EX金23
# 1201NTV土21
# 1201TBS日21
# 1201CX日21
# 1201EX日23
# 1110CX月21
# 1110CX火21
# 1110CX火22
# 1110NTV水22
# 1110EX木21
# 1110TBS木21
# 1110CX木22
# 1110NTV木23
# 1110TBS金22
# 1110EX金23
# 1110NTV土21
# 1110TBS日21
# 1110CX日21
# 1110EX日23
# 1107CX月21
# 1107CX火21
# 1107CX火22
# 1107NTV水22
# 1107EX木21
# 1107CX木22
# 1107NTV木23
# 1107TBS金22
# 1107EX金23
# 1107NTV土21
# 1107TBS日21
# 1107CX日21
# 1107EX日23
# 1104TBS月20
# 1104CX月21
# 1104CX火21
# 1104CX火22
# 1104EX水21
# 1104NTV水22
# 1104EX木21
# 1104CX木22
# 1104NTV木23
# 1104TBS金22
# 1104EX金23
# 1104NTV土21
# 1104TBS日21
# 1104CX日21
# 1104EX日23
# 1101CX月21
# 1101CX火21
# 1101CX火22
# 1101NTV水22
# 1101EX木21
# 1101CX木22
# 1101NTV木23
# 1101EX金21
# 1101TBS金22
# 1101EX金23
# 1101NTV土21
# 1101TBS日21
# 1101CX日21
# 1101EX日23
# 1010CX月21
# 1010CX火21
# 1010CX火22
# 1010NTV水22
# 1010EX木21
# 1010CX木22
# 1010NTV木23
# 1010EX金21
# 1010TBS金22
# 1010EX金23
# 1010NTV土21
# 1010TBS日21
# 1010CX日21
# 1010EX日23
# 1007TBS月20
# 1007CX月21
# 1007CX火21
# 1007CX火22
# 1007NTV水22
# 1007EX木21
# 1007CX木22
# 1007NTV木23
# 1007EX金21
# 1007TBS金22
# 1007EX金23
# 1007TBS土19
# 1007NTV土21
# 1007TBS日21
# 1004CX月21
# 1004CX火21
# 1004CX火22
# 1004EX水21
# 1004NTV水22
# 1004EX木21
# 1004CX木22
# 1004NTV木23
# 1004EX金21
# 1004TBS金22
# 1004EX金23
# 1004EX金23
# 1004TBS土19
# 1004NTV土21
# 1004TBS日21
# 1004EX日23
# 1001TBS月20
# 1001CX月21
# 1001CX火21
# 1001CX火22
# 1001NTV水22
# 1001EX木21
# 1001CX木22
# 1001NTV木23
# 1001EX金21
# 1001TBS金22
# 1001EX金23
# 1001TBS土19
# 1001NTV土21
# 1001TBS日21
# 0910CX月21
# 0910CX火21
# 0910CX火22
# 0910TBS水21
# 0910NTV水22
# 0910EX木21
# 0910CX木22
# 0910NTV木23
# 0910EX金21
# 0910TBS金22
# 0910EX金23
# 0910TBS土19
# 0910NTV土21
# 0910TBS日21
# 0907CX月21
# 0907CX火21
# 0907CX火22
# 0907TBS水21
# 0907NTV水22
# 0907EX木21
# 0907CX木22
# 0907NTV木23
# 0907EX金21
# 0907TBS金22
# 0907EX金23
# 0907TBS土19
# 0907NTV土21
# 0907CX土23
# 0907TBS日21
# 0904TBS月20
# 0904CX月21
# 0904CX火21
# 0904CX火22
# 0904TBS水21
# 0904EX水21
# 0904NTV水22
# 0904EX木21
# 0904CX木22
# 0904NTV木23
# 0904EX金21
# 0904TBS金22
# 0904EX金23
# 0904TBS土19
# 0904TBS土19
# 0904NTV土21
# 0904CX土23
# 0904CX土23
# 0904TBS日21
# 0901CX月21
# 0901CX火21
# 0901CX火22
# 0901NTV火22
# 0901NTV水22
# 0901EX木21
# 0901CX木22
# 0901NTV木23
# 0901EX金21
# 0901TBS金22
# 0901EX金23
# 0901TBS土19
# 0901NTV土21
# 0901CX土23
# 0901TBS日21
# 0810CX月21
# 0810CX火21
# 0810CX火22
# 0810NTV火22
# 0810NTV水22
# 0810EX木21
# 0810CX木22
# 0810NTV木23
# 0810EX金21
# 0810TBS金22
# 0810EX金23
# 0810TBS土19
# 0810NTV土21
# 0810CX土23
# 0810TBS日21
# 0807TBS月20
# 0807CX月21
# 0807CX火21
# 0807CX火22
# 0807NTV火22
# 0807EX水21
# 0807NTV水22
# 0807EX木21
# 0807CX木22
# 0807EX金21
# 0807TBS金22
# 0807EX金23
# 0807TBS土19
# 0807NTV土21
# 0807CX土23
# 0807TBS日21
# 0804CX月21
# 0804CX火21
# 0804CX火22
# 0804NTV火22
# 0804NTV水22
# 0804EX木21
# 0804CX木22
# 0804EX金21
# 0804TBS金22
# 0804EX金23
# 0804TBS土19
# 0804NTV土21
# 0804CX土23
# 0804TBS日21
# 0801CX月21
# 0801CX火21
# 0801CX火22
# 0801NTV火22
# 0801NTV水22
# 0801TBS木21
# 0801EX木21
# 0801TBS木22
# 0801CX木22
# 0801EX金21
# 0801TBS金22
# 0801EX金23
# 0801NTV土21
# 0801CX土23
# 0801TBS日21
# 0710CX月21
# 0710CX火21
# 0710CX火22
# 0710NTV火22
# 0710NTV水22
# 0710TBS木21
# 0710EX木21
# 0710TBS木22
# 0710CX木22
# 0710EX金21
# 0710TBS金22
# 0710EX金23
# 0710NTV土21
# 0710CX土23
# 0710TBS日21
# 0707CX月21
# 0707CX火21
# 0707CX火22
# 0707NTV火22
# 0707NTV水22
# 0707TBS木21
# 0707EX木21
# 0707TBS木22
# 0707CX木22
# 0707EX金21
# 0707TBS金22
# 0707EX金23
# 0707NTV土21
# 0707CX土23
# 0707TBS日21
# 0704CX月21
# 0704CX火21
# 0704CX火22
# 0704NTV火22
# 0704NTV水22
# 0704TBS木21
# 0704EX木21
# 0704TBS木22
# 0704CX木22
# 0704EX金21
# 0704TBS金22
# 0704EX金23
# 0704NTV土21
# 0704CX土23
# 0704TBS日21
# 0701CX月21
# 0701CX火21
# 0701CX火22
# 0701NTV水22
# 0701EX木21
# 0701TBS木22
# 0701CX木22
# 0701EX金21
# 0701TBS金22
# 0701EX金23
# 0701NTV土21
# 0701TBS日21
# 0610CX月21
# 0610CX火21
# 0610CX火22
# 0610NTV水22
# 0610EX木21
# 0610TBS木22
# 0610CX木22
# 0610EX金21
# 0610TBS金22
# 0610EX金23
# 0610NTV土21
# 0610TBS日21
# 0607CX月21
# 0607CX火21
# 0607CX火22
# 0607NTV水22
# 0607EX木21
# 0607TBS木22
# 0607CX木22
# 0607EX金21
# 0607TBS金22
# 0607EX金23
# 0607NTV土21
# 0607TBS日22
# 0604CX月21
# 0604CX火21
# 0604CX火22
# 0604NTV水22
# 0604EX木21
# 0604TBS木22
# 0604CX木22
# 0604EX金21
# 0604TBS金22
# 0604EX金23
# 0604NTV土21
# 0604TBS日21
# 0601CX月21
# 0601CX火21
# 0601CX火22
# 0601NTV水22
# 0601TBS木21
# 0601EX木21
# 0601TBS木22
# 0601CX木22
# 0601TBS金22
# 0601EX金23
# 0601NTV土21
# 0601TBS日21
# 0510CX月21
# 0510CX火21
# 0510CX火22
# 0510NTV水22
# 0510TBS木21
# 0510EX木21
# 0510TBS木22
# 0510CX木22
# 0510TBS金22
# 0510EX金23
# 0510NTV土21
# 0510TBS日21
# 0507CX月21
# 0507CX火21
# 0507CX火22
# 0507NTV水22
# 0507TBS木21
# 0507EX木21
# 0507TBS木22
# 0507CX木22
# 0507TBS金22
# 0507EX金23
# 0507NTV土21
# 0507TBS日21
# 0504CX月21
# 0504CX火21
# 0504CX火22
# 0504NTV水22
# 0504TBS木21
# 0504EX木21
# 0504TBS木22
# 0504CX木22
# 0504TBS金22
# 0504EX金23
# 0504NTV土21
# 0504TBS日21
# 0501CX月21
# 0501CX火21
# 0501CX火22
# 0501NTV水22
# 0501EX木21
# 0501TBS木22
# 0501CX木22
# 0501EX金23
# 0501NTV土21
# 0501TBS日21
# 0410CX月21
# 0410CX火21
# 0410CX火22
# 0410NTV水22
# 0410EX木21
# 0410TBS木22
# 0410CX木22
# 0410EX金23
# 0410NTV土21
# 0410TBS日21
# 0407CX月21
# 0407CX火21
# 0407CX火22
# 0407NTV水22
# 0407EX木21
# 0407TBS木22
# 0407CX木22
# 0407TBS金22
# 0407EX金23
# 0407NTV土21
# 0407TBS日21
# 0404CX月21
# 0404CX火21
# 0404CX火22
# 0404NTV水22
# 0404EX木21
# 0404TBS木22
# 0404CX木22
# 0404TBS金22
# 0404EX金23
# 0404NTV土21
# 0404TBS日21
# 0401CX月21
# 0401NTV月22
# 0401CX火21
# 0401CX火22
# 0401TBS水22
# 0401NTV水22
# 0401TBS木21
# 0401EX木21
# 0401TBS木22
# 0401CX木22
# 0401TBS金22
# 0401EX金23
# 0401NTV土21
# 0401TBS日21
# 0310CX月21
# 0310NTV月22
# 0310CX火21
# 0310CX火22
# 0310TBS水22
# 0310NTV水22
# 0310TBS木21
# 0310EX木21
# 0310TBS木22
# 0310CX木22
# 0310TBS金22
# 0310NTV土21
# 0310TBS日21
# 0307CX月21
# 0307NTV月22
# 0307CX火21
# 0307CX火22
# 0307TBS水22
# 0307NTV水22
# 0307TBS木21
# 0307EX木21
# 0307TBS木22
# 0307CX木22
# 0307TBS金22
# 0307NTV土21
# 0307TBS日21
# 0304CX月21
# 0304NTV月22
# 0304CX火21
# 0304CX火22
# 0304CX水21
# 0304TBS水22
# 0304TBS木21
# 0304EX木21
# 0304TBS木22
# 0304CX木22
# 0304TBS金22
# 0304NTV土21
# 0304TBS日21
# 0301CX月21
# 0301NTV月22
# 0301CX火21
# 0301CX火22
# 0301CX水21
# 0301TBS水22
# 0301NTV水22
# 0301EX木21
# 0301TBS木22
# 0301CX木22
# 0301TBS金22
# 0301NTV土21
# 0301TBS日21
# {'11人もいる！': ['神木隆之介、光浦靖子、',
#              '加藤清史郎、星野源、有村架純、',
#              '広末涼子、田辺誠一 etc',
#              '脚本 ： 宮藤官九郎',
#              'チーフＰ ： 黒田徹也',
#              'Ｐ ： 中川慎子、小池唯一',
#              '演出 ： 片山修、唐木希浩 etc',
#              '主題歌 ： NICO Touches the Walls『バイシクル』'],
#  '13歳のハローワーク ': ['松岡昌宏、横山裕、',
#                  '桐谷美玲、田中偉登、沢木ルカ、',
#                  '小松和重、光石研、古田新太、',
#                  '風吹ジュン etc',
#                  '原作 ： 村上龍「新13歳のハローワーク」',
#                  '脚本 ： 大石哲也',
#                  'チーフＰ ： 内山聖子',
#                  'Ｐ ： 中川慎子、遠田孝一、浅井千瑞',
#                  '演出 ： \ue2d3橋伸之、塚本連平、梶山貴弘 etc',
#                  '主題歌 ： TOKIO『羽田空港の奇跡』'],
#  '14ヶ月\u3000〜妻が子供に還っていく〜': ['高岡早紀、中村俊介、',
#                             '酒井若菜、丘みつ子、伊藤沙莉、',
#                             '羽場裕一、鈴木ヒロミツ、乃木涼介、',
#                             '松尾政寿、勝野洋輔、川津春、',
#                             '戸田恵子、石黒賢 etc',
#                             '原作 ： 市川たくじ「Separation〜きみが還る場所」',
#                             '脚本 ： 瀧川晃代、渡辺千穂',
#                             'Ｐ ： 竹綱裕博、山本和夫、梶野祐司',
#                             '演出 ： 山本和夫、岡本浩一 etc',
#                             '主題歌 ： GABALL〜feat.Joanne『幸せの表現』'],
#  '14才の母': ['志田未来、田中美佐子、',
#            '生瀬勝久、山口紗弥加、河本準一、',
#            '三浦春馬、谷村美月、北乃きい、',
#            '高畑淳子、海東健、金子さやか、',
#            '井坂俊哉、北村一輝、室井滋 etc',
#            '脚本 ： 井上由美子',
#            'Ｐ ： 村瀬健、浅井千瑞',
#            '演出 ： 佐藤東弥、佐久間紀佳 etc',
#            '主題歌 ： Mr.Children『しるし』'],
#  '1ポンドの福音': ['亀梨和也、黒木メイサ、',
#              '岡田義徳、山田涼介、高橋一生、',
#              '石黒英雄、波岡一喜、光石研、',
#              '南沢奈央、中村果生莉、江口のりこ、',
#              'もたいまさこ、小林聡美 etc',
#              '原作 ： 高橋留美子「1ポンドの福音」',
#              '脚本 ： 福田雄一',
#              'Ｐ ： 河野英裕、小泉守、下山潤',
#              '演出 ： 佐藤東弥 etc',
#              '主題歌 ： KAT-TUN『LIPS』'],
#  '1リットルの涙': ['沢尻エリカ、薬師丸ひろ子、',
#              '錦戸亮、成海璃子、真田佑馬、',
#              '三好杏依、松山ケンイチ、佐藤重幸、',
#              '勝野洋、藤木直人、陣内孝則 etc',
#              '原作 ： 木藤亜也「1リットルの涙」',
#              '脚本 ： 江頭美智留、大島里美、横田理恵',
#              'Ｐ ： 貸川聡子、江森浩子',
#              '演出 ： 村上正典、木下高男 etc',
#              '主題歌 ： K『Only Human』',
#              '挿入歌 ： レミオロメン『粉雪』'],
#  '33分探偵': ['堂本剛、水川あさみ、',
#            '野波麻帆、戸次重幸、小島よしお、',
#            '佐藤二朗、高橋克実 etc',
#            '脚本 ： 福田雄一',
#            'Ｐ ： 鹿内植、森谷雄',
#            '演出 ： 福田雄一、成田岳 etc',
#            '主題歌 ： KinKi Kids『Secret Code』'],
#  '35歳の高校生': ['米倉涼子、溝端淳平、',
#              '片瀬那奈、升毅、東根作寿英、',
#              '相葉裕樹、隈部洋平、生島翔、',
#              '横山めぐみ、榎本孝明、渡哲也 etc',
#              '脚本 ： 山浦雅大、高橋悠也',
#              'チーフＰ ： 大平太',
#              'Ｐ ： 池田健司、秋元孝之、高明希',
#              '演出 ： 佐久間紀佳、南雲聖一、西野真貴 etc',
#              '主題歌 ： EXILE『Flower Song』'],
#  '37.5℃の涙': ['蓮佛美沙子、成宮寛貴、',
#              '速水もこみち、トリンドル玲奈、鈴木梨央、',
#              '水上剣星、滝沢沙織、西村和彦、久保田磨希、',
#              '松島花、趣里、永池南津子、木戸邑弥、',
#              '谷川りさこ、石田登星、田上唯、横山歩、',
#              '藤木直人、美保純、水野美紀、浅野温子 etc',
#              '原作 ： 椎名チカ「37.5℃の涙」',
#              '脚本 ： 梅田みか',
#              'Ｐ ： 渋谷未来、近見哲平',
#              '演出 ： 古澤健、藤尾隆、村上牧人 etc',
#              '主題歌 ： wacci『大丈夫』',
#              '挿入歌 ： 木村カエラ『EGG』'],
#  '37歳で医者になった僕\u3000〜研修医純情物語〜': ['草\ue183剛、水川あさみ、',
#                                 'ミムラ、八乙女光、桐山漣、',
#                                 '鈴木浩介、斎藤工、真飛聖、',
#                                 '田辺誠一、松平健',
#                                 ' etc',
#                                 '原作 ： '
#                                 '川渕圭一「研修医純情物語〜先生と呼ばないで」「ふり返るなドクター〜研修医純情物語」',
#                                 '脚本 ： 古家和尚',
#                                 'Ｐ ： 木村淳',
#                                 '演出 ： 三宅喜重、白木啓一郎 etc',
#                                 '主題歌 ： サカナクション『僕と花』'],
#  '3年A組\u3000−今から皆さんは、人質です−': ['菅田将暉、永野芽郁、',
#                               '片寄涼太、川栄李奈、上白石萌歌、萩原利久、',
#                               '今田美桜、福原遥、神尾楓珠、鈴木仁、',
#                               '望月歩、堀田真由、富田望生、佐久本宝、',
#                               '古川毅、若林時英、森七菜、秋田汐梨、',
#                               '今井悠貴、箭内夢菜、新條由芽、細田善彦、',
#                               '堀田茜、バッファロー吾郎A、神尾佑、土村芳、',
#                               'ベンガル、矢島健一、大友康平、田辺誠一、椎名桔平 etc',
#                               '脚本 ： 武藤将吾',
#                               'チーフＰ ： 西憲彦',
#                               'Ｐ ： 福井雄太、松本明子',
#                               '演出 ： 小室直子、鈴木勇馬、水野格 etc',
#                               '主題歌 ： ザ・クロマニヨンズ『生きる』'],
#  '3年B組金八先生': ['武田鉄矢、星野真里、',
#               '藤澤恵麻、佐野泰臣、瀬川亮、',
#               '山田純大、明星真由美、鈴木正幸、',
#               '山崎銀之丞、浅野和之、森田順平、',
#               '金田明夫、高畑淳子 etc',
#               '原作 ： 小山内美江子',
#               '脚本 ： 清水有生',
#               'Ｐ ： 柳井満',
#               '演出 ： 今井夏木、加藤新、生野慈朗、大岡進 etc',
#               '主題歌 ： 海援隊『いつか見た青い空』'],
#  '4分間のマリーゴールド': ['近日更新。。 etc', '脚本 ： ', 'Ｐ ： ', '演出 ：  etc'],
#  '4姉妹探偵団': ['夏帆、中越典子、',
#             '加藤夏希、市川由衣、吉沢悠、',
#             '生瀬勝久、室井滋 etc',
#             '原作 ： 赤川次郎「三姉妹探偵団」',
#             '脚本 ： 福田卓郎',
#             'チーフＰ ： 桑田潔',
#             'Ｐ ： 横地邦英、奈良井正巳、太田雅晴',
#             '演出 ： 新城毅彦 etc',
#             '主題歌 ： YUI『Namidairo』'],
#  '5→9\u3000〜私に恋したお坊さん〜': ['石原さとみ、山下智久、',
#                           '田中圭、古川雄輝、高梨臨、紗栄子、',
#                           '吉本実憂、長妻怜央、恒松祐里、寺田心、',
#                           '中村アン、速水もこみち、戸田恵子、',
#                           '上島竜兵、小野武彦、加賀まりこ etc',
#                           '原作 ： 相原実貴「5時から9時まで」',
#                           '脚本 ： 小山正太',
#                           'Ｐ ： 後藤博幸、金城綾香',
#                           '演出 ： 平野眞、谷村政樹 etc',
#                           '主題歌 ： back number『クリスマスソング』'],
#  '7人の女弁護士': ['釈由美子、原沙知絵、',
#              '永井大、井上和香、南野陽子、',
#              '川島なお美、柴田理恵、武田航平、',
#              '野際陽子 etc',
#              '脚本 ： 尾崎将也',
#              'チーフＰ ： 五十嵐文朗',
#              'Ｐ ： 横地郁英、布施等、遠田孝一',
#              '演出 ： 塚本連平、今井和之、植田尚 etc',
#              '主題歌 ： AAA『ハリケーン・リリ，ボストン・マリ』'],
#  '87％\u3000−私の5年生存率−': ['夏川結衣、本木雅弘、',
#                         '酒井若菜、橋爪功、 古田新太、',
#                         '杉田かおる、渡辺いっけい、川口翔平、',
#                         '柏原収史、相川七瀬、北川弘美、',
#                         '今井雅之、高橋かおり etc',
#                         '脚本 ： 秦建日子',
#                         'Ｐ ： 伊藤響、大塚泰之、渡邉浩仁',
#                         '演出 ： 長沼誠、梅沢利之、佐久間紀佳 etc',
#                         '主題歌 ： CHEMISTRY『キミがいる』'],
#  '99.9\u3000-刑事専門弁護士- SEASON II': ['松本潤、香川照之、',
#                                    '木村文乃、片桐仁、マギー、馬場園梓、',
#                                    '馬場徹、映美くらら、池田貴史、岸井ゆきの、',
#                                    '渡辺真起子、藤本隆宏、佐藤勝利、甲本雅裕、',
#                                    '笑福亭鶴瓶、岸部一徳 etc',
#                                    '脚本 ： 宇田学',
#                                    'Ｐ ： 瀬戸口克陽、東仲恵吾',
#                                    '演出 ： 木村ひさし、岡本伸吾 etc',
#                                    '主題歌 ： 嵐『Find The Answer』'],
#  '99.9\u3000−刑事専門弁護士−': ['松本潤、香川照之、',
#                          '榮倉奈々、青木崇高、片桐仁、マギー、',
#                          '渡辺真起子、馬場徹、映美くらら、池田貴史、',
#                          '岸井ゆきの、藤本隆宏、奥田瑛二、岸部一徳 etc',
#                          '脚本 ： 宇田学',
#                          'Ｐ ： 瀬戸口克陽、佐野亜裕美',
#                          '演出 ： 木村ひさし、金子文紀、岡本伸吾 etc',
#                          '主題歌 ： 嵐『Daylight』'],
#  'A LIFE\u3000〜愛しき人〜': ['木村拓哉、竹内結子、',
#                         '松山ケンイチ、木村文乃、菜々緒、柄本明、',
#                         '田中泯、小林隆、及川光博、浅野忠信 etc',
#                         '脚本 ： 橋部敦子',
#                         'Ｐ ： 瀬戸口克陽、東仲恵吾',
#                         '演出 ： 平川雄一朗、加藤新、木村ひさし etc',
#                         "主題歌 ： B'z『Still Alive』"],
#  'ATARU': ['中居正広、北村一輝、',
#            '栗山千明、玉森裕太、利重剛、奥貫薫、',
#            '嶋田久作、田中哲司、千原せいじ、中村靖日、',
#            '庄野崎謙、光宗薫、中村昌也、三好博道、',
#            '市村正親、村上弘明 etc',
#            '脚本 ： 櫻井武晴',
#            'Ｐ ： 植田博樹、韓哲',
#            '演出 ： 木村ひさし、吉田健、韓哲 etc',
#            '主題歌 ： 椎名林檎『自由へ道連れ』'],
#  'Answer\u3000警視庁検証捜査官': ['観月ありさ、田辺誠一、',
#                           '五十嵐隼士、橘慶太、眞島秀和、',
#                           '風見しんご、松重豊、片岡鶴太郎 etc',
#                           '脚本 ： 池上純哉、真部千晶',
#                           'チーフＰ ： 佐藤凉一',
#                           'Ｐ ： 三輪祐見子、西勇哉、丸山真哉、大森敬仁',
#                           '演出 ： 猪原達三、長谷川康、田村直己 etc',
#                           '主題歌 ： 三浦大知『Two Hearts』'],
#  'Around40\u3000〜注文の多いオンナたち〜': ['天海祐希、藤木直人、',
#                                 '大塚寧々、筒井道隆、松下由樹、',
#                                 'AKIRA、さくら、林隆三、',
#                                 '加賀まりこ etc',
#                                 '脚本 ： 橋部敦子',
#                                 'Ｐ ： 瀬戸口克陽、\ue2d3成麻畝子',
#                                 '演出 ： 吉田健 etc',
#                                 '主題歌 ： 竹内まりや『幸せのものさし』'],
#  'BG\u3000〜身辺警護人〜': ['木村拓哉、江口洋介、',
#                      '斎藤工、菜々緒、間宮祥太朗、石田ゆり子、',
#                      '上川隆也、満島真之介、阿部進之介、田中奏生、',
#                      '永島敏行、宇梶剛士 etc',
#                      '脚本 ： 井上由美子',
#                      'Ｐ ： 内山聖子、三輪祐見子、川島誠史、秋山貴人、田上リサ',
#                      '演出 ： 常廣丈太、七\ue2d3剛 etc'],
#  'BORDER': ['小栗旬、青木崇高、',
#             '波瑠、遠藤憲一、古田新太、',
#             '滝藤賢一、野間口徹、浜野謙太 etc',
#             '脚本 ： 金城 一紀',
#             'Ｐ ： 山田兼司、太田雅晴',
#             '演出 ： 橋本一、波多野貴文 etc',
#             '主題歌 ： MAN WITH A MISSION『evils fall』'],
#  'BOSS': ['天海祐希、竹野内豊、',
#           '戸田恵梨香、溝端淳平、吉瀬美智子、',
#           'ケンドーコバヤシ、温水洋一、玉山鉄二、',
#           '光石研、相島一之、丸山智己、',
#           '長谷川博己、HILUMA、塩見三省 etc',
#           '脚本 ： 林宏司',
#           'Ｐ ： 村瀬健、三竿玲子',
#           '演出 ： 光野道夫 etc',
#           '主題歌 ： Superfly『Best Of My Life』'],
#  'CAとお呼びっ！': ['観月ありさ、谷原章介、',
#               '香里奈、佐藤江梨子、安田美沙子、',
#               '西田尚美、川原亜矢子、沢村一樹 etc',
#               '原作 ： 花津ハナヨ「CAとお呼びっ！」',
#               '脚本 ： 梅田みか',
#               'Ｐ ： 加藤正俊',
#               '演出 ： 大谷太郎、南雲聖一 etc',
#               '主題歌 ： 中ノ森BAND『Fly High』'],
#  'CHANGE': ['木村拓哉、深津絵里、',
#             '寺尾聰、加藤ローサ、堀内敬子、',
#             '風間杜夫、伊東四朗、中村敦夫、',
#             '神山繁、大林丈史、富司純子、',
#             '阿部寛 etc',
#             '脚本 ： 福田靖',
#             'Ｐ ： 後藤博幸、清水一幸',
#             '演出 ： 澤田鎌作、平野眞 etc',
#             '主題歌 ： Madonna『Miles Away』'],
#  'CHEAT\u3000〜詐欺師の皆さん、ご注意ください〜': ['近日更新。。 etc', '脚本 ： ', 'Ｐ ： ', '演出 ：  etc'],
#  'CONTROL\u3000〜犯罪心理捜査〜': ['松下奈緒、藤木直人、',
#                            '横山裕、北村有起哉、臼田あさ美、',
#                            '佐藤二朗、与座嘉秋、奥村佳恵、',
#                            '勝村政信、泉谷しげる etc',
#                            '脚本 ： 寺田敏雄、田辺満',
#                            'Ｐ ： 貸川聡子',
#                            '演出 ： 村上正典、佐藤源太、城宝秀則 etc',
#                            '主題歌 ： 桑田佳祐『銀河の星屑』'],
#  'CRISIS\u3000公安機動捜査隊特捜班': ['小栗旬、西島秀俊、',
#                             '田中哲司、野間口徹、新木優子、石田ゆり子、',
#                             '飯田基祐、眞島秀和、野崎萌香、長塚京三 etc',
#                             '脚本 ： 金城一紀',
#                             'チーフＰ ： 笠置高弘',
#                             'Ｐ ： 萩原崇',
#                             '演出 ： 鈴木浩介、白木啓一郎 etc',
#                             '主題歌 ： Beverly『I need you love』'],
#  'Chef\u3000〜三ツ星の給食〜': ['天海祐希、小泉孝太郎、',
#                         '川口春奈、荒川良々、池田成志、',
#                         '市川しんぺー、伊藤修子、豊原功補、',
#                         '友近、遠藤憲一 etc',
#                         '脚本 ： 浜田秀哉',
#                         'Ｐ ： 長部聡介、高田雄貴',
#                         '演出 ： 平野眞、田中亮、森脇智延 etc',
#                         '主題歌 ： 松任谷由実『Smile for me』'],
#  'DOCTORS2\u3000最強の名医': ['沢村一樹、高嶋政伸、',
#                          '比嘉愛未、黒川智花、宮地雅子、正名僕蔵、',
#                          '滝沢沙織、敦士、斉藤陽一郎、尾崎右宗、',
#                          '阿南敦子、藤原令子、小野武彦、伊藤蘭、',
#                          '野際陽子 etc',
#                          '脚本 ： 福田靖',
#                          'Ｐ ： 三輪祐見子、松野千鶴子',
#                          '演出 ： 本橋圭太、猪原達三、樹下直美 etc',
#                          "主題歌 ： B'z『ユートピア』"],
#  'DOCTORS3\u3000最強の名医': ['沢村一樹、高嶋政伸、',
#                          '比嘉愛未、黒川智花、宮地雅子、正名僕蔵、',
#                          '滝沢沙織、敦士、斉藤陽一郎、尾崎右宗、',
#                          '阿南敦子、浅利陽介、小野武彦、伊藤蘭、',
#                          '野際陽子 etc',
#                          '脚本 ： 福田靖',
#                          'Ｐ ： 松野千鶴子、神馬由季',
#                          '演出 ： 本橋圭太、常廣丈太 etc',
#                          '主題歌 ： コブクロ『奇跡』'],
#  'DOCTORS\u3000最強の名医': ['沢村一樹、高嶋政伸、',
#                         '比嘉愛未、黒川智花、滝沢沙織、',
#                         '敦士、伊藤蘭、野際陽子、',
#                         '小野武彦、正名僕蔵、斉藤陽一郎、',
#                         '尾崎右宗、宮地雅子、阿南敦子 etc',
#                         '脚本 ： 福田靖',
#                         'チーフＰ ： 黒田徹也',
#                         'Ｐ ： 三輪祐見子、及川博則、松野千鶴子',
#                         '演出 ： 本橋圭太、猪原達三 etc',
#                         '主題歌 ： JUJU『Lullaby Of Birdland』'],
#  'Dr.DMAT': ['大倉忠義、加藤あい、',
#              '瀧本美織、麻生祐未、市川実日子、',
#              '佐藤二朗、ほっしゃん。、松尾諭、',
#              '滝沢沙織、\ue2d3木雄也、左とん平、',
#              '石黒賢、國村隼 etc',
#              '原作 ： \ue2d3野洋・菊地昭夫「Dr.DMAT 〜瓦礫の下のヒポクラテス〜」',
#              '脚本 ： 穴吹一朗、吉澤智子',
#              'Ｐ ： 加藤章一',
#              '演出 ： 倉貫健二郎、松田礼人、堀英樹 etc',
#              '主題歌 ： 関ジャニ∞『ひびき』'],
#  'Dr.コトー診療所': ['吉岡秀隆、柴咲コウ、',
#                '時任三郎、大塚寧々、石田ゆり子、',
#                '千石規子、泉谷しげる、筧利夫、',
#                '小林薫 etc',
#                '原作 ： 山田貴敏',
#                '脚本 ： 吉田紀子',
#                'Ｐ ： 土屋健',
#                '演出 ： 中江功、小林和宏 etc',
#                '主題歌 ： 中島みゆき『銀の龍の背に乗って』'],
#  'Dr.コトー診療所2006': ['吉岡秀隆、柴咲コウ、',
#                    '時任三郎、大塚寧々、蒼井優、',
#                    '堺雅人、泉谷しげる、筧利夫、',
#                    '小林薫 etc',
#                    '原作 ： 山田貴敏「Dｒ．コトー診療所」',
#                    '脚本 ： 吉田紀子',
#                    'Ｐ ： 中江功、増本淳、塚田洋子',
#                    '演出 ： 中江功、平井秀樹、高木健太郎 etc',
#                    '主題歌 ： 中島みゆき『銀の龍の背に乗って』'],
#  'Dr.伊良部一郎': ['徳重聡、余貴美子、',
#               '原幹恵 etc',
#               '原作 ： 奥田英朗「イン・ザ・プール」「空中ブランコ」「町長選挙」',
#               '脚本 ： 八津弘幸',
#               'Ｐ ： 船津浩一、里内英司、松井洋子',
#               '演出 ： \ue2d3橋伸之 etc',
#               '主題歌 ： Not yet『週末Not yet』'],
#  'Dr.倫太郎': ['堺雅人、蒼井優、',
#             '吉瀬美智子、内田有紀、高梨臨、高橋一生、',
#             '真飛聖、中西美帆、余貴美子、遠藤憲一、',
#             '酒井若菜、長塚圭史、松重豊、石橋蓮司、',
#             '高畑淳子、小日向文世 etc',
#             '脚本 ： 中園ミホ',
#             'チーフＰ ： 神蔵克',
#             'Ｐ ： 次屋尚、大塚英治',
#             '演出 ： 水田伸生、相沢淳 etc'],
#  'FACE MAKER': ['永井大、日向千歩 etc',
#                 '脚本 ： 荒井修子、高山直也、田中眞一、田辺茂範',
#                 'チーフＰ ： 堀口良則',
#                 'Ｐ ： 尼子大介、遠田孝、山本喜彦',
#                 '演出 ： 植田尚、大塚徹、二宮浩行 etc',
#                 '主題歌 ： 阪井あゆみ『幸せのルール』'],
#  'FINAL CUT': ['亀梨和也、藤木直人、',
#                '栗山千明、橋本環奈、林遣都、\ue2d3木雄也、',
#                'やついいちろう、杉本哲太、裕木奈江、',
#                '鶴見辰吾、升毅、水野美紀、佐々木蔵之介 etc',
#                '脚本 ： 金子ありさ',
#                'Ｐ ： 豊福陽子',
#                '演出 ： 三宅喜重、日暮謙 etc',
#                '主題歌 ： KAT-TUN『Ask Yourself』'],
#  'GM\u3000踊れドクター': ['東山紀之、多部未華子、',
#                     '生瀬勝久、大倉忠義、吉沢悠、',
#                     '大和田伸也、八嶋智人、小池栄子、',
#                     '椎名桔平 etc',
#                     '脚本 ： 林宏司',
#                     'Ｐ ： 鈴木早苗、飯田和孝',
#                     '演出 ： 武藤淳、生野慈朗、渡瀬暁彦 etc'],
#  'GOLD': ['天海祐希、長澤まさみ、',
#           '水上剣星、松坂桃李、矢野聖人、',
#           '武井咲、大江駿輔、エド・はるみ、',
#           '綾野剛、志賀廣太郎、賀来千香子、',
#           '寺島進、夏八木勲、反町隆史 etc',
#           '脚本 ： 野島伸司',
#           'Ｐ ： 東康之',
#           '演出 ： 河毛俊作、加藤裕将 etc',
#           '主題歌 ： Superfly『Wildflower』'],
#  'GOOD LUCK!!': ['木村拓哉、堤真一、',
#                  '柴咲コウ、内山理名、ユンソナ、',
#                  '加藤貴子、要潤、市川実和子、',
#                  '安住紳一郎、中尾明慶、竹中直人、',
#                  'いかりや長介、段田安則、黒木瞳 etc',
#                  '脚本 ： 井上由美子',
#                  'Ｐ ： 植田博樹、瀬戸口克',
#                  '演出 ： 土井裕泰、福澤克雄、平野俊一 etc',
#                  '主題歌 ： 山下達郎『RIDE ON TIME』'],
#  'GTO': ['AKIRA、瀧本美織、',
#          '山本裕典、川口春奈、高田翔、森本慎太郎、',
#          '西内まりや、本田翼、宮崎香蓮、白濱亜嵐、',
#          '中川大志、山田裕貴、鈴木伸之、佐野岳、',
#          '高月彩良、高良光莉、新川優愛、高知東生、',
#          '滝沢沙織、矢野聖人、ふせえり、田山涼成、',
#          '城田優、黒木瞳 etc',
#          '原作 ： 藤沢とおる「GTO」「GTO SYONAN 14DAYS」',
#          '脚本 ： 深沢正樹',
#          'Ｐ ： 河西秀幸、山本喜彦',
#          '演出 ： 今井和久 etc',
#          '主題歌 ： EXILE TRIBE『24karats TRIBE OF GOLD』'],
#  'G線上のあなたと私': ['近日更新。。 etc', '脚本 ： ', 'Ｐ ： ', '演出 ：  etc'],
#  'H2\u3000〜君といた日々': ['山田孝之、石原さとみ、',
#                      '田中幸太朗、市川由衣、石垣佑磨、',
#                      '中尾明慶、北条隆博、的場浩司、',
#                      '田丸麻紀、柳沢慎吾、石野真子、',
#                      '七瀬なつみ、杉本哲太、竜雷太 etc',
#                      '原作 ： あだち充「H2」',
#                      '脚本 ： 関えり香、山崎淳也',
#                      'Ｐ ： 市山竜次',
#                      '演出 ： 堤幸彦、今井夏木、鬼頭理三、丸毛典子 etc',
#                      '主題歌 ： K『over...』'],
#  'HEAT': ['AKIRA、栗山千明、',
#           '佐藤隆太、田中圭、菜々緒、',
#           '工藤阿須加、鈴木伸之、吉沢亮、',
#           '井出卓也、小芝風花、堀内敬子、',
#           '正名僕蔵、菅原大吉、稲垣吾郎 etc',
#           '脚本 ： 丑尾健太郎、大浦光太、坪田文',
#           'チーフＰ ： 笠置高弘',
#           'Ｐ ： 萩原崇、豊福陽子、岩田祐二、柳川由起子',
#           '演出 ： 小林義則、佐藤源太 etc',
#           '主題歌 ： EXILE ATSUSHI + AI『Be Brave』'],
#  'HERO': ['木村拓哉、北川景子、',
#           '杉本哲太、濱田岳、正名僕蔵、吉田羊、',
#           '田中要次、勝矢、松重豊、八嶋智人、',
#           '小日向文世、角野卓造 etc',
#           '脚本 ： 福田靖',
#           'Ｐ ： 渡辺恒也',
#           '演出 ： 鈴木雅之、平野眞、金井紘 etc'],
#  'HOPE\u3000〜期待ゼロの新入社員〜': ['中島裕翔、遠藤憲一、',
#                            '瀬戸康史、山本美月、桐山照史、マギー、',
#                            '中村ゆり、丸山智己、松田賢二、松澤一之、',
#                            '遠山俊也、矢柴俊博、桜田通、加治将樹、',
#                            '渡辺邦斗、山内圭哉、朝加真由美、風間杜夫 etc',
#                            '原作 ： 「ミセン-未生-」',
#                            '脚本 ： 徳永友一',
#                            'Ｐ ： 高丸雅隆',
#                            '演出 ： 河野圭太、城宝秀則 etc',
#                            '主題歌 ： スピッツ『コメット』'],
#  'HUNTER\u3000〜その女たち、賞金稼ぎ〜': ['米倉涼子、谷原章介、',
#                               '桐谷美玲、堀内敬子、小泉孝太郎、',
#                               '川島鈴遥、原幹恵、齋藤めぐみ、',
#                               '佐伯大地、山口紗弥加、戸田恵子、',
#                               '柄本明 etc',
#                               '脚本 ： 伴一彦',
#                               'Ｐ ： 河西秀幸、後藤勝利、川西琢',
#                               '演出 ： 村上正典、佐藤源太、白木啓一郎 etc',
#                               '主題歌 ： 倉木麻衣『Strong Heart』'],
#  'Heaven？\u3000〜ご苦楽レストラン〜': ['石原さとみ、福士蒼汰、',
#                              '志尊淳、田口浩正、内田慈、大重わたる、',
#                              '松本ししまる、勝村政信、矢柴俊博、上田遥、',
#                              '舘ひろし、段田安則、岸部一徳 etc',
#                              '原作 ： 佐々木倫子「Heaven？ ご苦楽レストラン」',
#                              '脚本 ： 吉田恵里香',
#                              'Ｐ ： 瀬戸口克陽',
#                              '演出 ： 木村ひさし etc',
#                              '主題歌 ： あいみょん『真夏の夜の匂いがする』'],
#  'IQ246\u3000〜華麗なる事件簿〜': ['織田裕二、土屋太鳳、',
#                           'ディーン・フジオカ、宮尾俊太郎、真飛聖、',
#                           '新川優愛、矢野聖人、篠井英介、',
#                           '寺島進、中谷美紀 etc',
#                           '脚本 ： 泉澤陽子、栗本志津香、原涼子',
#                           'Ｐ ： 植田博樹',
#                           '演出 ： 木村ひさし、坪井敏雄、韓哲 etc'],
#  'JIN -仁-': ['大沢たかお、綾瀬はるか、',
#              '中谷美紀、内野聖陽、小出恵介、',
#              '桐谷健太、藤本隆宏、市村正親、',
#              '中村敦夫、佐藤隆太、市川亀治郎、',
#              '麻生祐未、小日向文世 etc',
#              '原作 ： 村上もとか「JIN -仁-」',
#              '脚本 ： 森下佳子',
#              'Ｐ ： 石丸彰彦、中井芳彦',
#              '演出 ： 平川雄一朗、山室大輔、那須田淳 etc',
#              '主題歌 ： 平井堅『いとしき日々よ』'],
#  'JIN -仁- ': ['大沢たかお、中谷美紀、',
#               '綾瀬はるか、小出恵介、桐谷健太、',
#               '田口浩正、戸田菜穂、武田鉄矢、',
#               '藤田まこと、高岡早紀、六平直政、',
#               '麻生祐未、小日向文世、内野聖陽 etc',
#               '原作 ： 村上もとか「JIN -仁-」',
#               '脚本 ： 森下佳子',
#               'Ｐ ： 石丸彰彦、津留正明',
#               '演出 ： 平川雄一朗、山室大輔、川嶋龍太郎 etc',
#               '主題歌 ： MISIA『逢いたくていま』'],
#  'JOKER\u3000ジョーカー許されざる捜査官': ['堺雅人、錦戸亮、',
#                               '杏、平山浩行、りょう、',
#                               '大杉漣、鹿賀丈史 etc',
#                               '脚本 ： 武藤将吾',
#                               'Ｐ ： 稲田秀樹、永井麗子',
#                               '演出 ： 土方政人、都築淳一、石川淳一 etc'],
#  'LADY\u3000〜最後の犯罪プロファイル〜': ['北川景子、木村多江、',
#                              '平岡祐太、須藤理彩、小澤征悦、',
#                              '要潤、ユースケ・サンタマリア etc',
#                              '脚本 ： 荒井修子、渡辺雄介、徳永友一',
#                              'Ｐ ： 津留正明、渡辺良介',
#                              '演出 ： 平野俊一、山本剛義 etc',
#                              '主題歌 ： 柴咲コウ『無形スピリット』'],
#  'LAST HOPE\u3000ラストホープ': ['相葉雅紀、多部未華子、',
#                            '田辺誠一、小池栄子、北村有起哉、',
#                            '桜庭ななみ、平田満、\ue2d3嶋政宏、',
#                            '小日向文世 etc',
#                            '脚本 ： 浜田秀哉',
#                            'Ｐ ： 成河広明、古屋建自',
#                            '演出 ： 葉山裕記、石井祐介、谷村政樹 etc',
#                            '主題歌 ： 嵐『Calling』'],
#  'LIAR GAME': ['戸田恵梨香、松田翔太、',
#                '渡辺いっけい、吉瀬美智子、福井友信、',
#                '北村総一朗 etc',
#                '原作 ： 甲斐谷忍「LIAR GAME」',
#                '脚本 ： 古家和尚',
#                'Ｐ ： 志牟田徹',
#                '演出 ： 松山博昭、大木綾子 etc'],
#  'LOVE GAME': ['釈由美子、',
#                '塩谷瞬、北川弘美、井上和香、牧田哲也、',
#                '鈴木亜美、中村ゆり、さとう珠緒、山口賢貴、',
#                '市川由衣、與真司郎、青山倫子、竹財輝之助 etc',
#                '原作 ： 安達元一「LOVE GAME」',
#                '脚本 ： 岩村匡子、村上直美、若生恵美子',
#                'チーフＰ ： 田中壽一',
#                'Ｐ ： 竹綱裕博、森川真行',
#                '演出 ： 岡本浩一、伊藤寿浩、石川北二 etc',
#                '主題歌 ： 鍵山由佳『Love player』'],
#  'MONSTERS': ['香取慎吾、山下智久、',
#               '柳原可奈子、蕨野友也、菊田大輔、',
#               '肥野竜也、白石朋也、日中泰景、',
#               '大竹まこと、遠藤憲一 etc',
#               '脚本 ： 蒔田光治',
#               'Ｐ ： 石丸彰彦、高橋正尚、阿部謙三',
#               '演出 ： 福澤克雄、平野俊一、大澤祐樹 etc',
#               '主題歌 ： The MONSTERS『MONSTERS』'],
#  'MOZU\u3000Season1 〜百舌の叫ぶ夜〜': ['西島秀俊、香川照之、',
#                                 '真木よう子、生瀬勝久、吉田鋼太郎、伊藤淳史、',
#                                 '有村架純、池松壮亮、奥貫薫、戸田昌宏、',
#                                 '鶴見辰吾、染谷将太、田口浩正、田中要次、',
#                                 '堀内敬子、杉咲花、音月桂、阿部力、',
#                                 '瑳川哲朗、品川徹、長谷川博己、石田ゆり子、',
#                                 '小日向文世 etc',
#                                 '原作 ： 逢坂剛「百舌の叫ぶ夜」「幻の翼」',
#                                 '脚本 ： 仁志光佑',
#                                 'Ｐ ： 渡辺信也、井上衛、森井輝',
#                                 '演出 ： 羽住英一郎 etc'],
#  'MOZU\u3000Season2 〜幻の翼〜': ['西島秀俊、香川照之、',
#                              '真木よう子、池松壮亮、伊藤淳史、長谷川博己、',
#                              '石田ゆり子、小日向文世、蒼井優、佐野史郎 etc',
#                              '原作 ： 逢坂剛「百舌の叫ぶ夜」「幻の翼」',
#                              '脚本 ： 仁志光佑',
#                              'Ｐ ： 渡辺信也、井上衛、森井輝',
#                              '演出 ： 羽住英一郎 etc'],
#  'MR.BRAIN': ['木村拓哉、綾瀬はるか、',
#               '水嶋ヒロ、平泉成、設楽統、',
#               '山崎樹範、SHIHO、木下優樹菜、',
#               '井坂俊哉、林泰文、小林克也、',
#               '田中裕二、トータス松本、大地真央、',
#               '香川照之 etc',
#               '脚本 ： 蒔田光治',
#               'Ｐ ： 石丸彰彦、伊與田英徳',
#               '演出 ： 福澤克雄、平川雄一朗、山室大輔 etc'],
#  'Missデビル\u3000人事の悪魔・椿眞子': ['菜々緒、佐藤勝利、',
#                             '木村佳乃、和田正人、白石聖、モロ師岡、',
#                             '水沢エレナ、山田キヌヲ、前田航基、山本直寛、',
#                             '猪野学、瀬戸さおり、関屋利歩、山下容莉枝、',
#                             '鶴見辰吾、船越英一郎、西田敏行 etc',
#                             '脚本 ： 山浦雅大、藤平久子',
#                             'チーフＰ ： 福士睦',
#                             'Ｐ ： 森雅弘、本多繁勝',
#                             '演出 ： 佐久間紀佳、小室直子 etc',
#                             '主題歌 ： 安室奈美恵『Body Feels EXIT』'],
#  'Mother': ['松雪泰子、山本耕史、',
#             '酒井若菜、倉科カナ、芦田愛菜、',
#             '尾野真千子、川村陽介、市川実和子、',
#             '音尾琢真、田中実、綾野剛、',
#             '高畑淳子、田中裕子 etc',
#             '脚本 ： 坂元裕二',
#             'チーフＰ ： 田中芳樹',
#             'Ｐ ： 次屋尚、千葉行利',
#             '演出 ： 水田伸生、長沼誠 etc',
#             '主題歌 ： hinaco『泣き顔スマイル』'],
#  'Mの悲劇': ['稲垣吾郎、長谷川京子、',
#           '佐々木蔵之介、岡本綾、吉岡美穂、',
#           '柏原収史、大西滝次郎、浅見れいな、',
#           '井澤健、佐藤二朗、成宮寛貴、',
#           '吉行和子、伊武雅刀 etc',
#           '脚本 ： 橋本裕志',
#           'Ｐ ： 伊佐野英樹、瀬戸口克陽',
#           '演出 ： 土井裕泰、石井康晴、山室大輔、川嶋龍太郎 etc',
#           '主題歌 ： Sister Q『Night and Day』'],
#  "Ns'あおい": ['石原さとみ、柳葉敏郎、',
#             '杉田かおる、八嶋智人、小山慶一郎、高橋ひとみ、',
#             '小野武彦、佐戸井けん太、西村雅彦、片平なぎさ、',
#             '鈴木浩介、載寧龍二、加藤貴子、大村美樹、',
#             '高樹マリア、六角精児、平賀雅臣、矢柴俊博 etc',
#             '原作 ： こしのりょう「Nｓ’あおい」',
#             '脚本 ： 吉田智子',
#             'Ｐ ： 小椋久雄、永井麗子',
#             '演出 ： 土方政人、都築淳一、石川淳一 etc',
#             '主題歌 ： コブクロ『桜』',
#             'OP曲 ： オオゼキタク『Destination』'],
#  'Nのために': ['榮倉奈々、窪田正孝、',
#            '賀来賢人、小出恵介、原日出子、柴本幸、',
#            'モロ師岡、美保純、葉山奨之、光石研、',
#            '山本未來、織本順吉、徳井義実、小西真奈美、',
#            '三浦友和 etc',
#            '原作 ： 湊かなえ「Nのために」',
#            '脚本 ： 奥寺佐渡子',
#            'Ｐ ： 新井順子',
#            '演出 ： 塚原あゆ子、山本剛義 etc',
#            '主題歌 ： 家入レオ『Silly』'],
#  'OLにっぽん': ['観月ありさ、阿部サダヲ、',
#             '美波、井上芳雄、東幹久、',
#             '浅野ゆう子、モロ師岡、前田知恵、',
#             '皆川猿時、宮地真緒、稲葉さゆり、',
#             '秋田真琴、ローラ・チャン etc',
#             '脚本 ： 中園ミホ',
#             'Ｐ ： 西憲彦、渡邉浩仁',
#             '演出 ： 岩本仁志、大谷太郎、本間美由紀 etc',
#             '主題歌 ： SPEED『あしたの空』'],
#  'ON\u3000異常犯罪捜査官・藤堂比奈子': ['波瑠、横山裕、',
#                            '要潤、高橋努、斉藤慎二、百瀬朔、',
#                            '佐藤玲、林遣都、奥貫薫、光石研、',
#                            '原田美枝子、渡部篤郎 etc',
#                            '原作 ： 内藤了「猟奇犯罪捜査班・藤堂比奈子」',
#                            '脚本 ： 古家和尚',
#                            'Ｐ ： 河西秀幸、萩原崇、石田麻衣',
#                            '演出 ： 白木啓一郎、宝来忠昭 etc',
#                            '主題歌 ： [Alexandros]『Swan』'],
#  'OUR HOUSE': ['芦田愛菜、シャーロット・ケイト・フォックス、',
#                '山本耕史、加藤清史郎、寺田心、松田芹香、',
#                '高山善廣、渡辺舞、犬飼貴丈、塚本高史、',
#                '松下由樹、橋爪功 etc',
#                '脚本 ： 野島伸司',
#                'Ｐ ： 太田大、高田雄貴',
#                '演出 ： 永山耕三、澤田鎌作、加藤裕将 etc',
#                '主題歌 ： オフコース『愛を止めないで』'],
#  'Oh, My Dad!!': ['織田裕二、田中奏生、',
#                   '長谷川京子、八嶋智人、鈴木杏樹 etc',
#                   '脚本 ： 安達奈緒子',
#                   'Ｐ ： 増本淳',
#                   '演出 ： 河野圭太、葉山裕記、加藤裕将 etc',
#                   '主題歌 ： GReeeeN『愛し君へ』'],
#  'PRICELESS\u3000〜あるわけねぇだろ、んなもん！〜': ['木村拓哉、中井貴一、',
#                                      '香里奈、藤ヶ谷太輔、蓮佛美沙子、',
#                                      '升毅、前田旺志郎、田中奏生、',
#                                      '中村敦夫、イッセー尾形、夏木マリ、',
#                                      '藤木直人 etc',
#                                      '脚本 ： 古家和尚',
#                                      'Ｐ ： 牧野正、村瀬健',
#                                      '演出 ： 鈴木雅之、平野眞 etc',
#                                      "主題歌 ： The Rolling Stones『Jumping' Jack "
#                                      'Flash』'],
#  'Q10': ['佐藤健、前田敦子、',
#          '蓮佛美沙子、賀来賢人、柄本時生、',
#          '高畑充希、細田よしひこ、福田麻由子、',
#          '光石研、西田尚美、松岡璃奈子、',
#          '池松壮亮、白石加代子、田中裕二、',
#          '小野武彦、薬師丸ひろ子 etc',
#          '脚本 ： 木皿泉',
#          'Ｐ ： 河野英裕、小泉守',
#          '演出 ： 狩山俊輔、佐久間紀佳 etc',
#          '主題歌 ： 高橋優『ほんとのきもち』'],
#  'RESCUE〜特別高度救助隊': ['中丸雄一、増田貴久、',
#                     '山本裕典、石黒英雄、大東俊介、',
#                     '浅利陽介、加治将樹、山田親太朗、',
#                     '市川由衣、笛木優子、西原亜希、',
#                     '橋本真実、田中要次、照英、',
#                     '高橋洋、佐藤二朗、矢島健一、',
#                     '山下真司、夏八木勲、石橋凌、',
#                     '要潤、石黒賢 etc',
#                     '脚本 ： 山浦雅大、八津弘幸',
#                     'Ｐ ： 加藤章一、佐藤敦司',
#                     '演出 ： 倉貫健二郎、松田礼人 etc',
#                     '主題歌 ： KAT-TUN『RESCUE』'],
#  'RESET': ['田中直樹、安めぐみ、',
#            '松山愛里、桐山漣 etc',
#            '原作 ： 山本まゆり「リセット」',
#            '脚本 ： 古賀直樹',
#            'チーフＰ ： 堀口良則',
#            'Ｐ ： 尼子大介、片岡秀介',
#            '演出 ： 白川士 etc',
#            '主題歌 ： 二千花『リバーズエッジ』'],
#  'ROOKIES': ['佐藤隆太、市原隼人、',
#              '小出恵介、城田優、中尾明慶、',
#              '高岡蒼甫、桐谷健太、佐藤健、',
#              '五十嵐隼士、川村陽介、尾上寛之、',
#              '村川絵梨、浅野和之、吹石一恵、',
#              '天野ひろゆき、伊武雅刀、能世あんな、',
#              '升田尚宏、森山未來、綾瀬はるか etc',
#              '原作 ： 森田まさのり「ROOKIES」',
#              '脚本 ： いずみ吉絋',
#              'Ｐ ： 津留正明',
#              '演出 ： 平川雄一朗 etc',
#              '主題歌 ： GreeeeN『キセキ』'],
#  'Room Of King': ['水嶋ヒロ、鈴木杏、',
#                   '井川遥、板尾創路、斉木しげる、',
#                   '我修院達也、ミッキー・カーチス、渡部篤郎 etc',
#                   '脚本 ： 大宮エリー',
#                   'Ｐ ： 中島久美子',
#                   '演出 ： 大宮エリー、大木綾子 etc',
#                   '主題歌 ： キマグレン『愛NEED』'],
#  'S -最後の警官-': ['向井理、綾野剛、',
#                '吹石一恵、池内博之、平山浩行、',
#                '高橋努、平山祐介、本宮泰風、',
#                '淵上泰史、\ue2d3嶋政宏、近藤正臣、',
#                '大森南朋 etc',
#                '原作 ： 小森陽一・藤堂裕「S -最後の警官-」',
#                '脚本 ： 古家和尚',
#                'Ｐ ： 韓哲',
#                '演出 ： 平野俊一、石井康晴 etc',
#                '主題歌 ： MISIA『僕はペガサス 君はポラリス』'],
#  'SAKURA\u3000〜事件を聞く女〜': ['仲間由紀恵、佐藤隆太、',
#                           '相島一之、木野花、大野拓朗、森岡豊、',
#                           '駿河太郎、文音、茅島成美、不破万作、',
#                           '山野史人、飯沼千恵子、上間美緒、',
#                           '草笛光子、高島礼子 etc',
#                           '脚本 ： 松本美弥子、山岡潤平',
#                           'Ｐ ： 志村彰、関川友理',
#                           '演出 ： 鈴木浩介、水村秀雄、加藤新 etc',
#                           '主題歌 ： Aqua Timez『生きて』'],
#  'SCANDAL': ['鈴木京香、長谷川京子、',
#              '吹石一恵、桃井かおり、沢村一樹、',
#              '光石研、遠藤憲一、石原良純、',
#              '戸田菜穂、加藤虎ノ介、植田浩望、',
#              '細田よしひこ、小日向文世 etc',
#              '脚本 ： 井上由美子',
#              'Ｐ ： 生野慈朗、植田博樹',
#              '演出 ： 生野慈朗、\ue2d3成麻畝子、山本剛義 etc'],
#  'SMOKING GUN\u3000〜決定的証拠〜': ['香取慎吾、西内まりや、',
#                               '中山優馬、安藤玉恵、濱田ここね、',
#                               '鈴木保奈美、倉科カナ、イッセー尾形、',
#                               '谷原章介 etc',
#                               '原作 ： 横幕智裕・竹谷州史「Smoking Gun 民間科捜研調査員 流田縁」',
#                               '脚本 ： 酒井雅秋',
#                               'Ｐ ： 森安彩、伊賀宣子',
#                               '演出 ： 村上正典、佐藤源太 etc',
#                               "主題歌 ： N'夙川BOYS『ジーザスフレンド』"],
#  'SPEC\u3000〜警視庁公安部公安第五課 未詳事件特別対策係事件簿〜': ['戸田恵梨香、加瀬亮、',
#                                           '福田沙紀、徳井優、安田顕、',
#                                           '田中哲司、城田優、岡田浩暉、',
#                                           '松澤一之、載寧龍二、有村架純、',
#                                           '伊藤毅、神木隆之介、椎名桔平、',
#                                           '竜雷太 etc',
#                                           '脚本 ： 西荻弓絵',
#                                           'Ｐ ： 植田博樹、今井夏木、赤羽智比呂',
#                                           '演出 ： 堤幸彦、加藤新、今井夏木、金子文紀 etc',
#                                           '主題歌 ： The '
#                                           'Ricecookers『NAMInoYUKUSAKI』'],
#  'SP\u3000警視庁警備部警護課第四係': ['岡田准一、真木よう子、',
#                           '松尾諭、神尾佑、山本圭、',
#                           '平田満、堤真一 etc',
#                           '脚本 ： 金城一紀',
#                           'Ｐ ： 高井一郎',
#                           '演出 ： 本広克行 etc',
#                           '主題歌 ： V6『way of life』'],
#  'STAND UP!!': ['二宮和也、山下智久、',
#                 '鈴木杏、成宮寛貴、小栗旬、',
#                 '釈由美子、的場浩司、加藤貴子、',
#                 '松本莉緒、塚本高史、ベッキー、',
#                 '西田尚美、杉田かおる、酒井敏也、',
#                 '清水章吾、段田安則、片平なぎさ etc',
#                 '脚本 ： 金子ありさ',
#                 'Ｐ ： 石丸彰彦',
#                 '演出 ： 堤幸彦、加藤新 etc',
#                 '主題歌 ： 嵐『言葉より大切なもの』'],
#  'ST\u3000赤と白の捜査ファイル': ['藤原竜也、岡田将生、',
#                         '志田未来、芦名星、窪田正孝、三宅弘城、',
#                         '柴本幸、水上剣星、田中哲司、林遣都、',
#                         '瀬戸朝香、渡部篤郎 etc',
#                         '原作 ： 今野敏「ST警視庁科学特捜班」',
#                         '脚本 ： 渡辺雄介',
#                         'チーフＰ ： 伊藤響',
#                         'Ｐ ： 森雅弘',
#                         '演出 ： 佐藤東弥、長沼誠、山下学美 etc',
#                         '主題歌 ： ファンキー加藤『太陽』'],
#  'SUITS／スーツ': ['織田裕二、中島裕翔、',
#                '新木優子、中村アン、磯村勇斗、今田美桜、',
#                '國村隼、田島令子、小手伸也、鈴木保奈美 etc',
#                '原作 ： 「Suits」',
#                '脚本 ： 池上純哉',
#                'Ｐ ： 後藤博幸、小林宙',
#                '演出 ： 土方政人、石井祐介 etc',
#                "主題歌 ： B'z『WOLF』"],
#  'SUMMER NUDE': ['山下智久、香里奈、',
#                  '戸田恵梨香、勝地涼、窪田正孝、',
#                  '佐藤勝利、山本美月、千葉雄大、',
#                  '橋本奈々未、中条あやみ、長澤まさみ、',
#                  '斉木しげる、板谷由夏、高橋克典 etc',
#                  '脚本 ： 金子茂樹',
#                  'Ｐ ： 村瀬健',
#                  '演出 ： 石井祐介、宮木正悟、金井紘 etc',
#                  "主題歌 ： 山下智久『SUMMER NUDE'13』"],
#  'TAKE FIVE\u3000〜俺たちは愛を盗めるか〜': ['唐沢寿明、松雪泰子、',
#                                  '松坂桃李、六角精児、入江甚儀、',
#                                  '千葉雄大、福田彩乃、江田結香、',
#                                  '阿部進之介、駿河太郎、でんでん、',
#                                  'JUJU、倍賞美津子、稲垣吾郎 etc',
#                                  '脚本 ： 藤井清美、丑尾健太郎',
#                                  'Ｐ ： 伊與田英徳',
#                                  '演出 ： 岡本伸吾、渡瀬暁彦、川嶋龍太郎 etc',
#                                  '主題歌 ： 2PM『GIVE ME LOVE』'],
#  'TEAM\u3000警視庁特別犯罪捜査本部': ['小澤征悦、田辺誠一、',
#                            '塚本高史、神尾佑、田中隆三、',
#                            '猪野学、篠田光亮、渡辺いっけい、',
#                            '西田敏行 etc',
#                            '脚本 ： 吉本昌弘',
#                            'Ｐ ： 藤本一彦、金丸哲也、和佐野健一',
#                            '演出 ： 猪崎宣昭、新村良二 etc',
#                            '主題歌 ： 加藤ミリヤ×清水翔太『ESCAPE』'],
#  'THE LAST COP\u3000ラストコップ': ['唐沢寿明、窪田正孝、',
#                               '佐々木希、黒川智花、竹内涼真、松尾諭、',
#                               '桜井日奈子、武田玲奈、伊藤沙莉、藤木直人、',
#                               '田山涼成、マギー、宮川一朗太、小日向文世、',
#                               '和久井映見 etc',
#                               '原作 ： 「DER LETZTE BULLE」',
#                               '脚本 ： 佐藤友治',
#                               'チーフＰ ： 伊藤響',
#                               'Ｐ ： 戸田一也、伊藤裕史、松山雅則',
#                               '演出 ： 猪股隆一、佐久間紀佳、明石広人、長沼誠 etc',
#                               '主題歌 ： BLUE ENCOUNT『LAST HERO』'],
#  'TOKYOエアポート\u3000〜東京空港管制保安部〜': ['深田恭子、佐々木希、',
#                                  '要潤、瀬戸康史、佐藤江梨子、',
#                                  '山口紗弥加、野波麻帆、浅香航大、',
#                                  '平岡祐太、瀬戸朝香、別所哲也、',
#                                  '梶原善、時任三郎 etc',
#                                  '脚本 ： 宇田学',
#                                  'Ｐ ： 長部聡介、関口大輔',
#                                  '演出 ： 西坂瑞城、長瀬国博 etc',
#                                  '劇中歌 ： THE 5TH DIMENSION『UP,UP AND AWAY』'],
#  'TWO WEEKS': ['三浦春馬、芳根京子、',
#                '比嘉愛未、三浦貴大、稲垣来泉、近藤公園、',
#                '鈴木仁、バッファロー吾郎A、神尾佑、',
#                '久保田悠来、磯村勇斗、原沙知絵、池田鉄洋、',
#                '高嶋政伸、黒木瞳 etc',
#                '原作 ： ソ・ヒョンギョン「TWO WEEKS」',
#                '脚本 ： 山浦雅大',
#                'Ｐ ： 岡光寛子、白石裕菜、平部隆明',
#                '演出 ： 本橋圭太、木内健人 etc',
#                '主題歌 ： 三浦春馬『Fight for your heart』',
#                'OP曲 ： 04 Limited Sazabys『Montage』'],
#  'Tomorrow': ['竹野内豊、菅野美穂、',
#               '緒川たまき、黒川智花、エド・はるみ、',
#               '永田彬、橋本真実、有村実樹、',
#               '秋田真琴、沢木ルカ、氏家恵、',
#               '村松利史、六角慎司、田中実、',
#               '志賀廣太郎、大沢あかね、松田美由紀、',
#               '永島暎子、陣内孝則、岸部一徳 etc',
#               '脚本 ： 篠\ue1cc絵里子',
#               'Ｐ ： 伊與田英徳、正木敦',
#               '演出 ： 山室大輔、川嶋龍太郎、韓哲 etc',
#               '主題歌 ： 星村麻衣『ひかり』'],
#  'VISION -殺しが見える女-': ['山田優、金子ノブアキ、',
#                       '勝村政信、矢柴俊博、吉家章人、',
#                       '安倍康律、コトウロレナ、麻倉みな etc',
#                       '脚本 ： 飯田譲治',
#                       'チーフＰ ： 堀口良則',
#                       'Ｐ ： 尼子大介、遠田孝一、浅井千端',
#                       '演出 ： 星野和成、植田尚 etc',
#                       '主題歌 ： CREAM『RUNAWAY』'],
#  'Woman': ['満島ひかり、田中裕子、',
#            '小栗旬、谷村美月、二階堂ふみ、',
#            '三浦貴大、臼田あさ美、高橋一生、',
#            '鈴木梨央、\ue2d3橋來、小林薫 etc',
#            '脚本 ： 坂元裕二',
#            'チーフＰ ： 大平太',
#            'Ｐ ： 次屋尚、千葉行利、大塚英冶',
#            '演出 ： 水田伸生、相沢淳 etc',
#            '主題歌 ： androp『Voice』'],
#  'Wの悲劇': ['武井咲、桐谷健太、',
#           '松下由樹、福田沙紀、剛力彩芽、森田彩華、',
#           '昆夏美、寺田農、野際陽子、若村麻由美、',
#           '中村俊介、武田航平、金田明夫、高橋一生、',
#           '広岡由里子 etc',
#           '原作 ： 夏樹静子「Ｗの悲劇」',
#           '脚本 ： 寺田敏雄',
#           'Ｐ ： 飯田爽、清水真由美',
#           '演出 ： 片山修、植田尚、常廣丈太 etc',
#           '主題歌 ： 平井堅『告白』'],
#  'anego\u3000〜アネゴ〜': ['篠原涼子、ともさかりえ、',
#                       '赤西仁、戸田菜穂、市川実和子、',
#                       '山口紗弥加、小西美帆、升毅、',
#                       '加藤雅也、由紀さおり etc',
#                       '原作 ： 林真理子「anego」',
#                       '脚本 ： 中園ミホ',
#                       'Ｐ ： 櫨山裕子、 内山雅博',
#                       '演出 ： 吉野洋、南雲聖一、佐久間紀佳 etc',
#                       '主題歌 ： 北出菜奈『KISS or KISS』'],
#  'anone': ['広瀬すず、小林聡美、',
#            '阿部サダヲ、瑛太、火野正平、',
#            '田中裕子 etc',
#            '脚本 ： 坂元裕二',
#            'チーフＰ ： 西憲彦',
#            'Ｐ ： 次屋尚',
#            '演出 ： 水田伸生 etc'],
#  'dele': ['菅田将暉、山田孝之、',
#           '麻生久美子 etc',
#           '脚本 ： 本多孝好、金城一紀、瀧本智行、青島武、渡辺雄介、徳永富彦',
#           'Ｐ ： 山田兼司、太田雅晴',
#           '演出 ： 常廣丈太、瀧本智行 etc'],
#  'dinner': ['江口洋介、倉科カナ、',
#             '松重豊、袴田吉彦、関めぐみ、',
#             '志賀廣太郎、柴本幸、池津祥子、',
#             '風間杜夫、八嶋智人、ユースケ・サンタマリア etc',
#             '脚本 ： 黒岩勉',
#             'Ｐ ： 小椋久雄、山崎淳子',
#             '演出 ： 星護、土方政人、城宝秀則 etc',
#             '主題歌 ： サカナクション『ミュージック』'],
#  '○○妻': ['柴咲コウ、東山紀之、',
#          '黒木瞳、城田優、蓮佛美沙子、',
#          '奥貫薫、渡辺真起子、岩本多代、',
#          '平泉成 etc',
#          '脚本 ： 遊川和彦',
#          'チーフＰ ： 伊藤響',
#          'Ｐ ： 大平太、福井宏、太田雅晴',
#          '演出 ： 猪股隆一、日暮謙、鈴木勇馬 etc',
#          '主題歌 ： 椎名林檎『至上の人生』'],
#  'ああ、探偵事務所': ['永井大、酒井若菜、',
#               '辺見えみり、東幹久、川島なお美 etc',
#               '原作 ： 関崎俊三「ああ、探偵事務所」',
#               '脚本 ： 高山直也',
#               'Ｐ ： 黒田徹也',
#               '演出 ： 今井和久 etc',
#               '主題歌 ： 175R『夕焼けファルセット』'],
#  'あいくるしい': ['市原隼人、綾瀬はるか、',
#             '神木隆之介、松本梨菜、桜井幸子、',
#             '本郷奏多、萩原聖人、志保、',
#             '小栗旬、田中幸太朗、沢尻エリカ、',
#             '高橋克実、高橋ひとみ、原田美枝子、',
#             '竹中直人、杉浦直樹 etc',
#             '脚本 ： 野島伸司',
#             'Ｐ ： 石丸彰彦',
#             '演出 ： 吉田健、平川雄一朗、那須田淳 etc',
#             '主題歌 ： Michael Jackson『BEN』'],
#  'あいのうた': ['菅野美穂、玉置浩二、',
#            '成宮寛貴、佐藤和也、山内奈々、渡邉奏人、',
#            '岸田今日子、阿南健治、中田有紀、佐藤寛子、',
#            '和鞍さほり、橘ユキコ、山崎雄也、芳本美代子、',
#            '小日向文世、和久井映見 etc',
#            '脚本 ： 岡田恵和',
#            'Ｐ ： 加藤正俊、村瀬健、浅井千瑞',
#            '演出 ： 大谷太郎、猪股隆一 etc',
#            '主題歌 ： 玉置浩二『プレゼント』'],
#  'あいの結婚相談所': ['山崎育三郎、高梨臨、',
#               '鹿賀丈史、前田美波里、中尾暢樹、',
#               '山賀琴子 etc',
#               '原作 ： 加藤山羊・矢樹純「あいの結婚相談所」',
#               '脚本 ： 徳尾浩司、矢島弘一、清水友佳子',
#               'Ｐ ： 竹園元、川島誠史、木曽貴美子',
#               '演出 ： 星野和成、小松隆志、竹園元 etc',
#               'テーマ曲 ： 山崎育三郎『Congratulations』『あいのデータ』'],
#  'あしたの、喜多善男\u3000〜世界一不運な男の、奇跡の11日間〜': ['小日向文世、松田龍平、',
#                                        '小西真奈美、栗山千明、岩松了、',
#                                        '今井雅之、吉高由里子、要潤、',
#                                        '生瀬勝久 etc',
#                                        '原作 ： 島田雅彦「自由死刑」',
#                                        '脚本 ： 飯田譲治',
#                                        'Ｐ ： 豊福陽子、遠田孝一',
#                                        '演出 ： 下山天、麻生学、三宅喜重 etc',
#                                        '主題歌 ： 山崎まさよし『真夜中のBoon Boon』'],
#  'あした天気になあれ。': ['観月ありさ、井ノ原快彦、',
#                 'ユンソナ、吉岡美穂、戸田恵子、',
#                 '仲村トオル etc',
#                 '脚本 ： 梅田みか',
#                 'Ｐ ： 加藤正俊',
#                 '演出 ： 岩本仁志、猪股隆一、佐久間紀佳 etc',
#                 '主題歌 ： 樋井明日香『Wanna be your girl friend』'],
#  'あすなろ三三七拍子': ['柳葉敏郎、剛力彩芽、',
#                '風間俊介、高畑充希、大内田悠平、',
#                '飯豊まりえ、菊池桃子、西田敏行、',
#                '森口瑤子、ほんこん、反町隆史 etc',
#                '原作 ： 重松清「あすなろ三三七拍子」',
#                '脚本 ： 吉田紀子、ふじきみつ彦',
#                'Ｐ ： 小林宙',
#                '演出 ： 土方政人、植田泰史 etc',
#                '主題歌 ： スピッツ『愛のことば -2014mix-』'],
#  'あなたには帰る家がある': ['中谷美紀、玉木宏、',
#                  '駿河太郎、高橋メアリージュン、藤本敏史、',
#                  '笛木優子、ユースケ・サンタマリア、木村多江 etc',
#                  '原作 ： 山本文緒「あなたには帰る家がある」',
#                  '脚本 ： 大島里美',
#                  'Ｐ ： 高成麻畝子、大高さえ子',
#                  '演出 ： 平野俊一、吉田健、松田礼人 etc',
#                  '主題歌 ： Superfly『Fall』'],
#  'あなたには渡さない': ['木村佳乃、水野美紀、',
#                '青柳翔、山本直寛、井本彩花、荻野目慶子、',
#                '田中哲司、萩原聖人 etc',
#                '原作 ： 連城三紀彦「隠れ菊」',
#                '脚本 ： 龍居由佳里、福田卓郎',
#                'Ｐ ： 川島誠史、清水真由美',
# ...
#                                   '脚本 ： 橋部敦子',
#                                   'Ｐ ： 成河広明、小林宙、江森浩子',
#                                   '演出 ： 石川淳一、植田泰史 etc',
#                                   '主題歌 ： Mr.Children『常套句』'],
#  '運命の人': ['本木雅弘、松たか子、',
#           '真木よう子、大森南朋、松重豊、北村有起哉、',
#           '遠藤雄弥、梶原善、でんでん、杉本哲太、',
#           '石橋凌、升毅、小松和重、石丸謙二郎、',
#           '橋爪功、吉村実子、今井悠貴、山崎竜太郎、',
#           '山本圭、高林由紀子、柴本幸、長谷川博己、',
#           '原田泰造、斎藤歩、眞島秀和、伊武雅刀、',
#           '小市慢太郎、浅野和之、柳葉敏郎、吹越満、',
#           '市川亀治郎、大和田伸也、本田博太郎、不破万作、',
#           '笹野高史、柄本明、北大路欣也 etc',
#           '原作 ： 山崎豊子「運命の人」',
#           '脚本 ： 橋本裕志',
#           'Ｐ ： 瀬戸口克陽',
#           '演出 ： 土井裕泰、吉田健 etc'],
#  '過保護のカホコ': ['高畑充希、黒木瞳、',
#              '竹内涼真、佐藤二朗、中島ひろ子、梅沢昌代、',
#              '濱田マリ、夙川アトム、西尾まり、久保田紗友、',
#              '三田佳子、西岡\ue1d5馬、平泉成、時任三郎 etc',
#              '脚本 ： 遊川和彦',
#              'チーフＰ ： 西憲彦',
#              'Ｐ ： 大平太、田上リサ',
#              '演出 ： 南雲聖一、日暮謙、伊藤彰記、明石広人 etc',
#              '主題歌 ： 星野源『Family Song』'],
#  '遺産争族': ['向井理、榮倉奈々、',
#           '伊東四朗、岸部一徳、余貴美子、室井滋、',
#           '板谷由夏、鈴木浩介、岸本加世子、渡辺いっけい、',
#           '堀内敬子、真飛聖、堀田茜 etc',
#           '脚本 ： 井上由美子',
#           'Ｐ ： 服部宣之、峰島あゆみ、霜田一寿、池田禎子',
#           '演出 ： 松田秀知、常廣丈太 etc',
#           '主題歌 ： いきものがかり『ラブとピース！』'],
#  '遺産相続弁護士\u3000柿崎真一': ['三上博史、森川葵、',
#                        '酒井若菜、豊原功輔 etc',
#                        '脚本 ： 林誠人 、杉山嘉一、早野円',
#                        'チーフＰ ： 中村泰規',
#                        'Ｐ ： 田中雅博、菊地裕幸、高橋優子',
#                        '演出 ： 白川士 etc',
#                        '主題歌 ： 出雲咲乃『世界のしかけ』'],
#  '遺留捜査': ['上川隆也、貫地谷しほり、',
#           '波岡一喜、水野真紀、佐野史郎、',
#           '大杉漣 etc',
#           '脚本 ： 尾西兼一、坂田義和、池上純哉、伊藤洋子',
#           'チーフＰ ： 松本基弘',
#           'Ｐ ： 三輪祐見子・丸山真哉・横塚孝弘',
#           '演出 ： 猪崎宣昭、麻生学、長谷川康 etc',
#           '主題歌 ： MISIA『記憶』'],
#  '都市伝説の女': ['長澤まさみ、溝端淳平、',
#             '竹中直人、平山浩行、宅間孝行、',
#             '安藤玉恵、良知真次、小林優美、',
#             '篠原真衣、秋月成美、菅原卓磨、',
#             '辻修、伊武雅刀、宇津井健 etc',
#             '脚本 ： 後藤法子',
#             'Ｐ ： 横地郁英、遠田孝一、八巻薫',
#             '演出 ： 星野和成、塚本連平、秋山純 etc',
#             '主題歌 ： 木村カエラ『マミレル』',
#             "OP曲 ： m-flo『Don't Stop Me Now』"],
#  '重版出来！': ['黒木華、オダギリジョー、',
#            '坂口健太郎、荒川良々、野々すみ花、永岡佑、',
#            '前野朋哉、小日向文世、滝藤賢一、要潤、',
#            '永山絢斗、ムロツヨシ、高田純次、安田顕、',
#            '松重豊 etc',
#            '原作 ： 松田奈緒子「重版出来！」',
#            '脚本 ： 野木亜紀子',
#            'Ｐ ： 那須田淳、東仲恵吾、八尾香澄',
#            '演出 ： 土井裕泰、福田亮介、塚原あゆ子 etc',
#            '主題歌 ： ユニコーン『エコー』'],
#  '重要参考人探偵': ['玉森裕太、小山慶一郎、',
#              '新木優子、古川雄輝、堀田茜、',
#              '一井直樹、滝藤賢一、豊原功補、',
#              '西岡\ue1d5馬、松平健 etc',
#              '原作 ： 絹田村子「重要参考人探偵」',
#              '脚本 ： 黒岩勉',
#              'Ｐ ： 神田エミイ亜希子、浅井千瑞、本郷達也',
#              '演出 ： 塚本連平、宝来忠昭、小松隆志 etc',
#              '主題歌 ： Kis-My-Ft2『赤い果実』'],
#  '野ブタ。をプロデュース': ['亀梨和也、山下智久、',
#                  '堀北真希、戸田恵梨香、宇梶剛士、',
#                  '深浦加奈子、中島裕翔、岡田義徳、',
#                  '木村祐一、不破万作、たくませいこ、',
#                  '忌野清志郎、高橋克実、夏木マリ etc',
#                  '原作 ： 白岩玄「野ブタ。をプロデュース」',
#                  '脚本 ： 木皿泉',
#                  'Ｐ ： 河野英裕',
#                  '演出 ： 岩本仁志、佐久間紀佳 etc',
#                  '主題歌 ： 修二と彰『青春アミーゴ』'],
#  '金田一少年の事件簿Neo': ['山田涼介、川口春奈、',
#                   '有岡大貴、浅利陽介、宮下純一、岡本あずさ、',
#                   '上白石萌歌、中島広稀、岡山天音、中川大志、',
#                   '大和田健介、萩原利久、小島あやめ、神木隆之介、',
#                   '山口智充 etc',
#                   '原作 ： 天樹征丸、金成陽三郎、さとうふみや「金田一少年の事件簿」',
#                   '脚本 ： 高橋悠也',
#                   'チーフＰ ： 神蔵克',
#                   'Ｐ ： 櫨山裕子、荻野哲弘、内山雅博',
#                   '演出 ： 木村ひさし、狩山俊輔 etc',
#                   '主題歌 ： Hey!Say!JUMP『ウィークエンダー』'],
#  '鉄板少女アカネ!!': ['堀北真希、塚本高史、',
#                '片瀬那奈、デビット伊東、大友みなみ、',
#                '奈津子、亜希子、竜雷太、',
#                '陣内孝則 etc',
#                '原作 ： 青木健生・ありがひとし「鉄板少女アカネ!!」',
#                '脚本 ： 秦建日子、松田知子、小川みづき',
#                'Ｐ ： 橋本孝､倉貫健二郎、斎藤頼照',
#                '演出 ： 倉貫健二郎､竹村謙太郎､森嶋正也 etc',
#                '主題歌 ： ORANGE RANGE『SAYONARA』'],
#  '銭の戦争': ['草\ue183剛、大島優子、',
#           '木村文乃、高田翔、新川優愛、',
#           '志賀廣太郎、木野花、玉森裕太、',
#           '丸山智己、立石涼子、ジュディ・オング、',
#           '津川雅彦、大杉漣、渡部篤郎',
#           ' etc',
#           '原作 ： パク・イングォン「銭の戦争」',
#           '脚本 ： 後藤法子',
#           'チーフＰ ： 笠置高弘',
#           'Ｐ ： 三宅喜重、河西秀幸',
#           '演出 ： 三宅喜重、白木啓一郎、鈴木浩介 etc',
#           '主題歌 ： SMAP『華麗なる逆襲』'],
#  '銭ゲバ': ['松山ケンイチ、ミムラ、',
#          '宮川大輔、木南晴夏、石橋杏奈、',
#          '光石研、りょう、椎名桔平 etc',
#          '原作 ： ジョージ秋山「銭ゲバ」',
#          '脚本 ： 岡田惠和',
#          'Ｐ ： 河野英裕、難波利昭',
#          '演出 ： 大谷太郎、狩山俊輔 etc',
#          '主題歌 ： かりゆし58『さよなら』'],
#  '鍵のかかった部屋': ['大野智、戸田恵梨香、',
#               '佐藤浩市、能年玲奈 etc',
#               '原作 ： 貴志祐介「鍵のかかった部屋」「硝子のハンマー」「狐火の家」',
#               '脚本 ： 相沢友子',
#               'Ｐ ： 小原一隆、中野利幸',
#               '演出 ： 松山博昭、加藤裕将、石井祐介 etc',
#               '主題歌 ： 嵐『Face Down』'],
#  '間違われちゃった男': ['古田新太、中丸雄一、',
#                '戸田菜穂、佐藤めぐみ、木村了、',
#                '三倉佳奈、金田明夫、大河内浩、',
#                '石田えり etc',
#                '原作 ： 宅間孝行「ぴえろ」',
#                '脚本 ： 宅間孝行',
#                'Ｐ ： 関口大輔、古郡真也',
#                '演出 ： 宅間孝行、成田岳、森脇智延 etc'],
#  '陸王': ['役所広司、山\ue1cc賢人、',
#         '竹内涼真、上白石萌音、風間俊介、音尾琢真、',
#         '和田正人、佐野岳、馬場徹、内村遥、',
#         '天野義久、吉谷彩子、春やすこ、上村依子、',
#         '正司照枝、宇野けんたろう、前原滉、花沢将人、',
#         '佐藤俊彦、石井貴就、安藤勇雅、山本涼介、',
#         '阿川佐和子、小籔千豊、桂雀々、志賀廣太郎、',
#         '光石研、檀ふみ、キムラ緑子、市川右團次、',
#         'ピエール瀧、寺尾聰 etc',
#         '原作 ： 池井戸潤「陸王」',
#         '脚本 ： 八津弘幸',
#         'Ｐ ： 伊與田英徳、飯田和孝、川嶋龍太郎',
#         '演出 ： 福澤克雄、田中健太 etc'],
#  '陽はまた昇る': ['佐藤浩市、三浦春馬、',
#             '池松壮亮、波岡一喜、高橋努、',
#             '南圭介、冨浦智嗣、北村友彦、',
#             '斉藤由貴、ARATA、YOU、',
#             '六角精児、石野真子、真矢みき、',
#             '橋爪功 etc',
#             '脚本 ： 井上由美子',
#             'Ｐ ： 黒田徹也',
#             '演出 ： 秋山純 etc',
#             '主題歌 ： EXILE ATSUSHI『いつかきっと・・・』'],
#  '隠蔽捜査': ['杉本哲太、古田新太、',
#           '安田顕、松澤一之、三倉茉奈、',
#           '八十田勇一、佐野玲於、鈴木砂羽、',
#           '生瀬勝久 etc',
#           '原作 ： 今野敏「隠蔽捜査」',
#           '脚本 ： 中澤圭規、嶋田うれ葉、松本美弥子',
#           'チーフＰ ： 橋本孝',
#           'Ｐ ： 橘康仁',
#           '演出 ： 岡本伸吾、酒井聖博、田中健太 etc',
#           '主題歌 ： wacci『東京』'],
#  '隣の家族は青く見える': ['深田恭子、松山ケンイチ、',
#                 '平山浩行、高橋メアリージュン、北村匠海、',
#                 '眞島秀和、真飛聖、野間口徹、須賀健太、',
#                 '伊藤沙莉、前原滉、寿大聡、橋本マナミ、',
#                 '春海四方、伊藤かずえ、高畑淳子 etc',
#                 '脚本 ： 中谷まゆみ',
#                 'Ｐ ： 中野利幸',
#                 '演出 ： 品田俊介、\ue2d3野舞、相沢秀幸 etc',
#                 '主題歌 ： Mr.Children『here comes my love』'],
#  '集団左遷!!': ['福山雅治、香川照之、',
#             '神木隆之介、中村アン、井之脇海、高橋和也、',
#             '迫田孝也、増田修一朗、谷口翔太、橋本真実、',
#             '市村正親、小手伸也、赤堀雅秋、パパイヤ鈴木、',
#             '絃瀬聡一、酒向芳、橋爪淳、津嘉山正種、',
#             '八木亜希子、西田尚美、尾美としのり、三上博史 etc',
#             '原作 ： 江波戸哲夫「新装版 銀行支店長」「集団左遷」',
#             '脚本 ： いずみ吉紘',
#             'Ｐ ： 飯田和孝、中前勇児',
#             '演出 ： 平川雄一朗、田中健太、韓哲 etc',
#             'テーマ曲 ： エレファントカシマシ『俺たちの明日』'],
#  '離婚弁護士': ['天海祐希、玉山鉄二、',
#            'ミムラ、佐々木蔵之介、久我陽子、',
#            '陣内孝則、津川雅彦、',
#            '(1話ゲスト)竹之内豊 etc',
#            '脚本 ： 田渕久美子、林宏司',
#            'Ｐ ： 長部聡介、瀧山麻土香',
#            '演出 ： 光野道夫、田島大輔 etc',
#            '主題歌 ： hitomi『心の旅人』',
#            '挿入歌 ： Nora Johns『What am I to you』'],
#  '離婚弁護士II\u3000〜ハンサムウーマン〜': ['天海祐希、瀬戸朝香、',
#                              '玉山鉄二、佐々木蔵之介、片瀬那奈、',
#                              '宇梶剛士、松重豊、戸田恵子、',
#                              '津川雅彦 etc',
#                              '脚本 ： 林宏司',
#                              'Ｐ ： 長部聡介、古屋建自',
#                              '演出 ： 久保田哲史、松山博昭 etc',
#                              '主題歌 ： 星村麻衣『EVERY』'],
#  '雨と夢のあとに': ['黒川智花、沢村一樹、',
#              '木村多江、速水もこみち、浅見れいな、',
#              '杏子、美保純、ブラザートム etc',
#              '原作 ： 柳美里「雨と夢のあとに」',
#              '脚本 ： 成井豊、真柴あずき',
#              'チーフＰ ： 五十嵐文郎',
#              'Ｐ ： 中込卓也、椿宜和、藤本一彦',
#              '演出 ： 麻生学、常廣丈太、唐木希浩、新村良二 etc',
#              '主題歌 ： 奥田美和子『雨と夢のあとに』'],
#  '雲の階段': ['長谷川博己、稲森いずみ、',
#           '木村文乃、萩原聖人、青柳翔、',
#           '優希美青、キムラ緑子、半海一晃、',
#           '加賀まりこ、多岐川裕美、大友康平、',
#           '内藤剛志 etc',
#           '原作 ： 渡辺淳一「雲の階段」',
#           '脚本 ： 寺田敏雄',
#           'チーフＰ ： 大平太',
#           'Ｐ ： 荻野哲弘、太田雅晴',
#           '演出 ： 猪股隆一、岩本仁志、吉野洋 etc',
#           "主題歌 ： B'z『核心』"],
#  '電池が切れるまで': ['財前直見、陣内孝則、',
#               '原沙知絵、要潤、吉岡美穂、',
#               '黒川智花、デビット伊東、野際陽子 etc',
#               '原作 ： すずらんの会・宮本雅史「電池が切れるまで」',
#               '脚本 ： 江頭美智留',
#               'チーフＰ ： 五十嵐文郎',
#               'Ｐ ： 川島保男、中込卓也、椿宜和、藤本一彦',
#               '演出 ： 藤田明二、唐木希浩 etc',
#               '主題歌 ： 星村麻衣『ひまわり』',
#               'OP曲 ： 平川地一丁目『君の分まで』'],
#  '電車男': ['伊東美咲、伊藤淳史、',
#          '白石美帆、佐藤江梨子、須藤理彩、',
#          '速水もこみち、劇団ひとり、菅原永二、',
#          '佐藤二朗、前川泰之、堀北真希、',
#          '小出早織、小栗旬、温水洋一、',
#          '我修院達也、山崎樹範、豊原功補、',
#          '岸部シロー、秋吉久美子 etc',
#          '脚本 ： 武藤将吾',
#          'Ｐ ： 若松央樹、川西琢',
#          '演出 ： 武内英樹、西浦正記、小林和宏 etc',
#          '主題歌 ： サンボマスター『世界はそれを愛と呼ぶんだぜ』'],
#  '霊感バスガイド事件簿': ['菊川怜、海東健、',
#                 '北川弘美、嘉門洋子、高橋ひとみ、',
#                 '北村総一朗 etc',
#                 '原作 ： 赤川次郎',
#                 '脚本 ： 大石哲也',
#                 'チーフＰ ： 桑田潔',
#                 'Ｐ ： 横地郁英、和田豊彦',
#                 '演出 ： 中島悟 etc',
#                 '主題歌 ： 安良城紅『Harmony』'],
#  '霊能力者 小田霧響子の嘘': ['石原さとみ、谷原章介、',
#                   '大島優子 etc',
#                   '原作 ： 甲斐谷忍「霊能力者 小田霧響子の嘘」',
#                   '脚本 ： 渡辺雄介',
#                   'Ｐ ： 関拓也、井上竜太',
#                   '演出 ： 常廣丈太 etc',
#                   '主題歌 ： 世界の終わり『天使と悪魔』'],
#  '青春探偵ハルヤ\u3000〜大人の悪を許さない!〜': ['玉森裕太、新川優愛、',
#                                '高田翔、柳ゆり菜、阿見201、池田沙絵美、',
#                                '小槙まこ、伊倉愛美、篠川桃音、宇梶剛士、',
#                                '高島礼子 etc',
#                                '原作 ： 福田栄一「エンド・クレジットに最適な夏」',
#                                '脚本 ： 田中眞一',
#                                'Ｐ ： ',
#                                '演出 ： 大塚徹、小松隆志 etc',
#                                '主題歌 ： Kis-My-Ft2『AAO』'],
#  '顔': ['仲間由紀恵、オダギリジョー、',
#        '益岡徹、余貴美子、矢島健一、',
#        '品川祐、京野ことみ、海東健 etc',
#        '原作 ： 横山秀夫',
#        '脚本 ： ',
#        'Ｐ ： 高橋萬彦、後藤博幸',
#        '演出 ： 土方政人、松田秀知、都築淳一 etc',
#        '主題歌 ： Nao『君があなたが』'],
#  '風のガーデン': ['中井貴一、黒木メイサ、',
#             '神木隆之介、国仲涼子、石田えり、',
#             '布施博、ガッツ石松、平原綾香、',
#             '平野勇樹、伊藤蘭、奥田瑛二、',
#             '緒形拳 etc',
#             '脚本 ： 倉本聰',
#             'チーフＰ ： 中村敏夫',
#             'Ｐ ： 若松央樹、浅野澄美',
#             '演出 ： 宮本理江子 etc'],
#  '高原へいらっしゃい': ['佐藤浩市、西村雅彦、',
#                '井川遥、堀内健、市川実和子、',
#                '平山広行、大山のぶ代、純名りさ、',
#                '入江雅人、平田満、高知東生、',
#                '竹脇無我、余貴美子、菅原文太 etc',
#                '原作 ： 山田太一',
#                '脚本 ： 前川洋一',
#                'Ｐ ： 志村彰、次屋尚',
#                '演出 ： 今井和久、吉田健 etc',
#                '主題歌 ： 浜崎あゆみ『Forgiveness』'],
#  '高嶺の花': ['石原さとみ、峯田和伸、',
#           '芳根京子、千葉雄大、三浦貴大、笛木優子、',
#           '袴田吉彦、吉田ウーロン太、高橋ひかる、城後光義、',
#           '舘秀々輝、田畑志真、西原亜希、正司照枝、',
#           '正司花江、博多華丸、升毅、十朱幸代、',
#           '戸田菜穂、小日向文世 etc',
#           '脚本 ： 野島伸司',
#           'チーフＰ ： 西憲彦',
#           'Ｐ ： 松原浩、鈴木亜希乃、渡邉浩仁',
#           '演出 ： 大塚恭司、狩山俊輔、岩\ue1ccマリエ etc',
#           '主題歌 ： エルヴィス・プレスリー『ラヴ・ミー・テンダー』'],
#  '高校入試': ['長澤まさみ、南沢奈央、',
#           '中尾明慶、徳山秀典、篠田光亮、小松利昌、',
#           '斉木しげる、入江雅人、生田智子、中村倫也、',
#           '姜暢雄、荒木宏文、倉貫匡弘、美山加恋、',
#           '柾木玲弥、高杉真宙、清水尋也、山崎紘菜、',
#           '清水一彰、阪田マサノブ、羽場裕一、',
#           '高橋ひとみ、山本圭 etc',
#           '脚本 ： 湊かなえ',
#           'Ｐ ： \ue200川由起子',
#           '演出 ： 星護、北川学 etc',
#           '主題歌 ： back number『青い春』'],
#  '高校教師': ['藤木直人、上戸彩、',
#           'ソニン、成宮寛貴、眞鍋かをり、',
#           '大倉孝二、蒼井優、京本政樹、',
#           '眞野あずさ etc',
#           '脚本 ： 野島伸司',
#           'Ｐ ： 伊藤一尋',
#           '演出 ： 鴨下信一、吉田健、今井夏木 etc',
#           '主題歌 ： 森田童子『ぼくたちの失敗』'],
#  '高校生レストラン': ['松岡昌宏、吹石一恵、',
#               '神木隆之介、川島海荷、板谷由夏、',
#               '原田芳雄、伊藤英明 etc',
#               '原作 ： 村林新吾「高校生レストラン､本日も満席｡」「高校生レストラン､行列の理由｡」',
#               '脚本 ： 吉本昌弘',
#               'チーフＰ ： 櫨山裕子',
#               'Ｐ ： 萩野哲弘、内山雅博',
#               '演出 ： 吉野洋、猪股隆一、佐久間紀佳 etc',
#               '主題歌 ： TOKIO『見上げた流星』'],
#  '鬼嫁日記': ['観月ありさ、ゴリ、',
#           '永井大、滝沢沙織、小池徹平、',
#           '山崎まどか、井上和香、東幹久 etc',
#           '原作 ： カズマ「実録鬼嫁日記」',
#           '脚本 ： 尾崎将也',
#           'Ｐ ： 安藤和久、東城祐司、布施等',
#           '演出 ： 池添博、塚本連平、植田尚 etc',
#           "主題歌 ： 中ノ森BAND『Oh My Darlin'』",
#           '挿入歌 ： Fayray『Spotlight』'],
#  '鬼嫁日記 いい湯だな': ['観月ありさ、ゴリ、',
#                 '遠藤由実、蛯原友里、山本裕典、',
#                 '樋井明日香、川島なお美、高知東生、',
#                 '鈴木砂羽、野際陽子、加藤茶 etc',
#                 '原作 ： カズマ「実録鬼嫁日記」',
#                 '脚本 ： 尾崎将也',
#                 'Ｐ ： 安藤和久、東城祐司、布施等',
#                 '演出 ： 塚本連平、池添博、小松隆志、植田尚 etc',
#                 '主題歌 ： 谷村奈南『Again』',
#                 '挿入歌 ： ナナ・イロ『ブランケット』'],
#  '魔女裁判': ['生田斗真、加藤あい、',
#           '比嘉愛未、鈴木亮平、忽那汐里、',
#           '末永遥、中村靖日、山谷初男、',
#           '平方元基、中村果生莉、松本じゅん、',
#           '渡邉鉱平、宍戸美和公、滝沢沙織、',
#           '石田ゆり子 etc',
#           '脚本 ： 前川洋一',
#           'Ｐ ： 関卓也、小池秀樹',
#           '演出 ： 加藤裕将、小原一隆 etc',
#           '主題歌 ： 福山雅治『化身』'],
#  '魔王': ['大野智、生田斗真、',
#         '小林涼子、田中圭、忍成修吾、',
#         '脇知弘、上原美佐、篠原真衣、',
#         '清水優、飯田基祐、東根作寿英、',
#         '吉瀬美智子、劇団ひとり、三宅裕司、',
#         '石坂浩二 etc',
#         '脚本 ： 前川洋一、西田征史',
#         'Ｐ ： 高橋正尚、渡辺良介',
#         '演出 ： 加藤新、坪井敏雄 etc',
#         '主題歌 ： 嵐『truth』'],
#  '鴨、京都へ行く。\u3000−老舗旅館の女将日記−': ['松下奈緒、椎名桔平、',
#                                '若村麻由美、堀内敬子、大東駿介、高杉亘、',
#                                '小柳友、丸山智己、楠見薫、岡本あずさ、',
#                                '御厨響一、佐野岳、彩也子、八木菜々花、',
#                                '笹野高史、伊武雅刀、市毛良枝、松平健、',
#                                'かたせ梨乃 etc',
#                                '脚本 ： 森ハヤシ、酒井雅秋、岩下悠子',
#                                'Ｐ ： 手塚治、妹尾啓太、中尾亜由子',
#                                '演出 ： 永山耕三、兼\ue1cc涼介、並木道子 etc',
#                                '主題歌 ： 椎名林檎『いろはにほへと』'],
#  '鹿男あをによし': ['玉木宏、綾瀬はるか、',
#              '多部未華子、柴本幸、篠井英介、',
#              'キムラ緑子、酒井敏也、鷲尾真知子、',
#              '田山涼成、佐々木蔵之介、児玉清 etc',
#              '原作 ： 万城目学「鹿男あをによし」',
#              '脚本 ： 相沢友子',
#              'Ｐ ： 土屋健',
#              '演出 ： 鈴木雅之、村上正典 etc'],
#  '黄昏流星群': ['佐々木蔵之介、中山美穂、',
#            '藤井流星、石川恋、礼二、麻生祐未、',
#            '八木亜希子、小野武彦、黒木瞳 etc',
#            '原作 ： 弘兼憲史「黄昏流星群」',
#            '脚本 ： 浅野妙子',
#            'Ｐ ： 高田雄貴',
#            '演出 ： 平野眞、林徹、森脇智延 etc',
#            '主題歌 ： 平井堅『half of me』',
#            '挿入歌 ： 中島美嘉『彩恋〜SAI_REN〜』'],
#  '黄金の豚\u3000−会計検査庁 特別調査課−': ['篠原涼子、岡田将生、',
#                              '大泉洋、桐谷健太、山口紗弥加、',
#                              '近藤芳正、矢沢心、能世あんな、',
#                              '山崎大輔、もたいまさこ、生瀬勝久、',
#                              '宇津井健 etc',
#                              '脚本 ： 吉田智子',
#                              'チーフＰ ： 櫨山裕子',
#                              'Ｐ ： 大倉寛子、内山雅博',
#                              '演出 ： 佐藤東弥、南雲聖一 etc',
#                              '主題歌 ： 伊藤由奈『守ってあげたい』'],
#  '黒い十人の女': ['船越英一郎、成海璃子、',
#             'トリンドル玲奈、佐藤仁美、佐野ひなこ、',
#             'MEGUMI、平山あや、白羽ゆり、',
#             'ちすん、若村麻由美、水野美紀 etc',
#             '原作 ： 和田夏十「黒い十人の女」',
#             '脚本 ： バカリズム',
#             'チーフＰ ： 中村泰規',
#             'Ｐ ： 汐口武史、河野美里',
#             '演出 ： 渡部亮平、瑠東東一郎、山本大輔、豊島圭介 etc',
#             '主題歌 ： CIVILIAN『愛/憎』'],
#  '黒い太陽': ['永井大、井上和香、',
#           '伊原剛志、酒井若菜、菅原卓磨、',
#           '吹越満、滝沢沙織、大友みなみ、',
#           '杏さゆり、渡邉邦門、浅香友紀、',
#           'かでなれおん、益子梨恵、涼果りん、',
#           '井上康、深水元基、田中要次 etc',
#           '原作 ： 新堂冬樹「黒い太陽」',
#           '脚本 ： 樫田正剛',
#           'チーフＰ ： 五十嵐文郎',
#           'Ｐ ： 藤本一彦、奥住尚弘',
#           '演出 ： 麻生学、田村直己 etc',
#           '主題歌 ： ユハラユキ『友ダチ』'],
#  '黒の女教師': ['榮倉奈々、松村北斗、',
#            '千葉雄大、大野いと、西井幸人、土屋太鳳、',
#            '山\ue1cc賢人、竹富聖花、広瀬アリス、太賀、',
#            '杉咲花、藤原令子、上遠野太洸、中条あやみ、',
#            '木村文乃、トリンドル玲奈、駿河太郎、光石研、',
#            '市川実日子、南果歩、小林聡美 etc',
#            '脚本 ： 山下友弘、大林利江子、吉澤智子、池田奈津子',
#            'Ｐ ： 伊與田英徳',
#            '演出 ： 岡本伸吾、石井康晴、川嶋龍太郎 etc',
#            '主題歌 ： UVERworld『THE OVER』'],
#  '黒服物語': ['中島健人、佐々木希、',
#           '山本裕典、柏木由紀、中尾明慶、安井謙太郎、',
#           '\ue200俊太郎、入山杏奈、筧美和子、杉本有美、',
#           '柳ゆり菜、福吉真璃奈、金田彩菜、相葉裕樹、',
#           '木下ほうか、宮川一朗太、中島ひろ子、神保悟志、',
#           '黒川智花、北村有起哉、要潤、竹中直人 etc',
#           '原作 ： 倉科遼、成田マナブ「黒服物語」',
#           '脚本 ： 旺季志ずか、山浦雅大',
#           'Ｐ ： 大江達樹、布施等、木曽貴美子',
#           '演出 ： 小松隆志、植田尚 etc',
#           '主題歌 ： Sexy Zone『君にHITOMEBORE』'],
#  '黒革の手帖': ['米倉涼子、仲村トオル、',
#            '釈由美子、室井滋、渡辺いっけい、',
#            '紫吹淳、吉岡美穂、山本陽子、',
#            '柳葉敏郎、小林稔侍、津川雅彦 etc',
#            '原作 ： 松本清張「黒革の手帖」',
#            '脚本 ： 神山由美子',
#            'チーフＰ ： 五十嵐文郎',
#            'Ｐ ： 内山聖子、中山和記',
#            '演出 ： 松田秀知、藤田明二 etc',
#            '主題歌 ： 安良城紅『Ｈｅｒｅ\u3000ａｌｏｎｅ』']}

# %%
simple_json = {}
for key in drama_info_dict.keys():
    main_actors = drama_info_dict[key][0].split("、")
    if len(main_actors)>1:
        simple_json[key] = {"cast1" : main_actors[0], "cast2" : main_actors[1]}
    else:
        simple_json[key] = {"cast1" : "", "cast2" : ""}
        #     simple_json[key]["main_actor2"] = main_actors if main_actors[0] else "aa"

print(simple_json)
# Out:
# {'シャーロック\u3000アントールドストーリーズ': {'cast1': '', 'cast2': ''}, 'まだ結婚できない男': {'cast1': '', 'cast2': ''}, 'G線上のあなたと私': {'cast1': '', 'cast2': ''}, '同期のサクラ': {'cast1': '', 'cast2': ''}, 'ドクターX\u3000〜外科医・大門未知子〜': {'cast1': '米倉涼子', 'cast2': '田中圭'}, 'モトカレマニア': {'cast1': '', 'cast2': ''}, 'CHEAT\u3000〜詐欺師の皆さん、ご注意ください〜': {'cast1': '', 'cast2': ''}, '4分間のマリーゴールド': {'cast1': '', 'cast2': ''}, '時効警察はじめました': {'cast1': '', 'cast2': ''}, '俺の話は長い': {'cast1': '', 'cast2': ''}, 'おっさんずラブ\u3000in the sky': {'cast1': '', 'cast2': ''}, 'グランメゾン東京': {'cast1': '', 'cast2': ''}, 'ニッポンノワール\u3000−刑事Yの反乱−': {'cast1': '', 'cast2': ''}, '監察医 朝顔': {'cast1': '上野樹里', 'cast2': '時任三郎'}, 'TWO WEEKS': {'cast1': '三浦春馬', 'cast2': '芳根京子'}, 'Heaven？\u3000〜ご苦楽レストラン〜': {'cast1': '石原さとみ', 'cast2': '福士蒼汰'}, '偽装不倫': {'cast1': '杏', 'cast2': '宮沢氷魚'}, 'サイン\u3000−法医学者 柚木貴志の事件−': {'cast1': '大森南朋', 'cast2': '松雪泰子'}, 'ルパンの娘': {'cast1': '深田恭子', 'cast2': '瀬戸康史'}, 'わたし旦那をシェアしてた': {'cast1': '小池栄子', 'cast2': 'りょう'}, '凪のお暇': {'cast1': '黒木華', 'cast2': '高橋一生'}, 'セミオトコ': {'cast1': '山田涼介', 'cast2': '木南晴夏'}, 'ボイス\u3000110緊急指令室': {'cast1': '唐沢寿明', 'cast2': '真木よう子'}, 'べしゃり暮らし': {'cast1': '間宮祥太朗', 'cast2': '渡辺大知'}, 'ノーサイド・ゲーム': {'cast1': '大泉洋', 'cast2': '松たか子'}, 'あなたの番です\u3000反撃編': {'cast1': '田中圭', 'cast2': '原田知世'}, 'ラジエーションハウス': {'cast1': '窪田正孝', 'cast2': '本田翼'}, 'パーフェクトワールド': {'cast1': '松坂桃李', 'cast2': '山本美月'}, 'わたし、定時で帰ります。': {'cast1': '吉高由里子', 'cast2': '向井理'}, '白衣の戦士！': {'cast1': '中条あやみ', 'cast2': '水川あさみ'}, '緊急取調室': {'cast1': '天海祐希', 'cast2': '田中哲司'}, 'ストロベリーナイト・サーガ': {'cast1': '二階堂ふみ', 'cast2': '亀梨和也'}, '向かいのバズる家族': {'cast1': '内田理央', 'cast2': '白洲迅'}, 'インハンド': {'cast1': '山下智久', 'cast2': '濱田岳'}, '家政夫のミタゾノ': {'cast1': '松岡昌宏', 'cast2': '清水富美加'}, '俺のスカート、どこ行った？': {'cast1': '古田新太', 'cast2': '松下奈緒'}, '東京独身男子': {'cast1': '高橋一生', 'cast2': '滝藤賢一'}, '集団左遷!!': {'cast1': '福山雅治', 'cast2': '香川照之'}, 'あなたの番です': {'cast1': '原田知世', 'cast2': '田中圭'}, 'トレース\u3000〜科捜研の男〜': {'cast1': '錦戸亮', 'cast2': '新木優子'}, '後妻業': {'cast1': '木村佳乃', 'cast2': '高橋克典'}, '初めて恋をした日に読む話': {'cast1': '深田恭子', 'cast2': '永山絢斗'}, '家売るオンナの逆襲': {'cast1': '北川景子', 'cast2': '松田翔太'}, 'ハケン占い師アタル': {'cast1': '杉咲花', 'cast2': '小澤征悦'}, 'スキャンダル専門弁護士\u3000QUEEN': {'cast1': '竹内結子', 'cast2': '水川あさみ'}, '人生が楽しくなる幸せの法則': {'cast1': '夏菜', 'cast2': '高橋メアリージュン'}, 'メゾン・ド・ポリス': {'cast1': '高畑充希', 'cast2': '西島秀俊'}, '私のおじさん\u3000〜WATAOJI〜': {'cast1': '岡田結実', 'cast2': '遠藤憲一'}, 'イノセンス\u3000冤罪弁護士': {'cast1': '坂口健太郎', 'cast2': '川口春奈'}, '僕の初恋をキミに捧ぐ': {'cast1': '野村周平', 'cast2': '桜井日奈子'}, 'グッドワイフ': {'cast1': '常盤貴子', 'cast2': '小泉孝太郎'}, '3年A組\u3000−今から皆さんは、人質です−': {'cast1': '菅田将暉', 'cast2': '永野芽郁'}, 'SUITS／スーツ': {'cast1': '織田裕二', 'cast2': '中島裕翔'}, '僕らは奇跡でできている': {'cast1': '高橋一生', 'cast2': '榮倉奈々'}, '中学聖日記': {'cast1': '有村架純', 'cast2': '岡田健史'}, '獣になれない私たち': {'cast1': '新垣結衣', 'cast2': '松田龍平'}, 'リーガルV\u3000〜元弁護士・小鳥遊翔子〜': {'cast1': '米倉涼子', 'cast2': '向井理'}, '黄昏流星群': {'cast1': '佐々木蔵之介', 'cast2': '中山美穂'}, 'ブラックスキャンダル': {'cast1': '山口紗弥加', 'cast2': '安藤政信'}, '大恋愛\u3000〜僕を忘れる君と': {'cast1': '戸田恵梨香', 'cast2': 'ムロツヨシ'}, '僕とシッポと神楽坂': {'cast1': '相葉雅紀', 'cast2': '広末涼子'}, 'ドロ刑\u3000−警視庁捜査三課−': {'cast1': '中島健人', 'cast2': '遠藤憲一'}, 'あなたには渡さない': {'cast1': '木村佳乃', 'cast2': '水野美紀'}, '下町ロケット': {'cast1': '阿部寛', 'cast2': '土屋太鳳'}, '今日から俺は!!': {'cast1': '賀来賢人', 'cast2': '伊藤健太郎'}, '絶対零度\u3000〜未然犯罪潜入捜査〜': {'cast1': '沢村一樹', 'cast2': '横山裕'}, '健康で文化的な最低限度の生活': {'cast1': '吉岡里帆', 'cast2': '井浦新'}, '義母と娘のブルース': {'cast1': '綾瀬はるか', 'cast2': '竹野内豊'}, '高嶺の花': {'cast1': '石原さとみ', 'cast2': '峯田和伸'}, 'ハゲタカ': {'cast1': '綾野剛', 'cast2': '渡部篤郎'}, 'グッド・ドクター': {'cast1': '山\ue1cc賢人', 'cast2': '上野樹里'}, '探偵が早すぎる': {'cast1': '滝藤賢一', 'cast2': '広瀬アリス'}, 'チア☆ダン': {'cast1': '土屋太鳳', 'cast2': '石井杏奈'}, 'dele': {'cast1': '菅田将暉', 'cast2': '山田孝之'}, 'サバイバル・ウェディング': {'cast1': '波瑠', 'cast2': '吉沢亮'}, 'ヒモメン': {'cast1': '窪田正孝', 'cast2': '川口春奈'}, 'この世界の片隅に': {'cast1': '松本穂香', 'cast2': '松坂桃李'}, 'ゼロ\u3000一獲千金ゲーム': {'cast1': '加藤シゲアキ', 'cast2': '間宮祥太朗'}, 'コンフィデンスマンJP': {'cast1': '長澤まさみ', 'cast2': '東出昌大'}, 'シグナル\u3000長期未解決事件捜査班': {'cast1': '坂口健太郎', 'cast2': '北村 ...

# %%
import json
fw = open('../data/main_actor_only.json','w')
# json.dump関数でファイルに書き込む
json.dump(simple_json ,fw,indent=4, ensure_ascii=False)
