# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#追記
import json
import datetime
import math

from urllib import request
from bs4 import BeautifulSoup
import urllib.request
import requests
import re

#importじゃないけど、個人的には省略されて良いことがあまりないので・・
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)

# %%
df_vr = pd.read_csv("../data/viewing_rating.csv", encoding='cp932')

# %%
# time型に
df_vr.start_at=pd.to_datetime(df_vr.start_at)
df_vr["start_at_month"] = df_vr["start_at"].dt.month

# %%
df_vr["drama_key"] = df_vr.start_at.dt.strftime("%y")+df_vr.start_at.dt.strftime("%m")+"_"+df_vr.TV_station+"_"+df_vr.time_table

# %%
df_vr.drama_key
# Out:
# 0       1910_CX_月21
# 1       1910_CX_火22
# 2      1910_TBS_火22
# 3      1910_NTV_水22
# 4       1910_EX_木22
# 5       1910_CX_木22
# 6      1910_NTV_木23
# 7      1910_TBS_金22
# 8       1910_EX_金23
# 9      1910_NTV_土22
# 10      1910_EX_土23
# 11     1910_TBS_日21
# 12     1910_NTV_日22
# 13      1907_CX_月21
# 14      1907_CX_火21
# 15     1907_TBS_火22
# 16     1907_NTV_水22
# 17      1907_EX_木21
# 18      1907_CX_木22
# 19     1907_NTV_木23
# 20     1907_TBS_金22
# 21      1907_EX_金23
# 22     1907_NTV_土22
# 23      1907_EX_土23
# 24     1907_TBS_日21
# 25     1907_NTV_日22
# 26      1904_CX_月21
# 27      1904_CX_火21
# 28     1904_TBS_火22
# 29     1904_NTV_水22
# 30      1904_EX_木21
# 31      1904_CX_木22
# 32     1904_NTV_木23
# 33     1904_TBS_金22
# 34      1904_EX_金23
# 35     1904_NTV_土22
# 36      1904_EX_土23
# 37     1904_TBS_日21
# 38     1904_NTV_日22
# 39      1901_CX_月21
# 40      1901_CX_火21
# 41     1901_TBS_火22
# 42     1901_NTV_水22
# 43      1901_EX_木21
# 44      1901_CX_木22
# 45     1901_NTV_木23
# 46     1901_TBS_金22
# 47      1901_EX_金23
# 48     1901_NTV_土22
# 49      1901_EX_土23
# 50     1901_TBS_日21
# 51     1901_NTV_日22
# 52      1810_CX_月21
# 53      1810_CX_火21
# 54     1810_TBS_火22
# 55     1810_NTV_水22
# 56      1810_EX_木21
# 57      1810_CX_木22
# 58     1810_NTV_木23
# 59     1810_TBS_金22
# 60      1810_EX_金23
# 61     1810_NTV_土22
# 62      1810_EX_土23
# 63     1810_TBS_日21
# 64     1810_NTV_日22
# 65      1807_CX_月21
# 66      1807_CX_火21
# 67     1807_TBS_火22
# 68     1807_NTV_水22
# 69      1807_EX_木21
# 70      1807_CX_木22
# 71     1807_NTV_木23
# 72     1807_TBS_金22
# 73      1807_EX_金23
# 74     1807_NTV_土22
# 75      1807_EX_土23
# 76     1807_TBS_日21
# 77     1807_NTV_日22
# 78      1804_CX_月21
# 79      1804_CX_火21
# 80     1804_TBS_火22
# 81     1804_NTV_水22
# 82      1804_EX_木21
# 83      1804_CX_木22
# 84     1804_NTV_木23
# 85     1804_TBS_金22
# 197     1601_CX_火22
# 198    1601_TBS_火22
# 199    1601_NTV_水22
# 200     1601_CX_水22
# 201     1601_EX_木21
# 202     1601_CX_木22
# 203    1601_NTV_木23
# 204    1601_TBS_金22
# 205     1601_EX_金23
# 206    1601_NTV_土21
# 207    1601_TBS_日21
# 208    1601_NTV_日22
# 209     1510_CX_月21
# 210     1510_CX_火22
# 211    1510_TBS_火22
# 212    1510_NTV_水22
# 213     1510_CX_水22
# 214     1510_EX_木21
# 215     1510_CX_木22
# 216    1510_NTV_木23
# 217    1510_TBS_金22
# 218     1510_EX_金23
# 219    1510_NTV_土21
# 220    1510_TBS_日21
# 221    1510_NTV_日22
# 222     1507_CX_月21
# 223     1507_CX_火22
# 224    1507_TBS_火22
# 225    1507_NTV_水22
# 226     1507_CX_水22
# 227    1507_TBS_木21
# 228     1507_EX_木21
# 229     1507_CX_木22
# 230    1507_NTV_木23
# 231    1507_TBS_金22
# 232     1507_EX_金23
# 233    1507_NTV_土21
# 234    1507_TBS_日21
# 235    1507_NTV_日22
# 236     1504_CX_月21
# 237     1504_CX_火22
# 238    1504_TBS_火22
# 239    1504_NTV_水22
# 240     1504_CX_水22
# 241    1504_TBS_木21
# 242     1504_EX_木21
# 243     1504_CX_木22
# 244    1504_NTV_木23
# 245    1504_TBS_金22
# 246     1504_EX_金23
# 247    1504_NTV_土21
# 248    1504_TBS_日21
# 249    1504_NTV_日22
# 250    1501_TBS_月20
# 251     1501_CX_月21
# 252     1501_CX_火21
# 253     1501_CX_火22
# 254    1501_TBS_火22
# 255    1501_NTV_水22
# 256     1501_CX_水22
# 257    1501_TBS_木21
# 258     1501_EX_木21
# 259     1501_CX_木22
# 260    1501_NTV_木23
# 261    1501_TBS_金22
# 262     1501_EX_金23
# 263    1501_NTV_土21
# 264    1501_TBS_日21
# 265    1410_TBS_月20
# 266     1410_CX_月21
# 267     1410_CX_火21
# 268     1410_CX_火22
# 269    1410_TBS_火22
# 270    1410_NTV_水22
# 271     1410_CX_水22
# 272    1410_TBS_木21
# 273    1410_TBS_木21
# 274     1410_EX_木21
# 275     1410_CX_木22
# 276    1410_NTV_木23
# 277    1410_TBS_金22
# 278     1410_EX_金23
# 279    1410_NTV_土21
# 280    1410_TBS_日21
# 281    1407_TBS_月20
# 282     1407_CX_月21
# 283    1407_TBS_火22
# 284     1407_CX_火21
# 285     1407_CX_火22
# 286    1407_NTV_水22
# 287     1407_CX_水22
# 288     1407_EX_木20
# 289    1407_TBS_木21
# 290     1407_EX_木21
# 291     1407_CX_木22
# 292    1407_NTV_木23
# 293    1407_TBS_金22
# 294     1407_EX_金23
# 295    1407_NTV_土21
# 296     1407_CX_土23
# 297    1407_TBS_日21
# 298    1404_TBS_月20
# 299     1404_CX_月21
# 300    1404_TBS_火22
# 301     1404_CX_火21
# 302     1404_CX_火22
# 303     1404_EX_水21
# 304    1404_NTV_水22
# 305     1404_CX_水22
# 306     1404_EX_木20
# 307    1404_TBS_木21
# 308     1404_EX_木21
# 309     1404_CX_木22
# 310    1404_NTV_木23
# 311    1404_TBS_金22
# 312     1404_EX_金23
# 313    1404_NTV_土21
# 314     1404_CX_土23
# 315    1404_TBS_日21
# 316    1401_TBS_月20
# 317     1401_CX_月21
# 318     1401_CX_火21
# 319     1401_CX_火22
# 320    1401_NTV_水22
# 321     1401_CX_水22
# 322    1401_TBS_木21
# 323     1401_EX_木21
# 324     1401_CX_木22
# 325    1401_NTV_木23
# 326     1401_CX_金20
# 327    1401_TBS_金22
# 328     1401_EX_金23
# 329    1401_NTV_土21
# 330     1401_CX_土23
# 331    1401_TBS_日21
# 332    1310_TBS_月20
# 333     1310_CX_月21
# 334     1310_CX_火21
# 335     1310_CX_火22
# 336    1310_NTV_水22
# 337     1310_CX_水22
# 338    1310_TBS_木21
# 339     1310_EX_木21
# 340     1310_CX_木22
# 341    1310_NTV_木23
# 342     1310_CX_金20
# 343    1310_TBS_金22
# 344     1310_EX_金23
# 345    1310_NTV_土21
# 346     1310_CX_土23
# 347    1310_TBS_日21
# 348    1307_TBS_月20
# 349     1307_CX_月21
# 350     1307_CX_火21
# 351     1307_CX_火22
# 352    1307_NTV_水22
# 353     1307_CX_水22
# 354    1307_TBS_木21
# 355     1307_EX_木21
# 356     1307_CX_木22
# 357    1307_NTV_木23
# 358    1307_TBS_金22
# 359     1307_EX_金23
# 360    1307_NTV_土21
# 361     1307_CX_土23
# 362    1307_TBS_日21
# 363    1304_TBS_月20
# 364     1304_CX_月21
# 365     1304_CX_火21
# 366     1304_CX_火22
# 367     1304_EX_水21
# 368    1304_NTV_水22
# 369     1304_CX_水22
# 370     1304_EX_木20
# 371    1304_TBS_木21
# 372     1304_EX_木21
# 373     1304_CX_木22
# 374    1304_NTV_木23
# 375    1304_TBS_金22
# 376     1304_EX_金23
# 377    1304_NTV_土21
# 378     1304_CX_土23
# 379    1304_TBS_日21
# 380    1301_TBS_月20
# 381     1301_CX_月21
# 382     1301_CX_火21
# 383     1301_CX_火22
# 384    1301_NTV_水22
# 385    1301_TBS_木21
# 386     1301_EX_木21
# 387     1301_CX_木22
# 388    1301_NTV_木23
# 389    1301_TBS_金22
# 390     1301_EX_金23
# 391    1301_NTV_土21
# 392     1301_CX_土23
# 393    1301_TBS_日21
# 394     1301_CX_日21
# 395    1210_TBS_月20
# 396     1210_CX_月21
# 397     1210_CX_火21
# 398     1210_CX_火22
# 399    1210_NTV_水22
# 400     1210_EX_木21
# 401    1210_TBS_木21
# 402     1210_CX_木22
# 403    1210_NTV_木23
# 404    1210_TBS_金22
# 405     1210_EX_金23
# 406    1210_NTV_土21
# 407     1210_CX_土23
# 408    1210_TBS_日21
# 409     1210_CX_日21
# 410    1207_TBS_月20
# 411     1207_CX_月21
# 412     1207_CX_火21
# 413     1207_CX_火22
# 414    1207_NTV_水22
# 415     1207_EX_木21
# 416    1207_TBS_木21
# 417     1207_CX_木22
# 418    1207_NTV_木23
# 419    1207_TBS_金22
# 420     1207_EX_金23
# 533    1007_NTV_木23
# 534     1007_EX_金21
# 535    1007_TBS_金22
# 536     1007_EX_金23
# 537    1007_TBS_土20
# 538    1007_NTV_土21
# 539    1007_TBS_日21
# 540     1004_CX_月21
# 541     1004_CX_火21
# 542     1004_CX_火22
# 543     1004_EX_水21
# 544    1004_NTV_水22
# 545     1004_EX_木21
# 546     1004_CX_木22
# 547    1004_NTV_木23
# 548     1004_EX_金21
# 549    1004_TBS_金22
# 550     1004_EX_金23
# 551     1004_EX_金23
# 552    1004_TBS_土20
# 553    1004_NTV_土21
# 554    1004_TBS_日21
# 555     1004_EX_日23
# 556    1001_TBS_月20
# 557     1001_CX_月21
# 558     1001_CX_火21
# 559     1001_CX_火22
# 560    1001_NTV_水22
# 561     1001_EX_木21
# 562     1001_CX_木22
# 563    1001_NTV_木23
# 564     1001_EX_金21
# 565    1001_TBS_金22
# 566     1001_EX_金23
# 567    1001_TBS_土20
# 568    1001_NTV_土21
# 569    1001_TBS_日21
# 570     0910_CX_月21
# 571     0910_CX_火21
# 572     0910_CX_火22
# 573    0910_TBS_水21
# 574    0910_NTV_水22
# 575     0910_EX_木21
# 576     0910_CX_木22
# 577    0910_NTV_木23
# 578     0910_EX_金21
# 579    0910_TBS_金22
# 580     0910_EX_金23
# 581    0910_TBS_土20
# 582    0910_NTV_土21
# 583    0910_TBS_日21
# 584     0907_CX_月21
# 585     0907_CX_火21
# 586     0907_CX_火22
# 587    0907_TBS_水21
# 588    0907_NTV_水22
# 589     0907_EX_木21
# 590     0907_CX_木22
# 591    0907_NTV_木23
# 592     0907_EX_金21
# 593    0907_TBS_金22
# 594     0907_EX_金23
# 595    0907_TBS_土20
# 596    0907_NTV_土21
# 597     0907_CX_土23
# 598    0907_TBS_日21
# 599    0904_TBS_月20
# 600     0904_CX_月21
# 601     0904_CX_火21
# 602     0904_CX_火22
# 603    0904_TBS_水21
# 604     0904_EX_水21
# 605    0904_NTV_水22
# 606     0904_EX_木21
# 607     0904_CX_木22
# 608    0904_NTV_木23
# 609     0904_EX_金21
# 610    0904_TBS_金22
# 611     0904_EX_金23
# 612    0904_TBS_土20
# 613    0904_TBS_土20
# 614    0904_NTV_土21
# 615     0904_CX_土23
# 616     0904_CX_土23
# 617    0904_TBS_日21
# 618     0901_CX_月21
# 619     0901_CX_火21
# 620     0901_CX_火22
# 621    0901_NTV_火22
# 622    0901_NTV_水22
# 623     0901_EX_木21
# 624     0901_CX_木22
# 625    0901_NTV_木23
# 626     0901_EX_金21
# 627    0901_TBS_金22
# 628     0901_EX_金23
# 629    0901_TBS_土20
# 630    0901_NTV_土21
# 631     0901_CX_土23
# 632    0901_TBS_日21
# 633     0810_CX_月21
# 634     0810_CX_火21
# 635     0810_CX_火22
# 636    0810_NTV_火22
# 637    0810_NTV_水22
# 638     0810_EX_木21
# 639     0810_CX_木22
# 640    0810_NTV_木23
# 641     0810_EX_金21
# 642    0810_TBS_金22
# 643     0810_EX_金23
# 644    0810_TBS_土20
# 870    0404_TBS_木22
# 871     0404_CX_木22
# 872    0404_TBS_金22
# 873     0404_EX_金23
# 874    0404_NTV_土21
# 875    0404_TBS_日21
# 876     0401_CX_月21
# 877    0401_NTV_月22
# 878     0401_CX_火21
# 879     0401_CX_火22
# 880    0401_TBS_水22
# 881    0401_NTV_水22
# 882    0401_TBS_木21
# 883     0401_EX_木21
# 884    0401_TBS_木22
# 885     0401_CX_木22
# 886    0401_TBS_金22
# 887     0401_EX_金23
# 888    0401_NTV_土21
# 889    0401_TBS_日21
# 890     0310_CX_月21
# 891    0310_NTV_月22
# 892     0310_CX_火21
# 893     0310_CX_火22
# 894    0310_TBS_水22
# 895    0310_NTV_水22
# 896    0310_TBS_木21
# 897     0310_EX_木21
# 898    0310_TBS_木22
# 899     0310_CX_木22
# 900    0310_TBS_金22
# 901    0310_NTV_土21
# 902    0310_TBS_日21
# 903     0307_CX_月21
# 904    0307_NTV_月22
# 905     0307_CX_火21
# 906     0307_CX_火22
# 907    0307_TBS_水22
# 908    0307_NTV_水22
# 909    0307_TBS_木21
# 910     0307_EX_木21
# 911    0307_TBS_木22
# 912     0307_CX_木22
# 913    0307_TBS_金22
# 914    0307_NTV_土21
# 915    0307_TBS_日21
# 916     0304_CX_月21
# 917    0304_NTV_月22
# 918     0304_CX_火21
# 919     0304_CX_火22
# 920     0304_CX_水21
# 921    0304_TBS_水22
# 922    0304_TBS_木21
# 923     0304_EX_木21
# 924    0304_TBS_木22
# 925     0304_CX_木22
# 926    0304_TBS_金22
# 927    0304_NTV_土21
# 928    0304_TBS_日21
# 929     0301_CX_月21
# 930    0301_NTV_月22
# 931     0301_CX_火21
# 932     0301_CX_火22
# 933     0301_CX_水21
# 934    0301_TBS_水22
# 935    0301_NTV_水22
# 936     0301_EX_木21
# 937    0301_TBS_木22
# 938     0301_CX_木22
# 939    0301_TBS_金22
# 940    0301_NTV_土21
# 941    0301_TBS_日21
# Name: drama_key, dtype: object

# %%
# URLごとにスクレイピングを行う
def scraping(url):
    
    #ページに複数ある対象部分を取得する
    html = request.urlopen(url)
    soup = BeautifulSoup(html, fromEncoding="utf-8")
    # cast
    tmp_drama_desc_dict = {}
#     for dt in drama_info_tables:
#         cye-lm-tag
    
    drama_title = soup.select('h2')[0].select('.bottom')[0]
#     drama_title = drama_desc[0].select('.cye-lm-tag')
    print(drama_title.text)
    
    drama_desc = soup.select('#exp_det_all')[0] 
    print(drama_desc.text)
    
    drama_info = soup.select('#drama_det_all')[0]
    breakpoint()
    print(drama_info.text)
    
#     breakpoint()
    # <フジテレビ>などを消す
#         [drama_title, TV_station] = reshape_title(drama_title[0].text)
        # キャストスタッフは調整中
#         cast_staff_value = reshape_cast_staff(str(cast_staff[0]))
        
        # 曜日時間
#         weekday_time_value = get_weekday_time(dt)
        # キーの作成 ex) 1710_EX_月21
#         drama_key = start_at + "_" + TV_station + "_" + weekday_time_value
        
#         drama_key = minor_correction(drama_key)
        
#         tmp_drama_info_dict[drama_key] = { "drama_title": drama_title, "TV_station": TV_station, \
#                                           "drama_info" : cast_staff_value}
    
    return tmp_drama_desc_dict

# %%
scraping("http://www.tvdrama-db.com/drama_info/p/id-55112")
scraping("http://www.tvdrama-db.com/drama_info/p/id-60465")
# Out:
# ショムニ2013
#
# 										今から10年前、会社から何の役にも立たないゴミ同然の存在だと烙印を押された社員が送り込まれた部署があった…。その名は「庶務二課」。しかし、その薄暗い庶務二課の部屋で、その生活を楽しむ者たちが現れた。彼女たちは欲望のままに行動し、結果的に会社を救い退職していった。そして「ショムニ」は廃止され、坪井千夏（江角マキコ）は消息不明に…。それから10年後…。日本は長い不況に陥りリストラの嵐が吹き荒れる。もちろん、満帆商事にも…。オリンピックを期待される棒高跳びの選手だった円山詩織（本田翼）は、広告塔として入社したが、ケガで選手生命を絶たれ、陸上部も廃止になり社内で邪魔扱いされ、悪口のツイッター攻撃も受けていた…。社員食堂にいても詩織には誰も近づかない。そんな中で、彼女にストレートな行動を取るOLたちが現れる。ネットに精通した頭脳明晰女子・三波まどか（ベッキー）、気配を感じさせない不気味女子・安倍麗子（安藤サクラ）、フェロモン全開お色気女子・小島美鈴（森カンナ）、そして健康オタクのおしゃべり女子・福田益代（堀内敬子）だ。ある日、落ち込む詩織は1人の女性に出会う。誰かに追われている彼女は、突然詩織の財布からタクシー代として1万円を抜き取り、去っていった…。翌日、出社した詩織は同じ女性の姿を目撃する。彼女こそ「伝説の女」坪井千夏だった。いったいなぜ、彼女は再び満帆商事に姿を現したのか!?【以上、フジテレビ広報資料より引用】協力：バスク、フジアール、ベイシス。車輌：ファン、コマツサポートサービス。提供：花王、ホンダ、アイフル、アコム、モビット、小林製薬(1)-(3)、YKK AP(1)-(3)、GALAXY S4(4)-(10)、サントリー(4)-(7)、今夜アナタと眠りたい(8)-(10)。特別協力：東京湾クルーズ・レストランシップ(9)。【データ協力：LED】
#
# > <ipython-input-10-e149468e4804>(21)scraping()
# -> print(drama_info.text)
# (Pdb) drama_info
# <div id="drama_det_all">
# <table><tbody>
# <tr>
# <td class="info_index drama_info_index">キー局</td>
# <td class="drama_info_area">CX</td>
# <td class="info_index drama_info_index">放送曜日</td>
# <td>水</td>
# <td class="info_index drama_info_index">放送期間</td>
# <td>2013/07/10～2013/09/18</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">放送時間</td>
# <td>22:00-22:54</td>
# <td class="info_index drama_info_index">放送回数</td>
# <td> </td>
# <td class="info_index drama_info_index">連続/単発</td>
# <td>連続</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">主な出演</td>
# <td colspan="5"><a href="/name/p/type-CAST=keyex-%E6%B1%9F%E8%A7%92%E3%83%9E%E3%82%AD%E3%82%B3">江角マキコ</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E3%83%99%E3%83%83%E3%82%AD%E3%83%BC">ベッキー</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E6%9C%AC%E7%94%B0%E3%80%80%E3%80%80%E7%BF%BC">本田　　翼</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%AE%89%E8%97%A4%E3%82%B5%E3%82%AF%E3%83%A9">安藤サクラ</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E6%A3%AE%E3%80%80%E3%82%AB%E3%83%B3%E3%83%8A">森　カンナ</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%A0%80%E5%86%85%E3%80%80%E6%95%AC%E5%AD%90">堀内　敬子</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E4%B8%89%E6%B5%A6%E3%80%80%E7%BF%94%E5%B9%B3">三浦　翔平</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E7%89%87%E7%80%AC%E3%80%80%E9%82%A3%E5%A5%88">片瀬　那奈</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%AE%89%E7%94%B0%E3%80%80%E3%80%80%E9%A1%95">安田　　顕</a>(<a href="/name/p/type-CAST=keyex-TEAM+NACS">TEAM NACS</a>)(1)-(10)、<a href="/name/p/type-CAST=keyex-%E9%88%B4%E6%9C%A8%E3%80%80%E6%B5%A9%E4%BB%8B">鈴木　浩介</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%8D%87%E3%80%80%E3%80%80%E3%80%80%E6%AF%85">升　　　毅</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%B0%8F%E6%9D%BE%E3%80%80%E5%92%8C%E9%87%8D">小松　和重</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E9%9B%A3%E6%B3%A2%E3%80%80%E5%9C%AD%E4%B8%80">難波　圭一</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E9%9A%88%E9%83%A8%E3%80%80%E6%B4%8B%E5%B9%B3">隈部　洋平</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E6%B3%89%E3%80%80%E3%80%80%E9%87%8C%E9%A6%99">泉　　里香</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E9%AB%98%E7%94%B0%E3%80%80%E6%9C%89%E7%B4%97">高田　有紗</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E6%9D%B1%E9%87%8E%E3%80%80%E4%BD%91%E7%BE%8E">東野　佑美</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%B7%A5%E8%97%A4%E9%98%BF%E9%A0%88%E5%8A%A0">工藤阿須加</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E4%B8%8A%E5%9C%B0%E3%80%80%E6%98%A5%E5%A5%88">上地　春奈</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E6%A4%8D%E6%9C%A8%E3%80%80%E5%A4%8F%E5%8D%81">植木　夏十</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E7%94%B0%E5%B3%B6%E3%82%86%E3%81%BF%E3%81%8B">田島ゆみか</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E8%8F%85%E6%B2%A2%E3%81%93%E3%82%86%E3%81%8D">菅沢こゆき</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E5%B8%82%E6%88%90%E3%81%BF%E3%82%86%E3%81%8D">市成みゆき</a>(1)-(10)、<a href="/name/p/type-CAST=keyex-%E6%A3%AE%E6%9C%AC%E3%80%80%E3%83%AC%E3%82%AA">森本　レオ</a>（語りも）(1)、<a href="/name/p/type-CAST=keyex-%E9%AB%98%E6%A9%8B%E3%80%80%E5%85%8B%E5%AE%9F">高橋　克実</a>(1)、<a href="/name/p/type-CAST=keyex-%E9%AB%98%E6%A9%8B%E7%94%B1%E7%BE%8E%E5%AD%90">高橋由美子</a>(1)、<a href="/name/p/type-CAST=keyex-%E4%BA%AC%E9%87%8E%E3%81%93%E3%81%A8%E3%81%BF">京野ことみ</a>(1)、<a href="/name/p/type-CAST=keyex-%E6%AB%BB%E4%BA%95%E3%80%80%E6%B7%B3%E5%AD%90">櫻井　淳子</a>(1)、<a href="/name/p/type-CAST=keyex-%E6%88%B8%E7%94%B0%E3%80%80%E6%81%B5%E5%AD%90">戸田　恵子</a>(1)、<a href="/name/p/type-CAST=keyex-%E5%AE%9D%E7%94%9F%E3%80%80%E3%80%80%E8%88%9E+">宝生　　舞 </a>(1) （写真）、<a href="/name/p/type-CAST=keyex-%E7%9F%B3%E9%BB%92%E3%80%80%E3%80%80%E8%B3%A2">石黒　　賢</a>(1)(10)（(1)<a href="/name/p/type-CAST=keyex-%E3%81%AF%E5%86%99%E7%9C%9F">は写真</a>）、<a href="/name/p/type-CAST=keyex-%E5%A4%A7%E9%AB%98%E3%80%80%E6%B4%8B%E5%A4%AB">大高　洋夫</a>(1)、<a href="/name/p/type-CAST=keyex-%E5%85%90%E7%8E%89%E3%80%80%E9%A0%BC%E4%BF%A1">児玉　頼信</a>(1)(4)(5)(9)、<a href="/name/p/type-CAST=keyex-%E5%B9%B3%E5%B7%9D%E3%80%80%E5%92%8C%E5%AE%8F">平川　和宏</a>(1)(5)(9)、<a href="/name/p/type-CAST=keyex-%E4%B8%B8%E5%B2%A1%E7%9C%9F%E7%94%B1%E5%AD%90">丸岡真由子</a>(1)、<a href="/name/p/type-CAST=keyex-%E6%97%A9%E5%B7%9D%E3%80%80%E4%BA%9C%E5%B8%8C">早川　亜希</a>(1)(4)、<a href="/name/p/type-CAST=keyex-%E7%94%B1%E5%88%A9%E3%80%80%E5%B0%9A%E5%AD%90">由利　尚子</a>(1)、<a href="/name/p/type-CAST=keyex-%E4%B8%8A%E5%8E%9F%E3%80%80%E6%95%A6%E5%AD%90">上原　敦子</a>(1)、<a href="/name/p/type-CAST=keyex-%E6%96%89%E8%97%A4%E3%80%80%E4%BD%91%E4%BB%8B">斉藤　佑介</a>(1)、<a href="/name/p/type-CAST=keyex-%E6%9D%BE%E6%B0%B8%E3%80%80%E5%81%A5%E5%BF%97">松永　健志 ...
# </tr>
# <tr>
# <td class="info_index drama_info_index">主な脚本</td>
# <td colspan="5"><a href="/name/p/type-KYAKUHON=keyex-%E4%B8%91%E5%B0%BE%E5%81%A5%E5%A4%AA%E9%83%8E">丑尾健太郎</a>(1)(5)(8)、<a href="/name/p/type-KYAKUHON=keyex-%E5%A4%A7%E6%B5%A6%E5%85%89%E5%A4%AA">大浦光太</a>(2)(3)(7)、<a href="/name/p/type-KYAKUHON=keyex-%E5%8C%97%E5%B7%9D%E4%BA%9C%E7%9F%A2%E5%AD%90">北川亜矢子</a>(4)、<a href="/name/p/type-KYAKUHON=keyex-%E6%A3%AE%E3%80%80%E3%83%8F%E3%83%A4%E3%82%B7">森　ハヤシ</a>(6)(9)(10)、（脚本協力：<a href="/name/p/type-KYAKUHON=keyex-%E4%B8%91%E5%B0%BE%E5%81%A5%E5%A4%AA%E9%83%8E">丑尾健太郎</a>(2)(10)、<a href="/name/p/type-KYAKUHON=keyex-%E5%9D%AA%E7%94%B0%E3%80%80%E3%80%80%E6%96%87">坪田　　文</a>(2)、<a href="/name/p/type-KYAKUHON=keyex-%E9%AB%98%E5%B1%B1%E3%80%80%E7%9B%B4%E4%B9%9F">高山　直也</a>(5)、<a href="/name/p/type-KYAKUHON=keyex-%E5%A4%A7%E6%B5%A6%E3%80%80%E5%85%89%E5%A4%AA">大浦　光太</a>(10)）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">主なﾌﾟﾛﾃﾞｭｰｻ</td>
# <td colspan="5">（プロデュース：<a href="/name/p/type-PRODUCER=keyex-%E5%B2%A9%E7%94%B0%E3%80%80%E7%A5%90%E4%BA%8C">岩田　祐二</a>）（ラインプロデュース：<a href="/name/p/type-PRODUCER=keyex-%E6%B1%9F%E6%A3%AE%E3%80%80%E6%B5%A9%E5%AD%90">江森　浩子</a>）（プロデュース補：<a href="/name/p/type-PRODUCER=keyex-%E9%96%A2%E6%9C%AC%E3%80%80%E7%B4%94%E4%B8%80">関本　純一</a>(1)-(10)、<a href="/name/p/type-PRODUCER=keyex-%E4%BD%90%E3%80%85%E6%9C%A8%E3%80%80%E8%B1%AA">佐々木　豪</a>）（広報：<a href="/name/p/type-PRODUCER=keyex-%E9%88%B4%E6%9C%A8%E3%80%80%E8%89%AF%E5%AD%90">鈴木　良子</a>(CX)）（スチール：<a href="/name/p/type-PRODUCER=keyex-%E6%9D%BE%E5%8E%9F%E3%80%80%E7%9B%B4%E5%BD%A6">松原　直彦</a>）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">主な演出</td>
# <td colspan="5"><a href="/name/p/type-ENSHUTSU=keyex-%E9%88%B4%E6%9C%A8%E3%80%80%E9%9B%85%E4%B9%8B">鈴木　雅之</a>(CX)(1)(2)(6)(10)、<a href="/name/p/type-ENSHUTSU=keyex-%E5%B0%8F%E6%9E%97%E3%80%80%E7%BE%A9%E5%89%87">小林　義則</a>(3)(5)(7)(9)、<a href="/name/p/type-ENSHUTSU=keyex-%E4%BD%90%E8%97%A4%E3%80%80%E6%BA%90%E5%A4%AA">佐藤　源太</a>(4)(8)、（演出補：<a href="/name/p/type-ENSHUTSU=keyex-%E5%80%89%E6%9C%A8%E3%80%80%E7%BE%A9%E5%85%B8">倉木　義典</a>）（演出助手：<a href="/name/p/type-ENSHUTSU=keyex-%E7%B4%99%E8%B0%B7%E3%80%80%E3%80%80%E6%A5%93">紙谷　　楓</a>、<a href="/name/p/type-ENSHUTSU=keyex-%E6%9C%A8%E6%9D%91%E3%80%80%E7%9C%9F%E4%BA%BA">木村　真人</a>、<a href="/name/p/type-ENSHUTSU=keyex-%E5%B0%BE%E8%8A%B1%E3%80%80%E7%91%9B%E4%BB%81">尾花　瑛仁</a>、<a href="/name/p/type-ENSHUTSU=keyex-%E5%A4%A7%E5%85%AB%E6%9C%A8%E3%80%80%E5%92%B2">大八木　咲</a>)）（スクリプター：<a href="/name/p/type-ENSHUTSU=keyex-%E7%A8%B2%E7%94%B0%E9%BA%BB%E7%94%B1%E5%AD%90">稲田麻由子</a>(1)(2)(5)(6)、<a href="/name/p/type-ENSHUTSU=keyex-%E6%9D%BE%E5%85%83%E3%80%80%E3%80%80%E6%99%AF">松元　　景</a>(3)(4)(7)、<a href="/name/p/type-ENSHUTSU=keyex-%E6%B0%B4%E5%8F%A3%E3%80%80%E8%A3%95%E5%AD%90">水口　裕子</a>(8)(10)、<a href="/name/p/type-ENSHUTSU=keyex-%E8%97%A4%E5%B3%B6%E3%80%80%E7%90%86%E6%81%B5">藤島　理恵</a>(9)）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">原作</td>
# <td colspan="5"><a href="/name/p/type-GENSAKU=keyex-%E5%AE%89%E7%94%B0%E3%80%80%E5%BC%98%E4%B9%8B">安田　弘之</a>「ショムニ」（メディアファクトリー）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">局系列</td>
# <td colspan="5">FNN</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">制作会社</td>
# <td colspan="5">（制作著作：共同テレビジョン）（制作：CX）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">制作</td>
# <td colspan="5">（制作担当：持田　一政）（制作主任：田村　　豊、皆川なぎさ）（制作進行：大久保公路、小野寺詠美）（スタントコーディネート：釼持　　誠(1)）（スケジュール：吉田　使憲(1)-(5)(10)、佐々木詳太(6)-(10)）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">企画</td>
# <td colspan="5">（編成：<a href="/name/p/type-KIKAKU=keyex-%E4%BD%90%E8%97%A4%E3%80%80%E6%9C%AA%E9%83%B7">佐藤　未郷</a>(CX)(1)、<a href="/name/p/type-KIKAKU=keyex-%E4%B8%8B%E5%B7%9D%E3%80%80%E3%80%80%E7%8C%9B">下川　　猛</a>(CX)）（編成企画：<a href="/name/p/type-KIKAKU=keyex-%E7%9F%B3%E4%BA%95%E3%80%80%E6%B5%A9%E4%BA%8C">石井　浩二</a>(CX)、<a href="/name/p/type-KIKAKU=keyex-%E6%B8%85%E6%B0%B4%E3%80%80%E4%B8%80%E5%B9%B8">清水　一幸</a>(CX)）（広告宣伝：<a href="/name/p/type-KIKAKU=keyex-%E6%9C%8D%E9%83%A8%E4%BD%90%E7%9F%A5%E5%AD%90">服部佐知子</a>(CX)）（ホームページ：<a href="/name/p/type-KIKAKU=keyex-%E9%A0%88%E4%B9%8B%E5%86%85%E9%81%94%E4%B9%9F">須之内達也</a>(CX)）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">音楽</td>
# <td colspan="5"><a href="/name/p/type-MUSIC=keyex-%E5%A4%A7%E5%B3%B6%E3%83%9F%E3%83%81%E3%83%AB">大島ミチル</a>、（MA：<a href="/name/p/type-MUSIC=keyex-%E5%B8%82%E6%9D%91%E3%80%80%E8%81%A1%E9%9B%84">市村　聡雄</a>）（音響効果：<a href="/name/p/type-MUSIC=keyex-%E4%B8%8A%E7%94%B0%E7%9C%9F%E7%90%86%E9%A6%99">上田真理香</a>）（選曲：<a href="/name/p/type-MUSIC=keyex-%E8%97%A4%E6%9D%91%E3%80%80%E7%BE%A9%E5%AD%9D">藤村　義孝</a>）（音楽協力：フジパシフィック音楽出版、<a href="/name/p/type-MUSIC=keyex-%E3%83%AD%E3%83%83%E3%82%AF%E3%83%AA%E3%83%90%E3%83%BC">ロックリバー</a>）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">主題歌</td>
# <td colspan="5"><a href="/name/p/type-SONG=keyex-Serena">Serena</a>「ピンクの弾丸」（<a href="/name/p/type-SONG=keyex-%E3%82%A2%E3%83%AA%E3%82%AA%E3%83%A9%E3%82%B8%E3%83%A3%E3%83%91%E3%83%B3">アリオラジャパン</a>）</td>
# </tr>
# <tr>
# <td class="info_index drama_info_index">撮影技術</td>
# <td colspan="5"><a href="/name/p/type-TECNIQUE=keyex-%E4%BC%8A%E8%97%A4%E3%80%80%E6%B8%85%E4%B8%80">伊藤　清一</a>、（TD：<a href="/name/p/type-TECNIQUE=keyex-%E7%99%BD%E4%BA%95%E3%80%80%E5%93%B2%E7%9F%A2">白井　哲矢</a>）（技術プロデュース：<a href="/name/p/type-TECNIQUE=keyex-%E5%8F%8B%E9%83%A8%E3%80%80%E7%AF%80%E5%AD%90">友部　節子</a>）（照明：<a href="/name/p/type-TECNIQUE=keyex-%E9%98%BF%E9%83%A8%E3%80%80%E6%85%B6%E6%B2%BB">阿部　慶治</a>、<a href="/name/p/type-TECNIQUE=keyex-%E6%A4%99%E6%B5%A6%E3%80%80%E6%98%8E%E8%A6%8F">椙浦　明規</a>(1)(10)）（音声：<a href="/name/p/type-TECNIQUE=keyex-%E5%B3%B6%E7%94%B0%E3%80%80%E9%9A%86%E9%9B%84">島田　隆雄</a>）（映像：<a href="/name/p/type-TECNIQUE=keyex-%E6%A1%9C%E5%BA%AD%E3%80%80%E6%AD%A6%E5%BF%97">桜庭　武志</a>）（スタジオカメラ：<a href="/name/p/type-TECNIQUE=keyex-%E5%B1%B1%E4%B8%8B%E3%80%80%E6%99%BA%E5%BA%B7">
4%E3%80%80%E3%80%80%E5%81%A5">後藤　　健</a>）（生花装飾：<a href="/name/p/type-ART=keyex-%E7%89%A7%E5%B3%B6%E3%80%80%E7%BE%8E%E6%81%B5">牧島　美恵</a>）（フードコーディネーター：<a href="/name/p/type-ART=keyex-%E3%81%AF%E3%82%89%E3%82%86%E3%81%86%E3%81%93">はらゆうこ</a>(7)(10)）（タイトル：<a href="/name/p/type-ART=keyex-%E7%94%B0%E4%B8%AD%E3%80%80%E8%B2%B4%E5%BF%97">田中　貴志</a>（CGも））</td>
# </tr>
# </tbody></table>
# </div>

# %%
###########
# 実行本体
#
drama_desc_dict = {}
for tmp_did in range(30000, 67000):
    
    tmp_url = "http://www.tvdrama-db.com/drama_info/p/id-" + str(tmp_did)
    print (tmp_url)
    tmp_drama_desc_dict = scraping(tmp_url)
#     drama_desc_dict.update(tmp_drama_desc_dict)

import pprint
pprint.pprint(drama_info_dict)
# Out:
# http://www.tvdrama-db.com/drama_info/p/id-30000
# > <ipython-input-9-90db86b5f0a1>(10)<module>()
# -> tmp_drama_desc_dict = scraping(tmp_url)
# (Pdb) n
# 偽装結婚－愛は国境を越えて－　男は三百万円で戸籍を売った・女は明日を夢見た・しかし、悲劇は口を開けて待っていた！
#
# 										タクシードライバーの良治（古谷一行）は借金を返すために戸籍を売っていた。ある日、在留資格のために良治と結婚したいという中国人女性（秋野暢子）がやってくる。入国管理局の疑惑を晴らすため一緒に暮らしはじめた二人の間にやがて愛が…（スター名鑑'94）。
#
#
#
#
# キー局
# TBS
# 放送曜日
# 月
# 放送期間
# 1994/02/28～1994/02/28
#
#
# 放送時間
# 21:00-22:54
# 放送回数
# 1 回
# 連続/単発
# 単発
#
#
# 番組名
# 月曜ドラマスペシャル
#
#
# 主な出演
# 古谷　一行、秋野　暢子、白　　　竜、山田　吾一、池田　貴尉、清水ひとみ（※1962/02/17生まれ）、阿部　裕二
#
#
# 主な脚本
# 金子　　裕
#
#
# 主な演出
# 土屋統吾郎
#
#
# 局系列
# JNN
#
#
# 制作会社
# スタープロジェクト、TBS
#
#
#
# > <ipython-input-9-90db86b5f0a1>(5)<module>()
# -> for tmp_did in range(30000, 67000):
# (Pdb) drama_info[0]
# *** NameError: name 'drama_info' is not defined
# (Pdb) in
# *** SyntaxError: invalid syntax
# (Pdb) enter
# *** NameError: name 'enter' is not defined
# (Pdb) s
# > <ipython-input-9-90db86b5f0a1>(7)<module>()
# -> tmp_url = "http://www.tvdrama-db.com/drama_info/p/id-" + str(tmp_did)
# (Pdb) s
# > <ipython-input-9-90db86b5f0a1>(8)<module>()
# -> print (tmp_url)
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(382)write()
# -> def write(self, string):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(383)write()
# -> if self.echo is not None:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(391)write()
# -> if self.pub_thread is None:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(395)write()
# -> if not isinstance(string, unicode_type):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(398)write()
# -> is_child = (not self._is_master_process())
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(307)_is_master_process()
# -> def _is_master_process(self):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(308)_is_master_process()
# -> return os.getpid() == self._master_pid
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(308)_is_master_process()->True
# -> return os.getpid() == self._master_pid
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(400)write()
# -> self.pub_thread.schedule(lambda : self._buffer.write(string))
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(195)schedule()
# -> def schedule(self, f):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(200)schedule()
# -> if self.thread.is_alive():
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1080)is_alive()
# -> def is_alive(self):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1088)is_alive()
# -> assert self._initialized, "Thread.__init__() not called"
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1089)is_alive()
# -> if self._is_stopped or not self._started.is_set():
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(507)is_set()
# -> def is_set(self):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(509)is_set()
# -> return self._flag
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(509)is_set()->True
# -> return self._flag
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1091)is_alive()
# -> self._wait_for_tstate_lock(False)
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1038)_wait_for_tstate_lock()
# -> def _wait_for_tstate_lock(self, block=True, timeout=-1):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1045)_wait_for_tstate_lock()
# -> lock = self._tstate_lock
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1046)_wait_for_tstate_lock()
# -> if lock is None:  # already determined that the C code is done
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1048)_wait_for_tstate_lock()
# -> elif lock.acquire(block, timeout):
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1048)_wait_for_tstate_lock()->None
# -> elif lock.acquire(block, timeout):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1092)is_alive()
# -> return not self._is_stopped
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1092)is_alive()->True
# -> return not self._is_stopped
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(201)schedule()
# -> self._events.append(f)
# (Pdb) s
# http://www.tvdrama-db.com/drama_info/p/id-30001> /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(203)schedule()
# -> self._event_pipe.send(b'')
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(93)_event_pipe()
# -> @property
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(96)_event_pipe()
# -> try:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(97)_event_pipe()
# -> event_pipe = self._local.event_pipe
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(105)_event_pipe()
# -> return event_pipe
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(105)_event_pipe()-><zmq.sugar.so...t 0x10ea0c6c8>
# -> return event_pipe
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py(337)send()
# -> def send(self, data, flags=0, copy=True, track=False, routing_id=None, group=None):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py(385)send()
# -> if routing_id is not None:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py(390)send()
# -> if group is not None:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py(395)send()
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py(395)send()->None
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(203)schedule()->None
# -> self._event_pipe.send(b'')
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(401)write()
# -> if is_child:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(408)write()
# -> self._schedule_flush()
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(320)_schedule_flush()
# -> def _schedule_flush(self):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(325)_schedule_flush()
# -> if self._flush_pending:
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(327)_schedule_flush()
# -> self._flush_pending = True
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(330)_schedule_flush()
# -> def _schedule_in_thread():
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(332)_schedule_flush()
# -> self.pub_thread.schedule(_schedule_in_thread)
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(195)schedule()
# -> def schedule(self, f):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py(200)schedule()
# -> if self.thread.is_alive():
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1080)is_alive()
# -> def is_alive(self):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1088)is_alive()
# -> assert self._initialized, "Thread.__init__() not called"
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1089)is_alive()
# -> if self._is_stopped or not self._started.is_set():
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(507)is_set()
# -> def is_set(self):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(509)is_set()
# -> return self._flag
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(509)is_set()->True
# -> return self._flag
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1091)is_alive()
# -> self._wait_for_tstate_lock(False)
# (Pdb) s
# --Call--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1038)_wait_for_tstate_lock()
# -> def _wait_for_tstate_lock(self, block=True, timeout=-1):
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1045)_wait_for_tstate_lock()
# -> lock = self._tstate_lock
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1046)_wait_for_tstate_lock()
# -> if lock is None:  # already determined that the C code is done
# (Pdb) s
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1048)_wait_for_tstate_lock()
# -> elif lock.acquire(block, timeout):
# (Pdb) s
# --Return--
# > /Users/yoshimurahiroyuki/anaconda3/lib/python3.7/threading.py(1048)_wait_for_tstate_lock()->None
# -> elif lock.acquire(block, timeout):
# (Pdb) quit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-9-90db86b5f0a1> in <module>
#       6
#       7     tmp_url = "http://www.tvdrama-db.com/drama_info/p/id-" + str(tmp_did)
# ----> 8     print (tmp_url)
#       9     breakpoint()
#      10     tmp_drama_desc_dict = scraping(tmp_url)
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     406                     self.flush()
#     407             else:
# --> 408                 self._schedule_flush()
#     409
#     410     def writelines(self, sequence):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in _schedule_flush(self)
#     330         def _schedule_in_thread():
#     331             self._io_loop.call_later(self.flush_interval, self._flush)
# --> 332         self.pub_thread.schedule(_schedule_in_thread)
#     333
#     334     def flush(self):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     198         If the thread is not running, call immediately.
#     199         """
# --> 200         if self.thread.is_alive():
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
#
# ~/anaconda3/lib/python3.7/threading.py in is_alive(self)
#    1089         if self._is_stopped or not self._started.is_set():
#    1090             return False
# -> 1091         self._wait_for_tstate_lock(False)
#    1092         return not self._is_stopped
#    1093
#
# ~/anaconda3/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1046         if lock is None:  # already determined that the C code is done
#    1047             assert self._is_stopped
# -> 1048         elif lock.acquire(block, timeout):
#    1049             lock.release()
#    1050             self._stop()
#
# ~/anaconda3/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# ~/anaconda3/lib/python3.7/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
#     155             # The user issued a 'next' or 'until' command.
#     156             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:

# %%
simple_json = {}
for key in drama_info_dict.keys():
    main_actors = drama_info_dict[key]["drama_info"][0].split("、")
    original_work = check_and_get_original_work(drama_info_dict[key]["drama_info"])
#     print(original_work)
    if len(main_actors)>1:
        simple_json[key] = {"main_actor1" : main_actors[0], "main_actor2" : main_actors[1]}
    else:
        simple_json[key] = {"main_actor1" : "", "main_actor2" : ""}
        
    if original_work is not None:
        simple_json[key]["original_work"] = original_work
    else:
        simple_json[key]["original_work"] = ""
        
        #     simple_json[key]["main_actor2"] = main_actors if main_actors[0] else "aa"

print(simple_json)

# %%
import json
fw = open('../data/drama_info0115.json','w')
# json.dump関数でファイルに書き込む
json.dump(simple_json ,fw,indent=4, ensure_ascii=False)
