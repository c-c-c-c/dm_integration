# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#追記
import json
import datetime
import math

#importじゃないけど、個人的には省略されて良いことがあまりないので・・
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)

# %%
regex = r"血液型|事務所|生年月日|出身地|出身|最終学歴|活動期間|職業|ジャンル"

# %%
from urllib import request
from bs4 import BeautifulSoup
import urllib.request
import requests
import re

# %%
# URLごとにスクレイピングを行う
key_list = []

def scraping(url, actor_name):
    #ページに複数ある対象部分を取得する
    html = request.urlopen(url)
    soup = BeautifulSoup(html, fromEncoding="utf-8")
    actor_info_tables = soup.select('.infobox tr')
    
    tmp_actor_profile_dict = {actor_name : None}
    for i, dt in enumerate(actor_info_tables):
#         breakpoint()
        print(type(dt.contents))
        if type(dt.contents) is list and len(dt.contents) > 1:
            try:
                search_result = re.search(regex,str(dt.contents[0].text))
            except AttributeError ,e:
                print(actor_name)
            
            if search_result is not None:
                print("key:"+str(dt.contents[0].text))
                print("val:"+str(dt.contents[1].text))

                tmp_actor_profile_dict[dt.contents[0].text] = dt.contents[1].text
                
    return tmp_actor_profile_dict

# %%
import json

f = open("../data/drama_info0115.json", 'r')
print(f)
drama_info_json = json.load(f)
# Out:
# <_io.TextIOWrapper name='../data/drama_info0115.json' mode='r' encoding='UTF-8'>

# %%
actor_actress_list =[]

for tmp_key in drama_info_json:
    
    actor_actress_list.append(drama_info_json[tmp_key].get("main_actor1"))
    actor_actress_list.append(drama_info_json[tmp_key].get("main_actor2"))

# %%
actor_actress_list = list(set(actor_actress_list))

# %%
actor_actress_list
# Out:
# ['沢村一樹',
#  '',
#  '安藤政信',
#  '時任三郎',
#  '芦名星',
#  '高島礼子',
#  '伊東美咲',
#  '高良健吾',
#  '中島裕翔',
#  '平岡祐太',
#  '大塚寧々',
#  '菅田将暉',
#  '筒井道隆',
#  '飯島直子',
#  '岩田剛典',
#  '間宮祥太朗',
#  '桜井日奈子',
#  '木村多江',
#  '内山理名',
#  '三吉彩花',
#  'チェ・ジウ',
#  '林遣都',
#  '藤井流星',
#  '夏帆',
#  '八嶋智人',
#  '水嶋ヒロ',
#  '香里奈',
#  '岡本綾',
#  '菅野美穂',
#  '吉瀬美智子',
#  '大泉洋',
#  '中山美穂',
#  '三浦貴大',
#  '市原隼人',
#  '豊川悦司',
#  '井上和香',
#  '成宮博貴',
#  '加藤シゲアキ',
#  '江口洋介',
#  '松下由樹',
#  '滝沢秀明',
#  '岡田将生',
#  '水原希子',
#  '高畑淳子',
#  '二宮和也',
#  '山口達也',
#  '麻生久美子',
#  '竜雷太',
#  '東出昌大',
#  '須藤理彩',
#  '西島秀俊',
#  '田中直樹',
#  '夏菜',
#  '沢尻エリカ',
#  '黒島結菜',
#  '山村隆太',
#  '安達祐実',
#  '真中瞳',
#  '稲垣吾郎',
#  '黒木メイサ',
#  '前田敦子',
#  '陣内孝則',
#  '伊藤英明',
#  '柳葉敏郎',
#  '尾野真千子',
#  '臼田あさ美',
#  '高岡早紀',
#  '中条あやみ',
#  '遠藤憲一',
#  '村上知子',
#  '安田顕',
#  '森カンナ',
#  '妻夫木聡',
#  '橋本環奈',
#  '南沢奈央',
#  '和久井映見',
#  '高橋克典',
#  '松村北斗',
#  '真木よう子',
#  '星野真里',
#  'ベッキー',
#  '田中圭',
#  'ウエンツ瑛士',
#  '小栗旬',
#  '風間杜夫',
#  '田中麗奈',
#  '大後寿々花',
#  '堤真一',
#  '宮川大輔',
#  '山口智充',
#  '田中美佐子',
#  '田中聖',
#  '松本潤',
#  '原田美枝子',
#  '千紗',
#  '波瑠',
#  '斉藤由貴',
#  '金子ノブアキ',
#  '本郷奏多',
#  '京本政樹',
#  '本木雅弘',
#  '賀来賢人',
#  '長谷川京子',
#  '藤原紀香',
#  '浅野温子',
#  '桃井かおり',
#  '岡田結実',
#  '内田有紀',
#  '滝藤賢一',
#  '中谷美紀',
#  '門脇麦',
#  '志尊淳',
#  '山崎育三郎',
#  '国仲涼子',
#  '遠藤雄弥',
#  '小山慶一郎',
#  '海東健',
#  '東山紀之',
#  '宮沢氷魚',
#  '亀梨和也',
#  '原田泰造',
#  '中島健人',
#  '窪田正孝',
#  '高畑充希',
#  '杏',
#  '唐沢寿明',
#  '常盤貴子',
#  '佐藤浩市',
#  '船越英一郎',
#  '新川優愛',
#  '木村佳乃',
#  '寺島しのぶ',
#  '杉咲花',
#  '日向千歩 etc',
#  '中山優馬',
#  '片瀬那奈',
#  '役所広司',
#  'オダギリジョー',
#  '松本穂香',
#  '石田ゆり子',
#  '余貴美子',
#  '菊川怜',
#  '広瀬すず',
#  '菜々緒',
#  '佐々木蔵之介',
#  '小雪',
#  '高嶋政伸',
#  '北川景子',
#  '吉沢亮',
#  'ユースケサンタマリア',
#  '藤井隆',
#  '加藤ローサ',
#  '中川大志',
#  '宮迫博之',
#  '要潤',
#  '渡部篤郎',
#  '佐藤勝利',
#  '野際陽子',
#  '瑛太',
#  '財前直見',
#  '倉科カナ',
#  'GACKT',
#  '庄野崎謙',
#  '高橋真唯',
#  '中村俊介',
#  '原沙知絵',
#  '坂井真紀',
#  '松岡昌宏',
#  '若村麻由美',
#  '羽田美智子',
#  'シャーロット・ケイト・フォックス',
#  '杉本哲太',
#  '観月ありさ',
#  '松下洸平',
#  '松雪泰子',
#  '米倉涼子',
#  '香取慎吾',
#  '渡哲也',
#  'AKIRA',
#  '手越祐也',
#  '青木崇高',
#  '成宮寛貴',
#  '戸田恵梨香',
#  '星野源',
#  '吉田栄作',
#  '山下真司',
#  '吉岡里帆',
#  '宮沢りえ',
#  '清水富美加',
#  '三浦春馬',
#  '大倉忠義',
#  '玉山鉄二',
#  '森山未來',
#  '榮倉奈々',
#  '瀬戸康史',
#  '川口春奈',
#  '井上真央',
#  '長澤まさみ',
#  '本上まなみ',
#  '堂本光一',
#  '濱田岳',
#  '松浦亜弥',
#  '小籔千豊',
#  '高橋克実',
#  '上地雄輔',
#  '永山絢斗',
#  '和田聡宏',
#  '井浦新',
#  '香川照之',
#  '香椎由宇',
#  '優香',
#  '平愛梨',
#  '高梨臨',
#  '山本耕史',
#  '広末涼子',
#  '舘ひろし',
#  '杏さゆり',
#  '大橋のぞみ',
#  '竹内涼真',
#  '山田優',
#  '木村文乃',
#  '有村架純',
#  '金子大地',
#  '山口智子',
#  '稲森いずみ',
#  '板谷由夏',
#  '原田知世',
#  '松山ケンイチ',
#  '伊藤淳史',
#  '田口淳之介',
#  '鈴木砂羽',
#  '松本利夫',
#  '綾部祐二',
#  '菊池風磨',
#  '中井貴一',
#  '峯田和伸',
#  '平野紫耀',
#  '坂口憲二',
#  '田村正和',
#  '\ue225田雅功',
#  '中越典子',
#  '矢部浩之',
#  '原田龍二',
#  '篠原涼子',
#  '小泉今日子',
#  '小出恵介',
#  '田中裕子',
#  '藤ヶ谷太輔',
#  '石黒賢',
#  '工藤阿須加',
#  '永井大',
#  '北川悠仁',
#  '佐藤隆太',
#  '福士蒼汰',
#  '蒼井優',
#  '山\ue1cc賢人',
#  '大倉孝二',
#  '神木隆之介',
#  '伊藤健太郎',
#  '藤原さくら',
#  '仲里依紗',
#  '鈴木梨央',
#  '浅香航大',
#  '深津絵里',
#  '北山宏光',
#  '満島真之介',
#  '明石家さんま',
#  'ゴリ',
#  '浅野忠信',
#  '西村雅彦',
#  '内村光良',
#  '武井咲',
#  '加藤あい',
#  '吉本実憂',
#  '橋本愛',
#  '伊原剛志',
#  '瀧本美織',
#  '田中哲司',
#  'DEAN FUJIOKA',
#  '増田貴久',
#  '古川雄輝',
#  '山田涼介',
#  '松田翔太',
#  '釈由美子',
#  '薬師丸ひろ子',
#  '加藤晴彦',
#  '中村アン',
#  '内田理央',
#  '中丸雄一',
#  '安倍なつみ',
#  '南果歩',
#  '上野樹里',
#  '吉田羊',
#  '酒井法子',
#  '仲間由紀恵',
#  '西野亮廣',
#  '貫地谷しほり',
#  '黒木瞳',
#  '草なぎ剛',
#  '小西真奈美',
#  '山口紗弥加',
#  '佐々木希',
#  '城田優',
#  '板尾創路',
#  '野村周平',
#  '石井杏奈',
#  '小池徹平',
#  '蓮佛美沙子',
#  '草\ue183剛',
#  '眞木大輔',
#  '武田鉄矢',
#  '福山雅治',
#  '桐谷美玲',
#  '小泉孝太郎',
#  '櫻井翔',
#  '比嘉愛未',
#  '中島知子',
#  '柴咲コウ',
#  '堂本剛',
#  '森川葵',
#  '渡辺大知',
#  '夏川結衣',
#  '泉ピン子',
#  '堀北真希',
#  '高橋一生',
#  '鈴木京香',
#  '白洲迅',
#  '青柳翔',
#  '生瀬勝久',
#  '山本裕典',
#  '深田恭子',
#  '忽那汐里',
#  '大沢たかお',
#  '竹中直人',
#  '大森南朋',
#  '西内まりや',
#  'りょう',
#  '玉置浩二',
#  '牧瀬里穂',
#  '吹石一恵',
#  '筧利夫',
#  '水沢エレナ',
#  '相葉雅紀',
#  '平山あや',
#  'ミムラ',
#  '上川隆也',
#  '吉岡秀隆',
#  '志田未来',
#  '西村和彦',
#  '内野聖陽',
#  '櫻井淳子',
#  'トータス松本',
#  '山本美月',
#  '松嶋菜々子',
#  '\ue2d3嶋政宏',
#  '山下智久',
#  '横山裕',
#  '上戸彩',
#  '向井理',
#  '阿部サダヲ',
#  '黒川智花',
#  'ムロツヨシ',
#  '相武紗季',
#  '松たか子',
#  '新垣結衣',
#  '井ノ原快彦',
#  '光浦靖子',
#  '佐藤二朗',
#  '田中奏生',
#  '古田新太',
#  '池田鉄洋',
#  '新木優子',
#  '松本莉緒',
#  '黒木華',
#  '大野智',
#  '酒井若菜',
#  '速水もこみち',
#  '土屋太鳳',
#  '木南晴夏',
#  '田辺誠一',
#  '小澤征悦',
#  '佐藤健',
#  'ディーン・フジオカ',
#  '安めぐみ',
#  '鹿賀丈史',
#  '中村蒼',
#  '仲村トオル',
#  '阿部寛',
#  '北村一輝',
#  '森田剛',
#  '藤木直人',
#  '伊藤歩',
#  '広瀬アリス',
#  '池田一真',
#  '水川あさみ',
#  '吉高由里子',
#  '天海祐希',
#  '松田龍平',
#  '柳楽優弥',
#  '中居正広',
#  '加瀬亮',
#  '谷原章介',
#  '綾瀬はるか',
#  '谷村美月',
#  'ユースケ・サンタマリア',
#  'TAKAHIRO',
#  '北乃きい',
#  '溝端淳平',
#  '吉沢悠',
#  '芳根京子',
#  '赤西仁',
#  '瀬戸朝香',
#  '水野美紀',
#  '椎名桔平',
#  '真矢みき',
#  '玉森裕太',
#  '岸谷五朗',
#  '多部未華子',
#  '三上博史',
#  '生田斗真',
#  '斎藤工',
#  '桐谷健太',
#  '三浦友和',
#  '及川光博',
#  '檀れい',
#  '大島優子',
#  '丸山隆平',
#  '坂口健太郎',
#  '石橋杏奈',
#  '江角マキコ',
#  '今井美樹',
#  '永作博美',
#  '北村有起哉',
#  '小池栄子',
#  '長谷川博己',
#  '松坂桃李',
#  '本田翼',
#  '高橋メアリージュン',
#  '桜庭ななみ',
#  '松下奈緒',
#  'ともさかりえ',
#  '岡田健史',
#  '福田沙紀',
#  '國村隼',
#  '堺正章',
#  '綾野剛',
#  '酒井彩名',
#  '渡辺麻友',
#  '角野卓造',
#  '岡田准一',
#  '塚地武雅',
#  '成海璃子',
#  '竹内結子',
#  '徳重聡',
#  'キム・テヒ',
#  '山崎賢人',
#  '小野ゆり子',
#  '二階堂ふみ',
#  '寺尾聰',
#  '堺雅人',
#  '織田裕二',
#  '三浦翔平',
#  '錦戸亮',
#  '鈴木杏',
#  '松岡茉優',
#  '山田孝之',
#  '永野芽郁',
#  '長瀬智也',
#  '押尾学',
#  '渡辺直美',
#  '塚本高史',
#  '伊野尾慧',
#  '室井滋',
#  '玉木宏',
#  '吉田鋼太郎',
#  '松坂慶子',
#  '芦田愛菜',
#  '小日向文世',
#  '南明奈',
#  '石原さとみ',
#  '木村拓哉',
#  '剛力彩芽',
#  '石塚英彦',
#  '内博貴',
#  '満島ひかり',
#  '矢田亜希子',
#  '反町隆史',
#  '武田真治',
#  '栗山千明',
#  '小林聡美',
#  '藤原竜也',
#  '竹野内豊',
#  '西岡徳馬']

# %%
import urllib.parse
###########
# 実行本体
###
actor_profile_dict = {}
import pprint
pprint.pprint(actor_profile_dict)

for tmp_name in actor_actress_list:
    actor_name = urllib.parse.quote(tmp_name)
    tmp_actor_profile_dict = scraping("https://ja.wikipedia.org/wiki/"+ actor_name)

    actor_profile_dict.update(tmp_actor_profile_dict)
# Out:
# {}
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1967-07-10) 1967年7月10日（52歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# B型
# <class 'list'>
# key:職業
# val:
# 俳優、モデル、司会、監督、絵本作家
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ、映画、舞台、ファッション、CM
# <class 'list'>
# key:活動期間
# val:
# 1996年 -
# <class 'list'>
# <class 'list'>
# key:事務所
# val:
# 研音
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1975-05-19) 1975年5月19日（44歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 俳優
# <class 'list'>
# key:ジャンル
# val:
# 映画・テレビドラマ
# <class 'list'>
# key:活動期間
# val:
# 1996年 -
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1958-02-04) 1958年2月4日（62歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 俳優、歌手
# <class 'list'>
# key:ジャンル
# val:
# 映画、テレビドラマ
# <class 'list'>
# key:活動期間
# val:
# 1980年 -
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1983-11-22) 1983年11月22日（36歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 女優、元ファッションモデル
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ、映画、舞台、CM
# <class 'list'>
# key:活動期間
# val:
# 2002年 -
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1964-07-25) 1964年7月25日（55歳）
# <class 'list'>
# key:出身地
# val:
#  日本・神奈川県横浜市[1][2]
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# B型[3]
# <class 'list'>
# key:職業
# val:
# 女優
# <class 'list'>
# key:ジャンル
# val:
# 映画・テレビドラマ・CM
# <class 'list'>
# key:活動期間
# val:
# 1987年 -
# <class 'list'>
# <class 'list'>
# key:事務所
# val:
# 太田プロダクション
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1977-05-26) 1977年5月26日（42歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# A型
# <class 'list'>
# key:職業
# val:
# 女優
# <class 'list'>
# key:ジャンル
# val:
# 映画・テレビドラマ・CM
# <class 'list'>
# key:活動期間
# val:
# 2000年 - 2010年2014年 -
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1987-11-12) 1987年11月12日（32歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 俳優
# <class 'list'>
# key:ジャンル
# val:
# 映画テレビドラマ
# <class 'list'>
# key:活動期間
# val:
# 2005年 -
# <class 'list'>
# key:事務所
# val:
# テンカラット
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1993-08-10) 1993年8月10日（26歳）
# <class 'list'>
# key:出身地
# val:
#  日本・東京都町田市[1]
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# A型[5]
# <class 'list'>
# key:職業
# val:
# アイドル 歌手、タレント、俳優、ファッションモデル
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ、映画
# <class 'list'>
# key:活動期間
# val:
# 2004年[1] -
# <class 'list'>
# key:事務所
# val:
# ジャニーズ事務所
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1984-09-01) 1984年9月1日（35歳）
# <class 'list'>
# <class 'list'>
# key:出身地
# val:
#  日本・山口県玖珂郡和木町
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 俳優
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ・映画・CM
# <class 'list'>
# key:活動期間
# val:
# 2003年 -
# <class 'list'>
# key:事務所
# val:
# アミューズ
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1968-06-14) 1968年6月14日（51歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# B型
# <class 'list'>
# key:職業
# val:
# 女優
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ、映画
# <class 'list'>
# key:活動期間
# val:
# 1988年 -
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:事務所
# val:
# アストラル
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1993-02-21) 1993年2月21日（26歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# A型[2]
# <class 'list'>
# key:職業
# val:
# 俳優歌手
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ映画CM
# <class 'list'>
# key:活動期間
# val:
# 2009年[2] -
# <class 'list'>
# key:事務所
# val:
# トップコート
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1971-03-31) 1971年3月31日（48歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ・映画・舞台
# <class 'list'>
# key:活動期間
# val:
# 1990年  -
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
# 1968年2月29日
# <class 'list'>
# <class 'list'>
# key:出身地
# val:
# 神奈川県横浜市港北区
# <class 'list'>
# key:血液型
# val:
# A
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:ジャンル
# val:
# タレント
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:出身地
# val:
#  日本・愛知県名古屋市[2]
# <class 'list'>
# <class 'list'>
# key:職業
# val:
# ダンサー俳優
# <class 'list'>
# key:活動期間
# val:
# 2010年 -
# <class 'list'>
# <class 'list'>
# key:事務所
# val:
# LDH JAPAN
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1993-06-11) 1993年6月11日（26歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 俳優
# <class 'list'>
# key:ジャンル
# val:
# 舞台・テレビドラマ・映画
# <class 'list'>
# key:活動期間
# val:
# 2008年 -
# <class 'list'>
# key:事務所
# val:
# トライストーン・エンタテイメント
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1997-04-02) 1997年4月2日（22歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 女優、モデル、タレント
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ・映画
# <class 'list'>
# key:活動期間
# val:
# 2014年 -
# <class 'list'>
# key:事務所
# val:
# インセント
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1971-03-16) 1971年3月16日（48歳）
# <class 'list'>
# key:出身地
# val:
#  日本 東京都
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# A型[1]
# <class 'list'>
# key:ジャンル
# val:
# テレビドラマ・映画・舞台・CM
# <class 'list'>
# <class 'list'>
# key:事務所
# val:
# 融合事務所
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
#  (1981-11-07) 1981年11月7日（38歳）
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:血液型
# val:
# O型
# <class 'list'>
# key:職業
# val:
# 女優
# <class 'list'>
# key:活動期間
# val:
# 1998年 -
# <class 'list'>
# key:事務所
# val:
# スウィートパワー
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:生年月日
# val:
# 1996年6月18日
# <class 'list'>
# <class 'list'>
# key:出身地
# val:
#  日本 埼玉県
# <class 'list'>
# key:血液型
# val:
# B型
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# key:ジャンル
# val:
# ファッション、広告
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b8cd7c150241> in <module>
#       9 for tmp_name in actor_actress_list:
#      10     actor_name = urllib.parse.quote(tmp_name)
# ---> 11     tmp_actor_profile_dict = scraping("https://ja.wikipedia.org/wiki/"+ actor_name)
#      12
#      13     actor_profile_dict.update(tmp_actor_profile_dict)
#
# <ipython-input-4-64f2469aac93> in scraping(url)
#      13         print(type(dt.contents))
#      14         if type(dt.contents) is list and len(dt.contents) > 1:
# ---> 15             search_result = re.search(regex,str(dt.contents[0].text))
#      16             if search_result is not None:
#      17                 print("key:"+str(dt.contents[0].text))
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, attr)
#     740             raise AttributeError(
#     741                 "'%s' object has no attribute '%s'" % (
# --> 742                     self.__class__.__name__, attr))
#     743
#     744     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'text'

# %%
key_list = list(set(key_list))

# %%
key_list

# %%
pprint(actor_profile_dict)
