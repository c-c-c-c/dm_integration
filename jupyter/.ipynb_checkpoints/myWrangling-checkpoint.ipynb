# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc

import datetime
# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
df = pd.read_csv("../data/viewing_rating.csv", encoding='cp932')

# %%
df.start_at=pd.to_datetime(df.start_at)

# %%
df["drama_key"] = df.start_at.dt.strftime("%y")+df.start_at.dt.strftime("%m")+"_"+df.TV_station+"_"+df.time_table

# %%
df
# df.start_at.dt.strftime("%m")

# %%
# import pandas_profiling as pdp
# pdp.ProfileReport(df)

# %%
import json

f = open("../data/drama_info.json", 'r')
print(f)
drama_info_json = json.load(f)

# %%
# def addDramaInfo (drama_title) 
#     main_actor_only_json[drama_title]

# %%
print (drama_info_json)

# %%
df["main_actor1"] = ""
df["main_actor2"] = ""

# %%
# for tmp_title in df.drama_title:
# #     if drama_title in main_actor_only_json  drama_title]:
#     if df.drama_title == tmp_title:
#         df[df.drama_title == tmp_title]["main_actor1"] = main_actor_only_json.get(drama_title,{}).get("cast1")

#     else:
#         print(tmp_title)
        
        #     df["main_actor2"].loc(tmp_title) = main_actor_only_json.get(drama_title,{}).get("cast2")
#     df[drama_title]["main_actor2"] = main_actor_only_json.get(drama_title,{}).get("cast2")

# %%
for tmp_index in range(len(df)):
    tmp_drama_key = df.iloc[tmp_index]["drama_key"]
    if tmp_drama_key in drama_info_json.keys():
#         print(drama_info_json[tmp_drama_key]["main_actor1"])
        df["main_actor1"][tmp_index] = drama_info_json[tmp_drama_key]["main_actor1"]
        df["main_actor2"][tmp_index] = drama_info_json[tmp_drama_key]["main_actor2"]
#         print("yes"+tmp_drama_title)
    else:
        print(tmp_drama_key)

# %%
# for i in range(1000):
#     print(df.iloc[i])
#     print (i)

# %%
def make_person_key_df (actor_actress):
    actor_actress_list = []
    for column in actor_actress.columns:
        if column == "ranking":
            continue
        actor_actress_list.extend(actor_actress[column].values.tolist())
    print ("元の数"+ str(len(actor_actress_list)))
    # uniqueにする
    actor_actress_list = list(set(actor_actress_list))
    #nan を除去
    actor_actress_list = [actor for actor in actor_actress_list if type(actor) is not float ]
    print ("後の数"+str(len(actor_actress_list)))

    df_pivot = pd.DataFrame( columns=actor_actress_list, index=[str(n) for n in range(2008,2020)])

    #pivot 形式に整形する
    for tmp_name in df_pivot.columns:
        for year in actor_actress.columns:
            if year == "ranking": continue
            if  len(actor_actress[actor_actress[year] == tmp_name].ranking) > 0:
                df_pivot.loc[year][tmp_name] = (actor_actress[actor_actress[year] == tmp_name].ranking).values[0]
    return (df_pivot)

# %%
df_actress = pd.read_csv("../data/actress_power.csv", encoding='cp932')
df_actress_pivot = make_person_key_df(df_actress)
# Out:
# 元の数360
# 後の数62

# %%
df_actor = pd.read_csv("../data/actor_power.csv", encoding='cp932')
df_actor_pivot = make_person_key_df(df_actor)
# Out:
# 元の数372
# 後の数65

# %%
df_actress_pivot
# Out:
#      菅野美穂 井上真央 北川景子 天海祐希 新垣結衣 広瀬アリス 木村文乃 橋本環奈 江角マキコ 深津絵里  ... 常盤貴子  吉田羊 堀北真希  \
# 2008  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN  ...  NaN  NaN  NaN
# 2009  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN  ...  NaN  NaN  NaN
# 2010    5   28  NaN    1    9   NaN  NaN  NaN   NaN   13  ...   24  NaN   15
# 2011    1   27   15    6   10   NaN  NaN  NaN   NaN   11  ...  NaN  NaN   14
# 2012  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN  ...  NaN  NaN  NaN
# 2013  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN  ...  NaN  NaN  NaN
# 2014    6   17    4    9    5   NaN  NaN  NaN    20   27  ...  NaN  NaN    2
# 2015   15   20    4    8    5   NaN  NaN  NaN   NaN   28  ...  NaN  NaN    2
# 2016   18   30    2    7    4   NaN  NaN  NaN   NaN   28  ...  NaN   16    6
# 2017   17   28    4    8    1   NaN  NaN  NaN   NaN   25  ...  NaN  NaN   15
# 2018   19   30    7    5    2    29   24  NaN   NaN   27  ...  NaN  NaN  NaN
# 2019   28  NaN    3    9    2    22  NaN   18   NaN  NaN  ...  NaN   27  NaN
#
#      藤原紀香 石原さとみ 長澤まさみ 米倉涼子 広瀬すず 綾瀬はるか 土屋太鳳
# 2008  NaN   NaN   NaN  NaN  NaN   NaN  NaN
# 2009  NaN   NaN   NaN  NaN  NaN   NaN  NaN
# 2010   27   NaN    17   19  NaN     6  NaN
# 2011  NaN    21   NaN   26  NaN     2  NaN
# 2012  NaN   NaN   NaN  NaN  NaN   NaN  NaN
# 2013  NaN   NaN   NaN  NaN  NaN   NaN  NaN
# 2014  NaN     8    22   13  NaN     1  NaN
# 2015  NaN    12    22    9  NaN     1  NaN
# 2016  NaN     5    22   20   15     1  NaN
# 2017  NaN     3    16   18   11     2   19
# 2018  NaN     3     9   15   10     1   13
# 2019  NaN     5     8   12    7     1   24
#
# [12 rows x 62 columns]

# %%
df_actor_namekey = df_actor_pivot.T.rename_axis('actor_actress').reset_index()

# %%
df_actress_namekey = df_actress_pivot.T.rename_axis('actor_actress').reset_index()

# %%
df_actress_namekey
# Out:
#    actor_actress 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019
# 0           菅野美穂  NaN  NaN    5    1  NaN  NaN    6   15   18   17   19   28
# 1           井上真央  NaN  NaN   28   27  NaN  NaN   17   20   30   28   30  NaN
# 2           北川景子  NaN  NaN  NaN   15  NaN  NaN    4    4    2    4    7    3
# 3           天海祐希  NaN  NaN    1    6  NaN  NaN    9    8    7    8    5    9
# 4           新垣結衣  NaN  NaN    9   10  NaN  NaN    5    5    4    1    2    2
# 5          広瀬アリス  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   29   22
# 6           木村文乃  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   24  NaN
# 7           橋本環奈  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   18
# 8          江角マキコ  NaN  NaN  NaN  NaN  NaN  NaN   20  NaN  NaN  NaN  NaN  NaN
# 9           深津絵里  NaN  NaN   13   11  NaN  NaN   27   28   28   25   27  NaN
# 10             杏  NaN  NaN  NaN  NaN  NaN  NaN   15    7   11   14   23  NaN
# 11          竹内結子  NaN  NaN    8   13  NaN  NaN  NaN   16   26   29  NaN   21
# 12            波瑠  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   26   25
# 13          桐谷美玲  NaN  NaN  NaN  NaN  NaN  NaN  NaN   29   10    9   20   23
# 14          柴崎コウ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   13  NaN  NaN
# 15            小雪  NaN  NaN   30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16          永作博美  NaN  NaN  NaN   29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#