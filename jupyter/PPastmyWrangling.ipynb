# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
import gc

import datetime
# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

import textwrap
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
import pydotplus
from IPython.display import Image
from graphviz import Digraph
from sklearn import tree


pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv("../data/viewing_rating.csv", encoding='cp932')

# %%
# time型に
df.start_at=pd.to_datetime(df.start_at)
# averageの％を削除
df["average"] =  df["average"].apply(lambda x : float(x[:-1]) )

# %%
df["start_at_year"] = df["start_at"].dt.year
df["start_at_month"] = df["start_at"].dt.month

# %%
df["drama_key"] = df.start_at.dt.strftime("%y")+df.start_at.dt.strftime("%m")+"_"+df.TV_station+"_"+df.time_table

# %%
import json

f = open("../data/drama_info0115.json", 'r')
print(f)
drama_info_json = json.load(f)
# Out:
# <_io.TextIOWrapper name='../data/drama_info0115.json' mode='r' encoding='UTF-8'>

# %%
# def addDramaInfo (drama_title) 
#     main_actor_only_json[drama_title]

# %%
print (textwrap.shorten(str(drama_info_json), 1000))
# Out:
# {'1910_CX_月21': {'main_actor1': 'ディーン・フジオカ', 'main_actor2': '岩田剛典', 'original_work': 'アーサー・コナン・ドイル「シャーロック・ホームズ」'}, '1910_CX_火22': {'main_actor1': '阿部寛', 'main_actor2': '吉田羊', 'original_work': ''}, '1910_TBS_火22': {'main_actor1': '波瑠', 'main_actor2': '中川大志', 'original_work': 'いくえみ綾「G線上のあなたと私」'}, '1910_NTV_水22': {'main_actor1': '高畑充希', 'main_actor2': '橋本愛', 'original_work': ''}, '1910_EX_木21': {'main_actor1': '米倉涼子', 'main_actor2': 'ユースケ・サンタマリア', 'original_work': ''}, '1910_CX_木22': {'main_actor1': '新木優子', 'main_actor2': '高良健吾', 'original_work': '瀧波ユカリ「モトカレマニア」'}, '1910_NTV_木23': {'main_actor1': '本田翼', 'main_actor2': '金子大地', 'original_work': ''}, '1910_TBS_金22': {'main_actor1': '福士蒼汰', 'main_actor2': '菜々緒', 'original_work': 'キリエ「4分間のマリーゴールド」'}, '1910_EX_金23': {'main_actor1': 'オダギリジョー', 'main_actor2': '麻生久美子', 'original_work': ''}, '1910_NTV_土22': {'main_actor1': '生田斗真', 'main_actor2': '安田顕', 'original_work': ''}, '1910_EX_土23': {'main_actor1': '田中圭', 'main_actor2': '吉田鋼太郎', [...]

# %%
df["main_actor1"] = ""
df["main_actor2"] = ""
df["original_work"] = ""

# %%
for tmp_index in range(len(df)):
    tmp_drama_key = df.iloc[tmp_index]["drama_key"]
    if tmp_drama_key in drama_info_json.keys():
#         print(drama_info_json[tmp_drama_key]["main_actor1"])
        df["main_actor1"][tmp_index] = drama_info_json[tmp_drama_key]["main_actor1"]
        df["main_actor2"][tmp_index] = drama_info_json[tmp_drama_key]["main_actor2"]
        df["original_work"][tmp_index] = drama_info_json[tmp_drama_key]["original_work"]
#         print("yes"+tmp_drama_title)
    else:
        print(tmp_drama_key)
# Out:
# 1910_EX_木22

# %%
def make_person_key_df (actor_actress):
    actor_actress_list = []
    for column in actor_actress.columns:
        if column == "ranking":
            continue
        actor_actress_list.extend(actor_actress[column].values.tolist())
    print ("元の数"+ str(len(actor_actress_list)))
    # uniqueにする
    actor_actress_list = list(set(actor_actress_list))
    #nan を除去
    actor_actress_list = [actor for actor in actor_actress_list if type(actor) is not float ]
    print ("後の数"+str(len(actor_actress_list)))

    df_pivot = pd.DataFrame( columns=actor_actress_list, index=[str(n) for n in range(2008,2020)])

    #pivot 形式に整形する
    for tmp_name in df_pivot.columns:
        for year in actor_actress.columns:
            if year == "ranking": continue
            if  len(actor_actress[actor_actress[year] == tmp_name].ranking) > 0:
                df_pivot.loc[year][tmp_name] = (actor_actress[actor_actress[year] == tmp_name].ranking).values[0]
    return (df_pivot)

# %%
df_actress = pd.read_csv("../data/actress_power.csv", encoding='cp932')
df_actress_pivot = make_person_key_df(df_actress)
# Out:
# 元の数360
# 後の数69

# %%
df_actor = pd.read_csv("../data/actor_power.csv", encoding='cp932')
df_actor_pivot = make_person_key_df(df_actor)
# Out:
# 元の数372
# 後の数69

# %%
df_actress_pivot
# Out:
#      有村架純 常盤貴子    松 佐々木希 橋本環奈 長澤まさみ 吉永小百合 綾瀬はるか 松嶋菜々子 上野樹里 松たか子 能年玲奈 松下奈緒  \
# 2008  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 2009  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 2010  NaN   24  NaN  NaN  NaN    17    22     6     3  NaN   16  NaN  NaN
# 2011  NaN  NaN  NaN  NaN  NaN   NaN    22     2     8   18   19  NaN   23
# 2012  NaN   28   24  NaN  NaN    12    29     2     1  NaN  NaN  NaN  NaN
# 2013  NaN   23  NaN  NaN  NaN    17    27     1     5  NaN  NaN  NaN  NaN
# 2014  NaN  NaN  NaN  NaN  NaN    22    19     1    12  NaN   23   25   29
# 2015  NaN  NaN  NaN   21  NaN    22    25     1    14   30   11   17  NaN
# 2016    3  NaN  NaN  NaN  NaN    22    25     1    21  NaN   17  NaN  NaN
# 2017    6  NaN  NaN   30  NaN    16   NaN     2    22  NaN  NaN  NaN  NaN
# 2018    6  NaN  NaN   12  NaN     9   NaN     1    18  NaN  NaN  NaN  NaN
# 2019    6  NaN  NaN   16   18     8   NaN     1    19  NaN  NaN  NaN  NaN
#
#         杏 榮倉奈々 篠原涼子  黒木瞳 堀北真希 深田恭子 井上真央 竹内結子 天海祐希 石原さとみ 菅野美穂 新垣結衣 吉高由里子 剛力彩芽  \
# 2008  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
# 2009  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
# 2010  NaN  NaN   21   14   15   20   28    8    1   NaN    5    9   NaN  NaN
# 2011  NaN  NaN   12   30   14   17   27   13    6    21    1   10   NaN  NaN
# 2012  NaN  NaN   15  NaN    5   21   13    8    3    23    9    7   NaN  NaN
# 2013  NaN  NaN   10  NaN    2   13   20   25    3    19    6    9    28   30
# 2014   15  NaN   14  NaN    2   18   17  NaN    9     8    6    5   NaN  NaN
NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 57          芦田愛菜  NaN  NaN  NaN  NaN   20  NaN  NaN  NaN  NaN  NaN   28   26
# 58           香里奈  NaN  NaN  NaN  NaN   25  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 59         多部未華子  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   24   22   14
# 60          樹木希林  NaN  NaN  NaN  NaN  NaN   18   24  NaN  NaN  NaN  NaN  NaN
# 61          深津絵里  NaN  NaN   13   11   11   16   27   28   28   25   27  NaN
# 62         戸田恵梨香  NaN  NaN   25  NaN  NaN  NaN  NaN  NaN  NaN  NaN   21   11
# 63          桐谷美玲  NaN  NaN  NaN  NaN  NaN  NaN  NaN   29   10    9   20   23
# 64          木村文乃  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   24  NaN
# 65          柴崎コウ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   13  NaN  NaN
# 66            小雪  NaN  NaN   30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 67         広瀬アリス  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   29   22
# 68         仲間由紀恵  NaN  NaN    2    5    4    7   10    3    9    7   14   13

# %%
df_merged = pd.merge(df, df_actor_namekey,left_on='main_actor1', right_on='actor_actress', how='left')
#df_merged = pd.merge(df_merged, df_actress_namekey,left_on='main_actor1', right_on='actor_actress', how='right')
#df_merged = pd.merge(df_merged, df_actress_namekey,left_on='main_actor2', right_on='actor_actress', how='right')

# %%
df_merged = pd.merge(df_merged, df_actress_namekey,left_on='main_actor1', right_on='actor_actress', how='left'
                     ,suffixes=('_1', '_2'))

# %%
df_merged = pd.merge(df_merged, df_actor_namekey,left_on='main_actor2', right_on='actor_actress', how='left'
                     ,suffixes=('_3', '_4') )

# %%
df_merged = pd.merge(df_merged, df_actress_namekey,left_on='main_actor2', right_on='actor_actress', how='left'
                    , suffixes=('_3', '_4'),)

# %%
# df_merged[["main_actor1","2017","2016","2014"]]
df_merged
# Out:
#     TV_station time_table  drama_title  Episode1  Episode2  Episode3  \
# 0           CX        月21       シャーロック      12.8       9.3       9.9
# 1           CX        火22    まだ結婚できない男      11.5       7.7      10.0
# 2          TBS        火22    G線上のあなたと私       7.8       8.8       7.3
# 3          NTV        水22       同期のサクラ       8.1       9.5       9.3
# 4           EX        木22        ドクターX      20.3      19.0      18.1
# ..         ...        ...          ...       ...       ...       ...
# 937        TBS        木22         年下の男      11.8      10.7      12.2
# 938         CX        木22        美女か野獣      20.0      17.3      18.6
# 939        TBS        金22         高校教師      14.9      12.2       6.4
# 940        NTV        土21       よい子の味方      13.4      10.2       8.9
# 941        TBS        日21  GOOD LUCK!!      31.6      27.5      28.6
#
#      Episode4 Episode5 Episode6 Episode7 Episode8 Episode9 Episode10  \
# 0        10.6      9.3      8.3      9.9      8.9      9.9       8.8
# 1         9.5       10      8.9      8.5      8.6        9       9.7
# 2         6.9      6.7      6.7      8.6      7.6      6.5       9.6
# 3        11.5     11.8     11.7     12.2     10.8     10.3      13.7
# 4        17.8     15.9     19.3     18.6     17.4     18.2      19.3
# ..        ...      ...      ...      ...      ...      ...       ...
# 937      11.8     12.6     12.6     13.7     13.5     14.1      14.2
# 938      18.6     17.3     17.5       17       19     19.4      18.9
# 939      10.7     10.6      8.8     10.2     13.5     11.2       8.8
# 940      10.0     10.1      7.5     11.1     10.7       12         -
# 941      27.6     30.9     28.2     28.9     29.7     33.5      37.6
#
#     Episode11 Episode12 Episode13 Episode14 Episode15  average      suii  \
# 0         9.8         -         -         -         -     9.90     5-5-0
# 1           -         -         -         -         -     9.40     5-4-0
# 2           -         -         -         -         -     7.65  2003/5/1
# 3           -         -         -         -         -    10.89     5-4-0
# 4           -         -         -         -         -    18.48     3-6-0
# ..        ...       ...       ...       ...       ...      ...       ...
# 937      13.3         -         -         -         -    12.77  2005/4/1
# 938      19.4         -         -         -         -    18.45  2005/4/1
# 939        11         -         -         -         -    10.75     4-6-0
# 940         -         -         -         -         -    10.43     4-4-0
# 941         -         -         -         -         -    30.41     6-3-0
#
#       start_at  start_at_year  start_at_month     drama_key main_actor1  \
# 0   2019-10-01           2019              10   1910_CX_月21   ディーン・フジオカ
# 1   2019-10-01           2019              10   1910_CX_火22         阿部寛
# 2   2019-10-01           2019              10  1910_TBS_火22          波瑠
# 3   2019-10-01           2019              10  1910_NTV_水22        高畑充希
# 4   2019-10-01           2019              10   1910_EX_木22
# ..         ...            ...             ...           ...         ...
# 937 2003-01-01           2003               1  0301_TBS_木22       稲森いずみ
# 938 2003-01-01           2003               1   0301_CX_木22       松嶋菜々子
# 939 2003-01-01           2003               1  0301_TBS_金22        藤木直人
# 940 2003-01-01           2003               1  0301_NTV_土21         櫻井翔
# 941 2003-01-01           2003               1  0301_TBS_日21        木村拓哉
#
#     main_actor2              original_work actor_actress_1 2008_1 2009_1  \
# 0          岩田剛典  アーサー・コナン・ドイル「シャーロック・ホームズ」             NaN    NaN    NaN
# 1           吉田羊                                        阿部寛    NaN    NaN
# 2          中川大志           いくえみ綾「G線上のあなたと私」             NaN    NaN    NaN
# 3           橋本愛                                        NaN    NaN    NaN
# 4                                                      NaN    NaN    NaN
# ..          ...                        ...             ...    ...    ...
# 937        高橋克典                                        NaN    NaN    NaN
# 938        福山雅治                                        NaN    NaN    NaN
# 939         上戸彩                                        NaN    NaN    NaN
# 940        松下由樹                                        櫻井翔    NaN    NaN
# 941         堤真一                                       木村拓哉    NaN    NaN
#
#     2010_1 2011_1 2012_1 2013_1 2014_1 2015_1 2016_1 2017_1 2018_1 2019_1  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1       11      3      1      1      1      1      1      2      1      8
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940      1      1      3      2      3      3      2      4      3      6
# 941      4     19     14     13     27     21     21    NaN    NaN    NaN
#
#     actor_actress_2 2008_2 2009_2 2010_2 2011_2 2012_2 2013_2 2014_2 2015_2  \
# 0               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2                波瑠    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3              高畑充希    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938           松嶋菜々子    NaN    NaN      3      8      1      5     12     14
# 939             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2016_2 2017_2 2018_2 2019_2 actor_actress_3 2008_3 2009_3 2010_3 2011_3  \
# 0      NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 2      NaN    NaN     26     25             NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN     17     20             NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...             ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 938     21     22     18     19             NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 940    NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN             堤真一    NaN    NaN    NaN    NaN
#
#     2012_3 2013_3 2014_3 2015_3 2016_3 2017_3 2018_3 2019_3 actor_actress_4  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             吉田羊
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...             ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             上戸彩
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 941     19     17     24     23     22     21     25    NaN             NaN
#
#     2008_4 2009_4 2010_4 2011_4 2012_4 2013_4 2014_4 2015_4 2016_4 2017_4  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     16    NaN
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN      4      3    NaN      4      3     10     12     12
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2018_4 2019_4
# 0      NaN    NaN
# 1      NaN     27
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 937    NaN    NaN
# 938    NaN    NaN
# 939     11    NaN
# 940    NaN    NaN
# 941    NaN    NaN
#
# [942 rows x 79 columns]

# %%
df_merged
# Out:
#     TV_station time_table  drama_title  Episode1  Episode2  Episode3  \
# 0           CX        月21       シャーロック      12.8       9.3       9.9
# 1           CX        火22    まだ結婚できない男      11.5       7.7      10.0
# 2          TBS        火22    G線上のあなたと私       7.8       8.8       7.3
# 3          NTV        水22       同期のサクラ       8.1       9.5       9.3
# 4           EX        木22        ドクターX      20.3      19.0      18.1
# ..         ...        ...          ...       ...       ...       ...
# 937        TBS        木22         年下の男      11.8      10.7      12.2
# 938         CX        木22        美女か野獣      20.0      17.3      18.6
# 939        TBS        金22         高校教師      14.9      12.2       6.4
# 940        NTV        土21       よい子の味方      13.4      10.2       8.9
# 941        TBS        日21  GOOD LUCK!!      31.6      27.5      28.6
#
#      Episode4 Episode5 Episode6 Episode7 Episode8 Episode9 Episode10  \
# 0        10.6      9.3      8.3      9.9      8.9      9.9       8.8
# 1         9.5       10      8.9      8.5      8.6        9       9.7
# 2         6.9      6.7      6.7      8.6      7.6      6.5       9.6
# 3        11.5     11.8     11.7     12.2     10.8     10.3      13.7
# 4        17.8     15.9     19.3     18.6     17.4     18.2      19.3
# ..        ...      ...      ...      ...      ...      ...       ...
# 937      11.8     12.6     12.6     13.7     13.5     14.1      14.2
# 938      18.6     17.3     17.5       17       19     19.4      18.9
# 939      10.7     10.6      8.8     10.2     13.5     11.2       8.8
# 940      10.0     10.1      7.5     11.1     10.7       12         -
# 941      27.6     30.9     28.2     28.9     29.7     33.5      37.6
#
#     Episode11 Episode12 Episode13 Episode14 Episode15  average      suii  \
# 0         9.8         -         -         -         -     9.90     5-5-0
# 1           -         -         -         -         -     9.40     5-4-0
# 2           -         -         -         -         -     7.65  2003/5/1
# 3           -         -         -         -         -    10.89     5-4-0
# 4           -         -         -         -         -    18.48     3-6-0
# ..        ...       ...       ...       ...       ...      ...       ...
# 937      13.3         -         -         -         -    12.77  2005/4/1
# 938      19.4         -         -         -         -    18.45  2005/4/1
# 939        11         -         -         -         -    10.75     4-6-0
# 940         -         -         -         -         -    10.43     4-4-0
# 941         -         -         -         -         -    30.41     6-3-0
#
#       start_at  start_at_year  start_at_month     drama_key main_actor1  \
# 0   2019-10-01           2019              10   1910_CX_月21   ディーン・フジオカ
# 1   2019-10-01           2019              10   1910_CX_火22         阿部寛
# 2   2019-10-01           2019              10  1910_TBS_火22          波瑠
# 3   2019-10-01           2019              10  1910_NTV_水22        高畑充希
# 4   2019-10-01           2019              10   1910_EX_木22
# ..         ...            ...             ...           ...         ...
# 937 2003-01-01           2003               1  0301_TBS_木22       稲森いずみ
# 938 2003-01-01           2003               1   0301_CX_木22       松嶋菜々子
# 939 2003-01-01           2003               1  0301_TBS_金22        藤木直人
# 940 2003-01-01           2003               1  0301_NTV_土21         櫻井翔
# 941 2003-01-01           2003               1  0301_TBS_日21        木村拓哉
#
#     main_actor2              original_work actor_actress_1 2008_1 2009_1  \
# 0          岩田剛典  アーサー・コナン・ドイル「シャーロック・ホームズ」             NaN    NaN    NaN
# 1           吉田羊                                        阿部寛    NaN    NaN
# 2          中川大志           いくえみ綾「G線上のあなたと私」             NaN    NaN    NaN
# 3           橋本愛                                        NaN    NaN    NaN
# 4                                                      NaN    NaN    NaN
# ..          ...                        ...             ...    ...    ...
# 937        高橋克典                                        NaN    NaN    NaN
# 938        福山雅治                                        NaN    NaN    NaN
# 939         上戸彩                                        NaN    NaN    NaN
# 940        松下由樹                                        櫻井翔    NaN    NaN
# 941         堤真一                                       木村拓哉    NaN    NaN
#
#     2010_1 2011_1 2012_1 2013_1 2014_1 2015_1 2016_1 2017_1 2018_1 2019_1  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1       11      3      1      1      1      1      1      2      1      8
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940      1      1      3      2      3      3      2      4      3      6
# 941      4     19     14     13     27     21     21    NaN    NaN    NaN
#
#     actor_actress_2 2008_2 2009_2 2010_2 2011_2 2012_2 2013_2 2014_2 2015_2  \
# 0               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2                波瑠    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3              高畑充希    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938           松嶋菜々子    NaN    NaN      3      8      1      5     12     14
# 939             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2016_2 2017_2 2018_2 2019_2 actor_actress_3 2008_3 2009_3 2010_3 2011_3  \
# 0      NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 2      NaN    NaN     26     25             NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN     17     20             NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...             ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 938     21     22     18     19             NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 940    NaN    NaN    NaN    NaN             NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN             堤真一    NaN    NaN    NaN    NaN
#
#     2012_3 2013_3 2014_3 2015_3 2016_3 2017_3 2018_3 2019_3 actor_actress_4  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             吉田羊
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...             ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             上戸彩
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN
# 941     19     17     24     23     22     21     25    NaN             NaN
#
#     2008_4 2009_4 2010_4 2011_4 2012_4 2013_4 2014_4 2015_4 2016_4 2017_4  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     16    NaN
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN      4      3    NaN      4      3     10     12     12
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2018_4 2019_4
# 0      NaN    NaN
# 1      NaN     27
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 937    NaN    NaN
# 938    NaN    NaN
# 939     11    NaN
# 940    NaN    NaN
# 941    NaN    NaN
#
# [942 rows x 79 columns]

# %%
df_merged.loc[:,df_merged.columns.str.contains('20')]
# Out:
#     2008_1 2009_1 2010_1 2011_1 2012_1 2013_1 2014_1 2015_1 2016_1 2017_1  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN     11      3      1      1      1      1      1      2
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940    NaN    NaN      1      1      3      2      3      3      2      4
# 941    NaN    NaN      4     19     14     13     27     21     21    NaN
#
#     2018_1 2019_1 2008_2 2009_2 2010_2 2011_2 2012_2 2013_2 2014_2 2015_2  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1        1      8    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN      3      8      1      5     12     14
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940      3      6    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2016_2 2017_2 2018_2 2019_2 2008_3 2009_3 2010_3 2011_3 2012_3 2013_3  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      NaN    NaN     26     25    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN     17     20    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938     21     22     18     19    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     19     17
#
#     2014_3 2015_3 2016_3 2017_3 2018_3 2019_3 2008_4 2009_4 2010_4 2011_4  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN      4      3
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941     24     23     22     21     25    NaN    NaN    NaN    NaN    NaN
#
#     2012_4 2013_4 2014_4 2015_4 2016_4 2017_4 2018_4 2019_4
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN     16    NaN    NaN     27
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 937    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 938    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 939    NaN      4      3     10     12     12     11    NaN
# 940    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 941    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [942 rows x 48 columns]

# %%
df_new4years = df_merged[df_merged["start_at"] > datetime.datetime.strptime("2016-01-01", '%Y-%m-%d')]

# %%
df_new4years
# Out:
#     TV_station time_table            drama_title  Episode1  Episode2  \
# 0           CX        月21                 シャーロック      12.8       9.3
# 1           CX        火22              まだ結婚できない男      11.5       7.7
# 2          TBS        火22              G線上のあなたと私       7.8       8.8
# 3          NTV        水22                 同期のサクラ       8.1       9.5
# 4           EX        木22                  ドクターX      20.3      19.0
# 5           CX        木22                モトカレマニア       5.6       5.2
# 6          NTV        木23                  CHEAT       4.2       3.0
# 7          TBS        金22            4分間のマリーゴールド      10.3       7.8
# 8           EX        金23             時効警察はじめました       7.7       6.1
# 9          NTV        土22                 俺の話は長い       8.4       9.0
# 10          EX        土23                おっさんずラブ       5.8       4.7
# 11         TBS        日21               グランメゾン東京      12.4      13.2
# 12         NTV        日22               ニッポンノワール       7.8       6.5
# 13          CX        月21                 監察医 朝顔      13.7      12.3
# 14          CX        火21              TWO WEEKS       8.4       5.9
# 15         TBS        火22                Heaven？      10.8       9.2
# 16         NTV        水22                   偽装不倫      10.1      11.2
# 17          EX        木21                    サイン      14.3       9.5
# 18          CX        木22                  ルパンの娘       8.4       7.4
# 19         NTV        木23           わたし旦那をシェアしてた       3.1       3.1
# 20         TBS        金22                   凪のお暇      10.3       9.5
# 21          EX        金23                  セミオトコ       4.0       4.4
# 22         NTV        土22                    ボイス      12.6       8.4
# 23          EX        土23                べしゃり暮らし       2.6       2.0
# 24         TBS        日21              ノーサイド・ゲーム      13.5      11.8
# 25         NTV        日22                あなたの番です       9.2       9.2
# 26          CX        月21             ラジエーションハウス      12.7      12.3
# 27          CX        火21             パーフェクトワールド       6.9       5.8
# 28         TBS        火22           わたし、定時で帰ります。       9.5      10.4
# 29         NTV        水22                 白衣の戦士！      10.3       9.3
# 30          EX        木21                  緊急取調室      15.2      13.4
# 31          CX        木22          ストロベリーナイト・サーガ       7.8       6.4
# 32         NTV        木23              向かいのバズる家族       2.7       2.7
# 33         TBS        金22                  インハンド      11.3       9.5
# 34          EX        金23               家政夫のミタゾノ       8.2       6.5
# 35         NTV        土22          俺のスカート、どこ行った？      10.9       9.7
# 36          EX        土23                 東京独身男子       5.7       3.2
# 37         TBS        日21                 集団左遷!!      13.8       8.9
# 38         NTV        日22                あなたの番です       8.3       6.5
# 39          CX        月21                   トレース      12.3      11.8
# 40          CX        火21                    後妻業       8.7       6.5
# 41         TBS        火22           初めて恋をした日に読む話       8.6       9.0
# 42         NTV        水22              家売るオンナの逆襲      12.7      12.9
# 43          EX        木21              ハケン占い師アタル      12.1      10.9
# 44          CX        木22                  QUEEN       9.3       5.8
# 45         NTV        木23          人生が楽しくなる幸せの法則       3.8       3.4
# 46         TBS        金22              メゾン・ド・ポリス      12.7      12.4
# 47          EX        金23                 私のおじさん       5.6       4.4
# 48         NTV        土22                  イノセンス       8.3       8.7
# 49          EX        土23             僕の初恋をキミに捧ぐ       3.3       2.5
# 50         TBS        日21                 グッドワイフ      10.0      11.5
# 51         NTV        日22                   3年A組      10.2      10.6
# 52          CX        月21                  SUITS      14.2      11.1
# 53          CX        火21            僕らは奇跡でできている       7.6       6.1
# 54         TBS        火22                  中学聖日記       6.0       6.5
# 55         NTV        水22              獣になれない私たち      11.5       8.5
# 56          EX        木21                  リーガルV      15.0      18.1
# 57          CX        木22                  黄昏流星群       7.3       7.3
# 58         NTV        木23             ブラックスキャンダル       4.3       3.3
# 59         TBS        金22                    大恋愛      10.4      10.6
# 60          EX        金23              僕とシッポと神楽坂       6.6       5.4
# 61         NTV        土22                    ドロ刑      11.8       8.6
# 62          EX        土23              あなたには渡さない       4.3       4.6
# 63         TBS        日21                 下町ロケット      13.9      12.4
# 64         NTV        日22               今日から俺は!!       9.8       8.3
# 65          CX        月21                   絶対零度      10.6       9.6
# 66          CX        火21         健康で文化的な最低限度の生活       7.6       5.5
# 67         TBS        火22              義母と娘のブルース      11.5      11.3
# 68         NTV        水22                   高嶺の花      11.1       9.6
# 69          EX        木21                   ハゲタカ      11.9      11.3
# 70          CX        木22               グッド・ドクター      11.5      10.6
# 71         NTV        木23                探偵が早すぎる       3.9       4.2
# 72         TBS        金22                  チア☆ダン       8.5       8.6
# 73          EX        金23                   dele       5.5       3.7
# 74         NTV        土22           サバイバル・ウェディング      10.4      10.8
# 75          EX        土23                   ヒモメン       4.6       4.9
# 76         TBS        日21               この世界の片隅に      10.9      10.5
# 77         NTV        日22                     ゼロ       7.1       6.7
# 78          CX        月21            コンフィデンスマンJP       9.4       7.7
# 79          CX        火21                   シグナル       9.7       8.4
# 80         TBS        火22                  花のち晴れ       7.4       7.9
# 81         NTV        水22                   正義のセ      11.0       9.9
# 82          EX        木21                  未解決の女      14.7      12.8
# 83          CX        木22              モンテ・クリスト伯       5.1       5.7
# 84         NTV        木23                  ラブリラン       3.9       2.7
# 85         TBS        金22            あなたには帰る家がある       9.3       8.1
# 86          EX        金23               家政夫のミタゾノ       7.2       7.2
# 87         NTV        土22                Missデビル       9.6       8.1
# 88          EX        土23                おっさんずラブ       2.9       4.2
# 89         TBS        日21                ブラックペアン      13.7      12.4
# 90         NTV        日22               崖っぷちホテル！      10.6       6.1
# 91          CX        月21                    海月姫       8.6       6.9
# 92          CX        火21              FINAL CUT       7.2       6.5
# 93         TBS        火22             きみが心に棲みついた       9.4       8.5
# 94         NTV        水22                  anone       9.2       7.2
# 95          EX        木21                     BG      15.7      15.1
# 96          CX        木22             隣の家族は青く見える       7.0       6.2
# 97         NTV        木23                   リピート       3.8       2.9
# 98         TBS        金22                アンナチュラル      12.7      13.1
# 99          EX        金23                 ホリデイラブ       5.1       5.8
# 100        NTV        土22                 もみ消して冬      13.3      11.1
# 101         EX        土23             明日の君がもっと好き       4.3       3.9
# 102        TBS        日21                   99.9      15.1      18.0
# 103        NTV        日22                 トドメの接吻       7.4       6.5
# 104         CX        月21                   民衆の敵       9.0       7.1
# 105         CX        火21                  明日の約束       8.2       6.2
# 106        TBS        火22                監獄のお姫さま       9.6       9.6
# 107        NTV        水22             奥様は、取り扱い注意      11.4      11.3
# 108         EX        木21                  ドクターX      20.9      19.6
# 109         CX        木22                  刑事ゆがみ       7.6       5.8
# 110        NTV        木23               ブラックリベンジ       3.7       3.1
# 111        TBS        金22                  コウノドリ      12.9      11.8
# 112         EX        金23                重要参考人探偵       4.9       5.1
# 113        NTV        土22             先に生まれただけの僕      10.1       7.5
# 114        TBS        日21                     陸王      14.7      14.0
# 115        NTV        日22           今からあなたを脅迫します       8.0       5.7
# 116         CX        月21            コード・ブルー 3rd      16.3      15.6
# 117         CX        火21              僕たちがやりました       7.9       6.5
# 118        TBS        火22                カンナさーん！      12.0      12.6
# 119        NTV        水22                過保護のカホコ      11.6      10.8
# 120         EX        木20                   遺留捜査      13.1       8.8
# 121         EX        木21                  黒革の手帖      11.7      12.3
# 122         CX        木22               セシルのもくろみ       5.1       4.5
# 123        NTV        木23           脳にスマホが埋められた！       3.7       3.8
# 124        TBS        金22               ハロー張りネズミ      10.3       7.6
# 125         EX        金23               あいの結婚相談所       5.1       3.6
# 126        NTV        土22           ウチの夫は仕事ができない      11.2       9.1
# 127        TBS        日21               ごめん、愛してる       9.8      10.0
# 128         CX        日21               警視庁いきもの係       8.9       7.2
# 129        NTV        日22          愛してたって、秘密はある。       8.2       8.7
# 130         CX        月21                   貴族探偵      11.8       8.3
# 131         CX        火21                 CRISIS      13.9      11.2
# 132        TBS        火22            あなたのことはそれほど      11.1       9.0
# 133        NTV        水22                   母になる      10.6      10.7
# 134         EX        木21                  緊急取調室      17.9      14.2
# 135         CX        木22         人は見た目が100パーセント       9.5       6.4
# 136        NTV        木23            恋がヘタでも生きてます       3.7       3.2
# 137        TBS        金22                   リバース      10.3       6.3
# 138         EX        金23                  女囚セブン       7.5       5.3
# 139        NTV        土22             ボク、運命の人です。      12.0       9.6
# 140        TBS        日21                  小さな巨人      13.7      13.0
# 141         CX        日21     櫻子さんの足下には死体が埋まっている       6.9       6.5
# 142        NTV        日22           フランケンシュタインの恋      11.2       7.3
# 143         CX        月21          突然ですが、明日結婚します       8.5       6.9
# 144         CX        火21                   嘘の戦争      11.8      12.0
# 145        TBS        火22                  カルテット       9.8       9.6
# 146        NTV        水22                東京タラレバ娘      13.8      11.5
# 147         EX        木21                   就活家族      11.0       9.4
# 148         CX        木22                 嫌われる勇気       8.1       6.4
# 149        NTV        木23              増山超能力師事務所       4.5       3.2
# 150        TBS        金22                  下剋上受験      10.9      10.6
# 151         EX        金23                  奪い愛、冬       6.6       5.1
# 152        NTV        土21         スーパーサラリーマン左江内氏      12.9       9.6
# 153         CX        日21                    大貧乏       7.7       4.4
# 154        TBS        日21                 A LIFE      14.2      14.7
# 155        NTV        日22              視覚探偵　日暮旅人      11.2      10.7
# 156         CX        月21                カインとアベル       8.8       8.6
# 157         CX        火21          レディ・ダ・ヴィンチの診断       8.8       8.0
# 158        TBS        火22            逃げるは恥だが役に立つ      10.2      12.1
# 159        NTV        水22                地味にスゴイ！      12.9      11.2
# 160         EX        木21                  ドクターX      20.4      19.7
# 161         CX        木22                   Chef       8.0       7.0
# 162        NTV        木23                 黒い十人の女       3.1       3.9
# 163        TBS        金22                    砂の塔       9.8       9.6
# 164         EX        金23               家政夫のミタゾノ       8.2       6.7
# 165        NTV        土21           THE LAST COP       8.6       7.4
# 166         CX        日21                   キャリア       7.9       6.2
# 167        TBS        日21                  IQ246      13.1      12.4
# 168        NTV        日22                レンタル救世主      10.2       7.5
# 169         CX        月21              好きな人がいること      10.1      10.4
# 170         CX        火22                     ON       9.6       9.2
# 171        TBS        火22          せいせいするほど、愛してる       9.3       7.4
# 172        NTV        水22                 家売るオンナ      12.4      10.1
# 173         EX        木21         はじめまして、愛しています。      10.0      11.4
# 174         CX        木22             営業部長 吉良奈津子      10.2       7.7
# 175        NTV        木23           遺産相続弁護士　柿崎真一       2.7       3.4
# 176        TBS        金22                神の舌を持つ男       6.4       6.2
# 177         EX        金23                 グ・ラ・メ！       7.2       6.7
# 178        NTV        土21                時をかける少女       9.4       6.6
# 179         CX        日21                   HOPE       6.5       7.1
# 180        TBS        日21                  仰げば尊し      11.4      11.7
# 181        NTV        日22           そして、誰もいなくなった      10.7       8.6
# 182         CX        月21                  ラヴソング      10.6       9.1
# 183         CX        火22                 僕のヤバイ妻       8.3       7.7
# 184        TBS        火22                  重版出来！       9.2       7.1
# 185        NTV        水22                世界一難しい恋      12.8      12.9
# 186         EX        木21               グッドパートナー      12.9       9.9
# 187         CX        木22      早子先生、結婚するって本当ですか?       6.8       6.1
# 188        NTV        木23                 ドクターカー       4.5       3.2
# 189        TBS        金22  私 結婚できないんじゃなくて、しないんです      10.3      10.3
# 190         EX        金23                 不機嫌な果実       8.2       7.4
# 191        NTV        土21                 お迎えデス。      10.3       9.3
# 192         CX        土23                    火の粉       5.8       3.6
# 193         CX        日21              OUR HOUSE       4.8       5.0
# 194        TBS        日21                   99.9      15.5      19.1
# 195        NTV        日22              ゆとりですがなにか       9.4       8.9
#
#      Episode3  Episode4 Episode5 Episode6 Episode7 Episode8 Episode9  \
# 0         9.9      10.6      9.3      8.3      9.9      8.9      9.9
# 1        10.0       9.5       10      8.9      8.5      8.6        9
# 2         7.3       6.9      6.7      6.7      8.6      7.6      6.5
# 3         9.3      11.5     11.8     11.7     12.2     10.8     10.3
# 4        18.1      17.8     15.9     19.3     18.6     17.4     18.2
# 5         4.1       3.0      4.6      4.1      4.3      4.7      4.2
# 6         4.4       3.0      3.1      2.9      3.5      3.7      3.5
# 7         7.6       6.2      7.1      5.7      7.1      6.4        7
# 8         5.9       4.9      6.3      6.2      5.5      5.5        -
# 9         8.9       8.4        8      7.7      7.4      9.1      7.2
# 10        3.5       4.6      4.3      4.2      4.3      5.1        -
# 11       11.8      13.3     12.6     11.8     11.8       11     14.7
# 12        6.4       6.5      7.1      6.4        6      7.1      6.9
# 13       12.3      12.3     12.3     14.4     11.4     10.2     12.7
# 14        6.4       5.4      6.2      6.2      6.1        6      6.7
# 15        8.7      10.0      7.8      7.5      8.1      7.5      8.5
# 16        9.0       9.8      9.4      9.3     11.3     10.9      9.7
# 17       11.5       9.5     10.7      9.9       10     11.1     12.1
# 176       4.8         -         -         -         -         -     5.62
# 177         -         -         -         -         -         -     5.64
# 178         -         -         -         -         -         -     6.66
# 179         -         -         -         -         -         -     6.13
# 180         -         -         -         -         -         -    10.58
# 181         -         -         -         -         -         -     8.27
# 182       9.3         -         -         -         -         -     8.54
# 183         -         -         -         -         -         -     8.18
# 184       8.9         -         -         -         -         -     8.02
# 185        16         -         -         -         -         -    12.88
# 186         -         -         -         -         -         -    10.77
# 187         -         -         -         -         -         -     5.61
# 188       3.7       3.7       3.4         -         -         -     3.47
# 189         9         -         -         -         -         -     9.03
# 190         -         -         -         -         -         -     7.70
# 191         -         -         -         -         -         -     7.91
# 192         -         -         -         -         -         -     4.36
# 193         -         -         -         -         -         -     4.51
# 194      19.1         -         -         -         -         -    17.15
# 195       9.3         -         -         -         -         -     8.41
#
#          suii   start_at  start_at_year  start_at_month     drama_key  \
# 0       5-5-0 2019-10-01           2019              10   1910_CX_月21
# 1       5-4-0 2019-10-01           2019              10   1910_CX_火22
# 2    2003/5/1 2019-10-01           2019              10  1910_TBS_火22
# 3       5-4-0 2019-10-01           2019              10  1910_NTV_水22
# 4       3-6-0 2019-10-01           2019              10   1910_EX_木22
# 5       3-5-0 2019-10-01           2019              10   1910_CX_木22
# 6       4-5-0 2019-10-01           2019              10  1910_NTV_木23
# 7       4-5-0 2019-10-01           2019              10  1910_TBS_金22
# 8    2001/5/1 2019-10-01           2019              10   1910_EX_金23
# 9       3-6-0 2019-10-01           2019              10  1910_NTV_土22
# 10      3-4-0 2019-10-01           2019              10   1910_EX_土23
# 11   2003/5/1 2019-10-01           2019              10  1910_TBS_日21
# 12      4-5-0 2019-10-01           2019              10  1910_NTV_日22
# 13   2003/4/3 2019-07-01           2019               7   1907_CX_月21
# 14   2004/4/1 2019-07-01           2019               7   1907_CX_火21
# 15      4-5-0 2019-07-01           2019               7  1907_TBS_火22
# 16      4-5-0 2019-07-01           2019               7  1907_NTV_水22
# 17      5-3-0 2019-07-01           2019               7   1907_EX_木21
# 18      6-4-0 2019-07-01           2019               7   1907_CX_木22
# 19   2002/6/1 2019-07-01           2019               7  1907_NTV_木23
# 20      5-4-0 2019-07-01           2019               7  1907_TBS_金22
# 21      4-3-0 2019-07-01           2019               7   1907_EX_金23
# 22      4-5-0 2019-07-01           2019               7  1907_NTV_土22
# 23      4-3-0 2019-07-01           2019               7   1907_EX_土23
# 24      5-4-0 2019-07-01           2019               7  1907_TBS_日21
# 25   2005/2/2 2019-07-01           2019               7  1907_NTV_日22
# 26      5-5-0 2019-04-01           2019               4   1904_CX_月21
# 27   2005/3/1 2019-04-01           2019               4   1904_CX_火21
# 28   2006/2/1 2019-04-01           2019               4  1904_TBS_火22
# 29   2004/4/1 2019-04-01           2019               4  1904_NTV_水22
# 30      5-4-0 2019-04-01           2019               4   1904_EX_木21
# 31   2005/3/2 2019-04-01           2019               4   1904_CX_木22
# 32   2002/6/1 2019-04-01           2019               4  1904_NTV_木23
# 33   2004/5/1 2019-04-01           2019               4  1904_TBS_金22
# 34      3-4-0 2019-04-01           2019               4   1904_EX_金23
# 35      3-6-0 2019-04-01           2019               4  1904_NTV_土22
# 36   2002/4/1 2019-04-01           2019               4   1904_EX_土23
# 37      4-5-0 2019-04-01           2019               4  1904_TBS_日21
# 38      4-5-0 2019-04-01           2019               4  1904_NTV_日22
# 39   2004/5/1 2019-01-01           2019               1   1901_CX_月21
# 40      2-6-0 2019-01-01           2019               1   1901_CX_火21
# 41      5-4-0 2019-01-01           2019               1  1901_TBS_火22
# 42   2003/5/1 2019-01-01           2019               1  1901_NTV_水22
# 43   2003/4/1 2019-01-01           2019               1   1901_EX_木21
# 44      4-5-0 2019-01-01           2019               1   1901_CX_木22
# 45   2004/4/1 2019-01-01           2019               1  1901_NTV_木23
# 46      4-5-0 2019-01-01           2019               1  1901_TBS_金22
# 47      2-5-0 2019-01-01           2019               1   1901_EX_金23
# 48   2005/3/1 2019-01-01           2019               1  1901_NTV_土22
# 49      3-3-0 2019-01-01           2019               1   1901_EX_土23
# 50      4-5-0 2019-01-01           2019               1  1901_TBS_日21
# 51      8-1-0 2019-01-01           2019               1  1901_NTV_日22
# 52      5-5-0 2018-10-01           2018              10   1810_CX_月21
# 53      5-4-0 2018-10-01           2018              10   1810_CX_火21
# 54      6-4-0 2018-10-01           2018              10  1810_TBS_火22
# 55      4-5-0 2018-10-01           2018              10  1810_NTV_水22
# 56      3-5-0 2018-10-01           2018              10   1810_EX_木21
# 57   2003/5/1 2018-10-01           2018              10   1810_CX_木22
# 58      4-5-0 2018-10-01           2018              10  1810_NTV_木23
# 59      6-3-0 2018-10-01           2018              10  1810_TBS_金22
# 60      3-4-0 2018-10-01           2018              10   1810_EX_金23
# 61   2003/5/1 2018-10-01           2018              10  1810_NTV_土22
# ...
# 79              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 80              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 81              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 82              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 83              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 84              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 85              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 86             剛力彩芽    NaN    NaN    NaN    NaN    NaN     30    NaN    NaN
# 87              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 88              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 89              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 90            戸田恵梨香    NaN    NaN     25    NaN    NaN    NaN    NaN    NaN
# 91              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 92              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 93              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 94              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 95              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 96              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 97              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 99              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 100              波瑠    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 101             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 103             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 104             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 105             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 106             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 107             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 108             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 109             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 110             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 111             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 112             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 113             蒼井優    NaN    NaN     26     25    NaN    NaN    NaN    NaN
# 114             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 115             武井咲    NaN    NaN    NaN    NaN    NaN     26     21     23
# 116            新垣結衣    NaN    NaN      9     10      7      9      5      5
# 117             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 118             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 119             黒木瞳    NaN    NaN     14     30    NaN    NaN    NaN    NaN
# 120             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 121             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 122           吉瀬美智子    NaN    NaN    NaN    NaN    NaN    NaN    NaN     27
# 123             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 124            深田恭子    NaN    NaN     20     17     21     13     18     18
# 125             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 126             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 127             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 128            橋本環奈    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 129             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 130             武井咲    NaN    NaN    NaN    NaN    NaN     26     21     23
# 131             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 133             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 134             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 136             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 137           戸田恵梨香    NaN    NaN     25    NaN    NaN    NaN    NaN    NaN
# 138             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 139            木村文乃    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# 131    NaN    NaN    NaN    NaN
# 132    NaN    NaN    NaN    NaN
# 133    NaN    NaN    NaN    NaN
# 134    NaN    NaN    NaN    NaN
# 135    NaN    NaN    NaN    NaN
# 136    NaN    NaN    NaN    NaN
# 137    NaN    NaN     21     11
# 138    NaN    NaN    NaN    NaN
# 139    NaN    NaN     24    NaN
# 140    NaN    NaN    NaN    NaN
# 141    NaN    NaN    NaN    NaN
# 142    NaN    NaN    NaN    NaN
# 143    NaN    NaN    NaN    NaN
# 144    NaN    NaN    NaN    NaN
# 145    NaN    NaN    NaN    NaN
# 146    NaN     26    NaN    NaN
# 147    NaN    NaN    NaN    NaN
# 148    NaN    NaN    NaN    NaN
# 149    NaN    NaN    NaN    NaN
# 150      8      5      4      4
# 151    NaN    NaN    NaN    NaN
# 152     19     27    NaN    NaN
# 153    NaN    NaN    NaN    NaN
# 154     26     29    NaN     21
# 155    NaN     24     22     14
# 156    NaN    NaN    NaN    NaN
# 157    NaN    NaN    NaN    NaN
# 158    NaN    NaN    NaN    NaN
# 159    NaN    NaN    NaN    NaN
# 160    NaN    NaN    NaN    NaN
# 161    NaN    NaN    NaN    NaN
# 162    NaN    NaN    NaN    NaN
# 163    NaN    NaN    NaN    NaN
# 164    NaN    NaN    NaN    NaN
# 165    NaN    NaN    NaN    NaN
# 166    NaN    NaN    NaN    NaN
# 167    NaN     19     13     24
# 168    NaN    NaN    NaN    NaN
# 169    NaN    NaN    NaN    NaN
# 170    NaN    NaN    NaN    NaN
# 171    NaN    NaN    NaN    NaN
# 172    NaN    NaN    NaN    NaN
# 173    NaN    NaN    NaN    NaN
# 174    NaN    NaN    NaN    NaN
# 175    NaN    NaN    NaN    NaN
# 176    NaN    NaN     24    NaN
# 177    NaN    NaN    NaN    NaN
# 178    NaN    NaN    NaN    NaN
# 179    NaN    NaN    NaN    NaN
# 180    NaN     24     22     14
# 181    NaN    NaN    NaN    NaN
# 182    NaN    NaN    NaN    NaN
# 183    NaN    NaN    NaN     30
# 184    NaN    NaN    NaN    NaN
# 185    NaN    NaN     26     25
# 186    NaN    NaN    NaN    NaN
# 187    NaN    NaN    NaN    NaN
# 188    NaN    NaN    NaN    NaN
# 189    NaN    NaN    NaN    NaN
# 190    NaN    NaN    NaN    NaN
# 191    NaN     19     13     24
# 192     24    NaN    NaN    NaN
# 193    NaN    NaN    NaN    NaN
# 194    NaN    NaN    NaN    NaN
# 195    NaN    NaN    NaN    NaN

# %%
df_new4years["main_actor1_rank"] = np.nan
df_new4years["main_actor2_rank"] = np.nan

# %%
for i in range(len(df_new4years)):
    #print(df_new4years.iloc[i])
#     print(df_new4years.iloc[i]["start_at"])
    prev_year = df_new4years["start_at"].dt.year.iloc[i] - 1 
    df_filter = df_new4years.loc[:,df_new4years.columns.str.contains(str(prev_year))]
#   import pdb;pdb.set_trace()
    
    prev_year1 = str(prev_year) + "_1"
    prev_year2 = str(prev_year) + "_2"
    prev_year3 = str(prev_year) + "_3"
    prev_year4 = str(prev_year) + "_4"
#     import pdb; pdb.set_trace()
    for j in range(len(df_filter)):
        tmp1 =  0 if np.isnan(df_filter[prev_year1].iloc[j]) else df_filter[prev_year1].iloc[j]
        tmp2 =  0 if np.isnan(df_filter[prev_year2].iloc[j]) else df_filter[prev_year2].iloc[j]
        tmp3 =  0 if np.isnan(df_filter[prev_year3].iloc[j]) else df_filter[prev_year3].iloc[j]
        tmp4 =  0 if np.isnan(df_filter[prev_year4].iloc[j]) else df_filter[prev_year4].iloc[j]
#         import pdb; pdb.set_trace()
        df_new4years["main_actor1_rank"].iloc[j] =   tmp1 + tmp2 if (tmp1 + tmp2 != 0) else np.nan
        df_new4years["main_actor2_rank"].iloc[j] =   tmp3 + tmp4 if (tmp3 + tmp4 != 0) else np.nan
#         print(dbg)
#     df_filter[prev_year + "_2"]
#    if  np.isnan(df_filter["2018_1"]) or np.isnan(df_filter["2018_2"])  :
#        print("come")

# %%
df_new4years["main_actor1_rank"]
# Out:
# 0       NaN
# 1       1.0
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9      24.0
# 10      NaN
# 11     21.0
# 12      NaN
# 13     30.0
# 14      NaN
# 15     12.0
# 16      7.0
# 17      NaN
# 18     18.0
# 19      NaN
# 20      NaN
# 21      NaN
# 22     22.0
# 23      NaN
# 24     12.0
# 25      NaN
# 26      NaN
# 27      NaN
# 28     26.0
# 29      NaN
# 30      8.0
# 31      NaN
# 32      NaN
# 33      NaN
# 34     25.0
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
# 40      NaN
# 41     18.0
# 42      4.0
# 43      NaN
# 44     16.0
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49      NaN
# 50      NaN
# 51      NaN
# 52      NaN
# 53      NaN
# 54      NaN
# 55      5.0
# 56      9.0
# 57      NaN
# 58      NaN
# 59      NaN
# 60      6.0
# 61      NaN
# 62      NaN
# 63      1.0
# 64      NaN
# 65      NaN
# 66      NaN
# 67      1.0
# 68     12.0
# 69      NaN
# 70      NaN
# 71      NaN
# 72      NaN
# 73      NaN
# 74      NaN
# 75      NaN
# 76      NaN
# 77      NaN
# 78     22.0
# 79      NaN
# 80      NaN
# 81     26.0
# 82      NaN
# 83      NaN
# 84      NaN
# 85      NaN
# 86     25.0
# 87      NaN
# 88      NaN
# 89      4.0
# 90      NaN
# 91      NaN
# 92      NaN
# 93      NaN
# 94      NaN
# 95     21.0
# 96     18.0
# 97      NaN
# 98     12.0
# 99      NaN
# 100     NaN
# 101     NaN
# 102     8.0
# 103     NaN
# 104    13.0
# 105    20.0
# 106    24.0
# 107     1.0
# 108     9.0
# 109     NaN
# 110     NaN
# 111     NaN
# 112     NaN
# 113     3.0
# 114     NaN
# 115     NaN
# 116     NaN
# 117     NaN
# 118     NaN
# 119     NaN
# 120     NaN
# 121    23.0
# 122     NaN
# 123     NaN
# 124    27.0
# 125     NaN
# 126     NaN
# 127    14.0
# 128     NaN
# 129     NaN
# 130     6.0
# 131    13.0
# 132     NaN
# 133     NaN
# 134     8.0
# 135    29.0
# 136     NaN
# 137     NaN
# 138     NaN
# 139     NaN
# 140     NaN
# 141     NaN
# 142     NaN
# 143     NaN
# 144     NaN
# 145    11.0
# 146    26.0
# 147     NaN
# 148     NaN
# 149     NaN
# 150    16.0
# 151     NaN
# 152    23.0
# 153     NaN
# 154    21.0
# 155     NaN
# 156     NaN
# 157     NaN
# 158     5.0
# 159    12.0
# 160     9.0
# 161     8.0
# 162     NaN
# 163    15.0
# 164    25.0
# 165    22.0
# 166    28.0
# 167     NaN
# 168     NaN
# 169    29.0
# 170     NaN
# 171    23.0
# 172     4.0
# 173     NaN
# 174    14.0
# 175     NaN
# 176    19.0
# 177     NaN
# 178     NaN
# 179     NaN
# 180     NaN
# 181     NaN
# 182     NaN
# 183     NaN
# 184     NaN
# 185     2.0
# 186    15.0
# 187     NaN
# 188     NaN
# 189     NaN
# 190     NaN
# 191     NaN
# 192     NaN
# 193     NaN
# 194     8.0
# 195     NaN
# Name: main_actor1_rank, dtype: float64

# %%
df_new4years["main_actor2_rank"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24     11.0
# 25      NaN
# 26      NaN
# 27      NaN
# 28     19.0
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37     11.0
# 38      NaN
# 39      NaN
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 46     30.0
# 47      NaN
# 48      NaN
# 49      NaN
# 50      NaN
# 51      NaN
# 52      NaN
# 53      NaN
# 54      NaN
# 55      NaN
# 56     19.0
# 57      NaN
# 58      NaN
# 59      NaN
# 60      NaN
# 61      NaN
# 62      NaN
# 63      NaN
# 64      NaN
# 65      NaN
# 66      NaN
# 67     15.0
# 68      NaN
# 69      NaN
# 70     30.0
# 71      NaN
# 72      NaN
# 73      NaN
# 74      NaN
# 75      NaN
# 76      NaN
# 77      NaN
# 78      NaN
# 79      NaN
# 80      NaN
# 81      NaN
# 82      NaN
# 83      NaN
# 84      NaN
# 85     28.0
# 86      NaN
# 87      NaN
# 88      NaN
# 89      NaN
# 90      NaN
# 91      NaN
# 92      NaN
# 93      NaN
# 94      NaN
# 95      NaN
# 96      NaN
# 97      NaN
# 98      NaN
# 99      NaN
# 100     NaN
# 101     NaN
# 102    11.0
# 103     NaN
# 104     NaN
# 105     NaN
# 106     NaN
# 107     NaN
# 108     NaN
# 109     NaN
# 110     NaN
# 111     NaN
# 112     NaN
# 113     NaN
# 114     NaN
# 115    23.0
# 116     5.0
# 117     NaN
# 118     NaN
# 119     NaN
# 120     NaN
# 121     NaN
# 122    27.0
# 123     NaN
# 124    18.0
# 125     NaN
# 126     NaN
# 127     NaN
# 128     NaN
# 129     NaN
# 130    23.0
# 131    30.0
# 132     NaN
# 133     NaN
# 134     NaN
# 135     NaN
# 136     NaN
# 137     NaN
# 138     NaN
# 139     NaN
# 140     NaN
# 141     NaN
# 142     NaN
# 143     NaN
# 144     NaN
# 145     NaN
# 146     NaN
# 147     NaN
# 148     NaN
# 149     NaN
# 150    18.0
# 151     NaN
# 152    24.0
# 153     NaN
# 154    16.0
# 155     NaN
# 156     NaN
# 157     NaN
# 158     NaN
# 159     NaN
# 160     NaN
# 161     NaN
# 162     NaN
# 163     NaN
# 164     NaN
# 165     NaN
# 166     NaN
# 167     NaN
# 168     NaN
# 169     NaN
# 170     NaN
# 171     NaN
# 172     NaN
# 173     NaN
# 174     NaN
# 175     NaN
# 176     NaN
# 177     NaN
# 178     NaN
# 179     NaN
# 180     NaN
# 181     NaN
# 182     NaN
# 183     NaN
# 184     NaN
# 185     NaN
# 186     NaN
# 187     NaN
# 188     NaN
# 189     NaN
# 190     NaN
# 191     NaN
# 192    19.0
# 193     NaN
# 194    11.0
# 195     NaN
# Name: main_actor2_rank, dtype: float64

# %%
df_episode = df_new4years.loc[:, df_new4years.columns.str.contains("Epi")]

# %%
df_new4years["average_calc"] = np.nan

# %%
# averageを計算してみたが、もともとあるaverageが加重平均だったので、そちらを採用することに
for i in  range(len(df_episode)):
    vr_sum = 0
    for epi_i, col in  enumerate(df_episode.columns):
#         print(str(df_new4years[col].iloc[i] )+ "__"+str(vr_sum) +"_"+str(epi_i) + "index"+str(i))
        if df_episode[col].iloc[i] == "-"  :
            if epi_i == 0:
#                 print (col+"_"+str(epi_i))
                break
            df_new4years["average_calc"].iloc[i] = vr_sum/epi_i
            break
#            df_new4years["average_calc"].iloc[i] = vr_sum/i
        vr_sum += float(df_episode[col].iloc[i])
        if epi_i == 14 : df_new4years["average_calc"].iloc[i] = vr_sum / 15
        
        #df_new4years.iloc[i]

# %%
df_cm = pd.read_csv("../data/number_of_cm.csv", encoding='cp932')

# %%
df_cm["name_ns"] = df_cm.name.str.replace('\s','')

# %%
t_name ="ベッキー"
t_year = str(2007)
tmp_q = f"name_ns == '{t_name}' & year == '{t_year}' " 
print(tmp_q)

df_cm.query(tmp_q)
# Out:
# name_ns == 'ベッキー' & year == '2007'
#      year sex  number_of_cm  name age group name_ns
# 479  2007   f            11  ベッキー  23   NaN    ベッキー

# %%
for t_name in set(df_cm.name_ns.values):
    for t_year in range(1990,2019):
        
        tmp_q = f"name_ns == '{t_name}' & year == '{t_year}' " 
# print(tmp_q)
        try :
            tmp_df = df_cm.query(tmp_q)
    #             print(f'{tmp_df["number_of_cm"].values} タレント{t_name},{t_year}年')
            if tmp_df["number_of_cm"].values:
                print(f'{tmp_df["number_of_cm"].values} タレント{t_name},{t_year}年')
                df_cm_pivot.loc[t_name,t_year] = int(tmp_df["number_of_cm"].values)
        except KeyError as instance:
            print (instance)
# Out:
# [5] タレント柳葉敏郎,1990年
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6fc5d8a728c9> in <module>
#       9             if tmp_df["number_of_cm"].values:
#      10                 print(f'{tmp_df["number_of_cm"].values} タレント{t_name},{t_year}年')
# ---> 11                 df_cm_pivot.loc[t_name,t_year] = int(tmp_df["number_of_cm"].values)
#      12         except KeyError as instance:
#      13             print (instance)
#
# NameError: name 'df_cm_pivot' is not defined

# %%
df_cm_pivot = pd.DataFrame(index = columns =  )

# %% [markdown]
# # 特徴量エンジニアリング

# %% [markdown]
# ### 俳優ランクを人気ポイントに

# %%
df_new4years["main_actor1_pt"] = df_new4years["main_actor1_rank"].apply(lambda x : 40 - x )

# %%
df_new4years["main_actor2_pt"] = df_new4years["main_actor2_rank"].apply(lambda x : 40 - x )

# %%
df_new4years["main_actor1_pt"] = df_new4years["main_actor1_pt"].fillna(0)
df_new4years["main_actor2_pt"] = df_new4years["main_actor2_pt"].fillna(0)

# %%
df_new4years["has_original_work"] = df_new4years["original_work"].apply(lambda x : "" if x =="" else True )

# %% [markdown]
# ### one hotエンコーディング

# %%
df_new4years = pd.get_dummies(df_new4years, columns=["TV_station", "start_at_month", "start_at_year","has_original_work"] )

# %% [markdown]
# ### モデル作成

# %%
lm = LinearRegression()

# %%
y = df_new4years["average"]

# %%
df_new4years

# %%
X = df_new4years[["main_actor1_pt" , "main_actor2_pt"]]

# %%
X_dummys = df_new4years.loc[:,df_new4years.columns.str.contains(('start_at_year_|TV_station_|start_at_month_|has_original_work'))]

# %%
# arr = df_new4years.columns.str.contains(('start_at_year_|TV_station_|start_at_month_'))
df_cm["name_ns"]

# %%
# df_new4years.loc[:, arr]

# %%
X_dummys

# %%
X = pd.concat([X,X_dummys], axis=1)

# %% [markdown]
# ### モデル作成

# %%
y = df_new4years["average"]

# %%
lm = LinearRegression()

# %%
 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234 )

# %%
model=lm.fit(X_train,y_train)
#predictions=model.predict(x_test)

# %%
y_pred = lm.predict(X_test)

# %%
lm_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
print(lm_rmse)

# %%
y_test

# %%
for i in range(len(y_pred)):
    a = y_test.values[i]
    b = y_pred[i]
    print(f'視聴率：実際 {a}   \t 予測 {b} ')

# %%
for i in range (len (X.columns)):
    print(f"""{i}  回帰係数 {X.columns[i]}\t{model.coef_[i]} """)

# %%
print('モデル関数の切片 w2: %.3f' %model.intercept_)

# %%
print('決定係数 R^2： ', model.score(X, y))

# %% [markdown]
# # モデル２決定木

# %%
# clf = DecisionTreeRegressor(max_depth = 3)
clf = DecisionTreeRegressor(max_leaf_nodes= 14)
clf.fit(X_train, y_train)

# %%
y_pred_tree = clf.predict(X_test)

# %%
lm_rmse = np.sqrt(mean_squared_error(y_test, y_pred_tree))
print (lm_rmse)

# %%
for i in range (len (X.columns)):
    print(f"""{i}  FI {X.columns[i]}     \t{clf.feature_importances_[i]} """)

# %%
for i in range(len(y_pred)):
    a = y_test.values[i]
    b = y_pred[i]
    print(f'視聴率：実際 {a}   \t 予測 {b} ')

# %%
dot_data = tree.export_graphviz(
    clf,
    out_file=None,
    feature_names=X.columns,
    class_names="average",
    filled=True,
    proportion=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
